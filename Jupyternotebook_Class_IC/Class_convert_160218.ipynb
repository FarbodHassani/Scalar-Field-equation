# %%
import numpy as np
import matplotlib.pylab as plt
from scipy.interpolate import interp1d

# %% [markdown]
# # \pi' comparison between class and hi-class

# %%
# Class_newt=np.loadtxt("./Kessence_field_class_Newt.dat")
Class_synch=np.loadtxt("./Kessence_field_class_synch.dat")
# hiclass_cs1=np.loadtxt("./Kessence_field_cs1.dat")
# hiclass_cs0z0=np.loadtxt("./Kessence_field_cs0_z0.dat")
# class_cs0_synch=np.loadtxt("./class_kess_cs0_synch_tk.dat")
# class_cs1_synch=np.loadtxt("./class_kess_cs1_synch_tk.dat")
# class_cs0_newt=np.loadtxt("./class_kess_cs0_newt_tk.dat")
# class_cs1_newt=np.loadtxt("./class_kess_cs1_newt_tk.dat")

# %% [markdown]
# # Make the file of hi-class

# %% [markdown]
# # Making file in Newtonian gauge at z=100

# %%
h=0.67;
# file=open("kessenc.dat",'w+');
data_hi = Class_newt
Num_columns=3;
astar_hi=1./101. # z=100, desired redshift
ainterval_hi=0.3  # if you get interpolation error just increase this number :D
mask_hi = np.logical_and(data_hi[:,1]>astar_hi-ainterval_hi, data_hi[:,1]<astar_hi+ainterval_hi)
# 1 is a column
dataprime_hi = data_hi[mask_hi]

condition_hi=np.zeros(np.shape(dataprime_hi)[0])
for i in range(0,np.shape(dataprime_hi)[0]-1):
    condition_hi[i]=int(np.array_equal(dataprime_hi[i,0],dataprime_hi[i+1,0]))
#0 is k
klistinitial_hi=np.zeros(np.shape(dataprime_hi)[0]);
j=0;
for i in range (0,np.shape(dataprime_hi)[0]-1):
    if (condition_hi[i]==0):
        klistinitial_hi[j]=dataprime_hi[i-1,0]
        j+=1;

klist_hi = klistinitial_hi[klistinitial_hi!=0]
# klist_hi

dataprime_separated_hi = np.zeros((np.shape(klist_hi)[0],np.shape(dataprime_hi)[0],Num_columns))
for l,p in enumerate(klist_hi):
    w = np.shape(dataprime_hi[dataprime_hi[:,0]==p])[0]
    dataprime_separated_hi[l,:w,:] = dataprime_hi[dataprime_hi[:,0]==p]
#     print("separated",dataprime_separated)
# np.shape(dataprime_separated_hi)
hiclass_cs0_fin=np.zeros((np.shape(klist_hi)[0],3)); # the final file for the fiels are initialized, klist is the list ok k without repitition
# Transfer_kess=np.zeros((np.shape(klist)[0],8)); # the final file for the fiels are initialized, klist is the list ok k without repitition
Gev_cs0=np.zeros((np.shape(klist_hi)[0],3)); # the Gev appropriate file                                             #It must be in Newtonian gauge

for i in range(np.shape(klist_hi)[0]):
# #     print(i)
    Vec_x_hi = dataprime_separated_hi[i,dataprime_separated_hi[i,:,0]!=0,:]
    interp_psi =interp1d(Vec_x_hi[:,1],Vec_x_hi[:,2])
        
    hiclass_cs0_fin[i,0]=klist_hi[i]
    hiclass_cs0_fin[i,1]=interp_psi(astar_hi)
    hiclass_cs0_fin[i,2]=astar_hi;
    Gev_cs0[i,0]=hiclass_cs0_fin[i,0];
    Gev_cs0[i,1]=hiclass_cs0_fin[i,1];
    Gev_cs0[i,2]=hiclass_cs0_fin[i,2];
    
Result=Gev_cs0[::-1,:];
np.savetxt('class_psi_newt_cs0z100.dat', Result, fmt='%.12e', delimiter='\t', newline='\n')

# %%
h=0.67;
# file=open("kessenc.dat",'w+');
data_hi = Class_synch
Num_columns=6;
astar_hi=1./101. # z=100, desired redshift
ainterval_hi=0.3  # if you get interpolation error just increase this number :D
mask_hi = np.logical_and(data_hi[:,1]>astar_hi-ainterval_hi, data_hi[:,1]<astar_hi+ainterval_hi)
# 1 is a column
dataprime_hi = data_hi[mask_hi]

condition_hi=np.zeros(np.shape(dataprime_hi)[0])
for i in range(0,np.shape(dataprime_hi)[0]-1):
    condition_hi[i]=int(np.array_equal(dataprime_hi[i,0],dataprime_hi[i+1,0]))
#0 is k
klistinitial_hi=np.zeros(np.shape(dataprime_hi)[0]);
j=0;
for i in range (0,np.shape(dataprime_hi)[0]-1):
    if (condition_hi[i]==0):
        klistinitial_hi[j]=dataprime_hi[i-1,0]
        j+=1;

klist_hi = klistinitial_hi[klistinitial_hi!=0]
# klist_hi

dataprime_separated_hi = np.zeros((np.shape(klist_hi)[0],np.shape(dataprime_hi)[0],Num_columns))
for l,p in enumerate(klist_hi):
    w = np.shape(dataprime_hi[dataprime_hi[:,0]==p])[0]
    dataprime_separated_hi[l,:w,:] = dataprime_hi[dataprime_hi[:,0]==p]
#     print("separated",dataprime_separated)
# np.shape(dataprime_separated_hi)
hiclass_cs0_fin=np.zeros((np.shape(klist_hi)[0],Num_columns)); # the final file for the fiels are initialized, klist is the list ok k without repitition
# Transfer_kess=np.zeros((np.shape(klist)[0],8)); # the final file for the fiels are initialized, klist is the list ok k without repitition
# Gev_cs0=np.zeros((np.shape(klist_hi)[0],3)); # the Gev appropriate file                                             #It must be in Newtonian gauge

for i in range(np.shape(klist_hi)[0]):
# #     print(i)
    Vec_x_hi = dataprime_separated_hi[i,dataprime_separated_hi[i,:,0]!=0,:]
    interp_psi =interp1d(Vec_x_hi[:,1],Vec_x_hi[:,2])
    interp_alpha =interp1d(Vec_x_hi[:,1],Vec_x_hi[:,3])
    interp_alpha_prime =interp1d(Vec_x_hi[:,1],Vec_x_hi[:,4])
    interp_hubble =interp1d(Vec_x_hi[:,1],Vec_x_hi[:,5])

    hiclass_cs0_fin[i,0]=klist_hi[i]
    hiclass_cs0_fin[i,1]=interp_psi(astar_hi)
    hiclass_cs0_fin[i,2]=interp_alpha(astar_hi);
    hiclass_cs0_fin[i,3]=interp_alpha_prime(astar_hi);
    hiclass_cs0_fin[i,4]=interp_hubble(astar_hi);
    hiclass_cs0_fin[i,5]=astar_hi;
    
#     Gev_cs0[i,0]=hiclass_cs0_fin[i,0];
#     Gev_cs0[i,1]=hiclass_cs0_fin[i,1];
#     Gev_cs0[i,2]=hiclass_cs0_fin[i,2];
    
Result=hiclass_cs0_fin[::-1,:];
np.savetxt('class_synch_cs2z100.dat', Result, fmt='%.12e', delimiter='\t', newline='\n')

# %% [markdown]
# # Making file in Newtonian gauge at z=10

# %%
h=0.67;
# file=open("kessenc.dat",'w+');
data_hi = Class_newt
astar_hi=1./(10.+1.) # z=10, desired redshift
ainterval_hi=0.03
mask_hi = np.logical_and(data_hi[:,1]>astar_hi-ainterval_hi, data_hi[:,1]<astar_hi+ainterval_hi)
# 1 is a column
dataprime_hi = data_hi[mask_hi]

condition_hi=np.zeros(np.shape(dataprime_hi)[0])
for i in range(0,np.shape(dataprime_hi)[0]-1):
    condition_hi[i]=int(np.array_equal(dataprime_hi[i,0],dataprime_hi[i+1,0]))
#0 is k
klistinitial_hi=np.zeros(np.shape(dataprime_hi)[0]);
j=0;
for i in range (0,np.shape(dataprime_hi)[0]-1):
    if (condition_hi[i]==0):
        klistinitial_hi[j]=dataprime_hi[i-1,0]
        j+=1;

klist_hi = klistinitial_hi[klistinitial_hi!=0]
# klist_hi

dataprime_separated_hi = np.zeros((np.shape(klist_hi)[0],np.shape(dataprime_hi)[0],Num_columns))
for l,p in enumerate(klist_hi):
    w = np.shape(dataprime_hi[dataprime_hi[:,0]==p])[0]
    dataprime_separated_hi[l,:w,:] = dataprime_hi[dataprime_hi[:,0]==p]
#     print("separated",dataprime_separated)
# np.shape(dataprime_separated_hi)
hiclass_cs0_fin=np.zeros((np.shape(klist_hi)[0],3)); # the final file for the fiels are initialized, klist is the list ok k without repitition
# Transfer_kess=np.zeros((np.shape(klist)[0],8)); # the final file for the fiels are initialized, klist is the list ok k without repitition
Gev_cs0=np.zeros((np.shape(klist_hi)[0],3)); # the Gev appropriate file                                             #It must be in Newtonian gauge

for i in range(np.shape(klist_hi)[0]):
# #     print(i)
    Vec_x_hi = dataprime_separated_hi[i,dataprime_separated_hi[i,:,0]!=0,:]
    interp_psi =interp1d(Vec_x_hi[:,1],Vec_x_hi[:,2])
        
    hiclass_cs0_fin[i,0]=klist_hi[i]
    hiclass_cs0_fin[i,1]=interp_psi(astar_hi)
    hiclass_cs0_fin[i,2]=astar_hi;
    Gev_cs0[i,0]=hiclass_cs0_fin[i,0];
    Gev_cs0[i,1]=hiclass_cs0_fin[i,1];
    Gev_cs0[i,2]=hiclass_cs0_fin[i,2];
    
Result=Gev_cs0[::-1,:];
np.savetxt('class_psi_newt_cs0z10.dat', Result, fmt='%.12e', delimiter='\t', newline='\n')
# hiclass_cs0_fin[:30,0]

# %%
h=0.67;
# file=open("kessenc.dat",'w+');
data_hi = Class_synch
Num_columns=6;
astar_hi=1./(10.+1.) # z=10, desired redshift
ainterval_hi=0.3  # if you get interpolation error just increase this number :D
mask_hi = np.logical_and(data_hi[:,1]>astar_hi-ainterval_hi, data_hi[:,1]<astar_hi+ainterval_hi)
# 1 is a column
dataprime_hi = data_hi[mask_hi]

condition_hi=np.zeros(np.shape(dataprime_hi)[0])
for i in range(0,np.shape(dataprime_hi)[0]-1):
    condition_hi[i]=int(np.array_equal(dataprime_hi[i,0],dataprime_hi[i+1,0]))
#0 is k
klistinitial_hi=np.zeros(np.shape(dataprime_hi)[0]);
j=0;
for i in range (0,np.shape(dataprime_hi)[0]-1):
    if (condition_hi[i]==0):
        klistinitial_hi[j]=dataprime_hi[i-1,0]
        j+=1;

klist_hi = klistinitial_hi[klistinitial_hi!=0]
# klist_hi

dataprime_separated_hi = np.zeros((np.shape(klist_hi)[0],np.shape(dataprime_hi)[0],Num_columns))
for l,p in enumerate(klist_hi):
    w = np.shape(dataprime_hi[dataprime_hi[:,0]==p])[0]
    dataprime_separated_hi[l,:w,:] = dataprime_hi[dataprime_hi[:,0]==p]
#     print("separated",dataprime_separated)
# np.shape(dataprime_separated_hi)
hiclass_cs0_fin=np.zeros((np.shape(klist_hi)[0],Num_columns)); # the final file for the fiels are initialized, klist is the list ok k without repitition
# Transfer_kess=np.zeros((np.shape(klist)[0],8)); # the final file for the fiels are initialized, klist is the list ok k without repitition
# Gev_cs0=np.zeros((np.shape(klist_hi)[0],3)); # the Gev appropriate file                                             #It must be in Newtonian gauge

for i in range(np.shape(klist_hi)[0]):
# #     print(i)
    Vec_x_hi = dataprime_separated_hi[i,dataprime_separated_hi[i,:,0]!=0,:]
    interp_psi =interp1d(Vec_x_hi[:,1],Vec_x_hi[:,2])
    interp_alpha =interp1d(Vec_x_hi[:,1],Vec_x_hi[:,3])
    interp_alpha_prime =interp1d(Vec_x_hi[:,1],Vec_x_hi[:,4])
    interp_hubble =interp1d(Vec_x_hi[:,1],Vec_x_hi[:,5])

    hiclass_cs0_fin[i,0]=klist_hi[i]
    hiclass_cs0_fin[i,1]=interp_psi(astar_hi)
    hiclass_cs0_fin[i,2]=interp_alpha(astar_hi);
    hiclass_cs0_fin[i,3]=interp_alpha_prime(astar_hi);
    hiclass_cs0_fin[i,4]=interp_hubble(astar_hi);
    hiclass_cs0_fin[i,5]=astar_hi;
    
#     Gev_cs0[i,0]=hiclass_cs0_fin[i,0];
#     Gev_cs0[i,1]=hiclass_cs0_fin[i,1];
#     Gev_cs0[i,2]=hiclass_cs0_fin[i,2];
    
Result=hiclass_cs0_fin[::-1,:];
np.savetxt('class_synch_cs2z10.dat', Result, fmt='%.12e', delimiter='\t', newline='\n')

# %% [markdown]
# # Making file in Newtonian gauge at z=3

# %%
h=0.67;
# file=open("kessenc.dat",'w+');
data_hi = Class_newt
astar_hi=1./(3.+1.) # z=10, desired redshift
ainterval_hi=0.03
mask_hi = np.logical_and(data_hi[:,1]>astar_hi-ainterval_hi, data_hi[:,1]<astar_hi+ainterval_hi)
# 1 is a column
dataprime_hi = data_hi[mask_hi]

condition_hi=np.zeros(np.shape(dataprime_hi)[0])
for i in range(0,np.shape(dataprime_hi)[0]-1):
    condition_hi[i]=int(np.array_equal(dataprime_hi[i,0],dataprime_hi[i+1,0]))
#0 is k
klistinitial_hi=np.zeros(np.shape(dataprime_hi)[0]);
j=0;
for i in range (0,np.shape(dataprime_hi)[0]-1):
    if (condition_hi[i]==0):
        klistinitial_hi[j]=dataprime_hi[i-1,0]
        j+=1;

klist_hi = klistinitial_hi[klistinitial_hi!=0]
# klist_hi

dataprime_separated_hi = np.zeros((np.shape(klist_hi)[0],np.shape(dataprime_hi)[0],Num_columns))
for l,p in enumerate(klist_hi):
    w = np.shape(dataprime_hi[dataprime_hi[:,0]==p])[0]
    dataprime_separated_hi[l,:w,:] = dataprime_hi[dataprime_hi[:,0]==p]
#     print("separated",dataprime_separated)
# np.shape(dataprime_separated_hi)
hiclass_cs0_fin=np.zeros((np.shape(klist_hi)[0],3)); # the final file for the fiels are initialized, klist is the list ok k without repitition
# Transfer_kess=np.zeros((np.shape(klist)[0],8)); # the final file for the fiels are initialized, klist is the list ok k without repitition
Gev_cs0=np.zeros((np.shape(klist_hi)[0],3)); # the Gev appropriate file                                             #It must be in Newtonian gauge

for i in range(np.shape(klist_hi)[0]):
# #     print(i)
    Vec_x_hi = dataprime_separated_hi[i,dataprime_separated_hi[i,:,0]!=0,:]
    interp_psi =interp1d(Vec_x_hi[:,1],Vec_x_hi[:,2])
        
    hiclass_cs0_fin[i,0]=klist_hi[i]
    hiclass_cs0_fin[i,1]=interp_psi(astar_hi)
    hiclass_cs0_fin[i,2]=astar_hi;
    Gev_cs0[i,0]=hiclass_cs0_fin[i,0];
    Gev_cs0[i,1]=hiclass_cs0_fin[i,1];
    Gev_cs0[i,2]=hiclass_cs0_fin[i,2];
    
Result=Gev_cs0[::-1,:];
np.savetxt('class_psi_newt_cs0z3.dat', Result, fmt='%.12e', delimiter='\t', newline='\n')
# hiclass_cs0_fin[:30,0]

# %%
h=0.67;
# file=open("kessenc.dat",'w+');
data_hi = Class_synch
Num_columns=6;
astar_hi=1./(3.+1.) # z=3, desired redshift
ainterval_hi=0.3  # if you get interpolation error just increase this number :D
mask_hi = np.logical_and(data_hi[:,1]>astar_hi-ainterval_hi, data_hi[:,1]<astar_hi+ainterval_hi)
# 1 is a column
dataprime_hi = data_hi[mask_hi]

condition_hi=np.zeros(np.shape(dataprime_hi)[0])
for i in range(0,np.shape(dataprime_hi)[0]-1):
    condition_hi[i]=int(np.array_equal(dataprime_hi[i,0],dataprime_hi[i+1,0]))
#0 is k
klistinitial_hi=np.zeros(np.shape(dataprime_hi)[0]);
j=0;
for i in range (0,np.shape(dataprime_hi)[0]-1):
    if (condition_hi[i]==0):
        klistinitial_hi[j]=dataprime_hi[i-1,0]
        j+=1;

klist_hi = klistinitial_hi[klistinitial_hi!=0]
# klist_hi

dataprime_separated_hi = np.zeros((np.shape(klist_hi)[0],np.shape(dataprime_hi)[0],Num_columns))
for l,p in enumerate(klist_hi):
    w = np.shape(dataprime_hi[dataprime_hi[:,0]==p])[0]
    dataprime_separated_hi[l,:w,:] = dataprime_hi[dataprime_hi[:,0]==p]
#     print("separated",dataprime_separated)
# np.shape(dataprime_separated_hi)
hiclass_cs0_fin=np.zeros((np.shape(klist_hi)[0],Num_columns)); # the final file for the fiels are initialized, klist is the list ok k without repitition
# Transfer_kess=np.zeros((np.shape(klist)[0],8)); # the final file for the fiels are initialized, klist is the list ok k without repitition
# Gev_cs0=np.zeros((np.shape(klist_hi)[0],3)); # the Gev appropriate file                                             #It must be in Newtonian gauge

for i in range(np.shape(klist_hi)[0]):
# #     print(i)
    Vec_x_hi = dataprime_separated_hi[i,dataprime_separated_hi[i,:,0]!=0,:]
    interp_psi =interp1d(Vec_x_hi[:,1],Vec_x_hi[:,2])
    interp_alpha =interp1d(Vec_x_hi[:,1],Vec_x_hi[:,3])
    interp_alpha_prime =interp1d(Vec_x_hi[:,1],Vec_x_hi[:,4])
    interp_hubble =interp1d(Vec_x_hi[:,1],Vec_x_hi[:,5])

    hiclass_cs0_fin[i,0]=klist_hi[i]
    hiclass_cs0_fin[i,1]=interp_psi(astar_hi)
    hiclass_cs0_fin[i,2]=interp_alpha(astar_hi);
    hiclass_cs0_fin[i,3]=interp_alpha_prime(astar_hi);
    hiclass_cs0_fin[i,4]=interp_hubble(astar_hi);
    hiclass_cs0_fin[i,5]=astar_hi;
    
#     Gev_cs0[i,0]=hiclass_cs0_fin[i,0];
#     Gev_cs0[i,1]=hiclass_cs0_fin[i,1];
#     Gev_cs0[i,2]=hiclass_cs0_fin[i,2];
    
Result=hiclass_cs0_fin[::-1,:];
np.savetxt('class_synch_cs2z3.dat', Result, fmt='%.12e', delimiter='\t', newline='\n')

# %% [markdown]
# # Making file in Newtonian gauge at z=0

# %%
h=0.67;
# file=open("kessenc.dat",'w+');
data_hi = Class_newt
astar_hi=1./(0.+1.) # z=10, desired redshift
ainterval_hi=0.03
mask_hi = np.logical_and(data_hi[:,1]>astar_hi-ainterval_hi, data_hi[:,1]<astar_hi+ainterval_hi)
# 1 is a column
dataprime_hi = data_hi[mask_hi]

condition_hi=np.zeros(np.shape(dataprime_hi)[0])
for i in range(0,np.shape(dataprime_hi)[0]-1):
    condition_hi[i]=int(np.array_equal(dataprime_hi[i,0],dataprime_hi[i+1,0]))
#0 is k
klistinitial_hi=np.zeros(np.shape(dataprime_hi)[0]);
j=0;
for i in range (0,np.shape(dataprime_hi)[0]-1):
    if (condition_hi[i]==0):
        klistinitial_hi[j]=dataprime_hi[i-1,0]
        j+=1;

klist_hi = klistinitial_hi[klistinitial_hi!=0]
# klist_hi

dataprime_separated_hi = np.zeros((np.shape(klist_hi)[0],np.shape(dataprime_hi)[0],Num_columns))
for l,p in enumerate(klist_hi):
    w = np.shape(dataprime_hi[dataprime_hi[:,0]==p])[0]
    dataprime_separated_hi[l,:w,:] = dataprime_hi[dataprime_hi[:,0]==p]
#     print("separated",dataprime_separated)
# np.shape(dataprime_separated_hi)
hiclass_cs0_fin=np.zeros((np.shape(klist_hi)[0],3)); # the final file for the fiels are initialized, klist is the list ok k without repitition
# Transfer_kess=np.zeros((np.shape(klist)[0],8)); # the final file for the fiels are initialized, klist is the list ok k without repitition
Gev_cs0=np.zeros((np.shape(klist_hi)[0],3)); # the Gev appropriate file                                             #It must be in Newtonian gauge

for i in range(np.shape(klist_hi)[0]):
# #     print(i)
    Vec_x_hi = dataprime_separated_hi[i,dataprime_separated_hi[i,:,0]!=0,:]
    interp_psi =interp1d(Vec_x_hi[:,1],Vec_x_hi[:,2])
        
    hiclass_cs0_fin[i,0]=klist_hi[i]
    hiclass_cs0_fin[i,1]=interp_psi(astar_hi)
    hiclass_cs0_fin[i,2]=astar_hi;
    Gev_cs0[i,0]=hiclass_cs0_fin[i,0];
    Gev_cs0[i,1]=hiclass_cs0_fin[i,1];
    Gev_cs0[i,2]=hiclass_cs0_fin[i,2];
    
Result=Gev_cs0[::-1,:];
np.savetxt('class_psi_newt_cs0z0.dat', Result, fmt='%.12e', delimiter='\t', newline='\n')
# hiclass_cs0_fin[:30,0]

# %%
h=0.67;
# file=open("kessenc.dat",'w+');
data_hi = Class_synch
Num_columns=6;
astar_hi=1./(0.+1.) # z=0, desired redshift
ainterval_hi=0.3  # if you get interpolation error just increase this number :D
mask_hi = np.logical_and(data_hi[:,1]>astar_hi-ainterval_hi, data_hi[:,1]<astar_hi+ainterval_hi)
# 1 is a column
dataprime_hi = data_hi[mask_hi]

condition_hi=np.zeros(np.shape(dataprime_hi)[0])
for i in range(0,np.shape(dataprime_hi)[0]-1):
    condition_hi[i]=int(np.array_equal(dataprime_hi[i,0],dataprime_hi[i+1,0]))
#0 is k
klistinitial_hi=np.zeros(np.shape(dataprime_hi)[0]);
j=0;
for i in range (0,np.shape(dataprime_hi)[0]-1):
    if (condition_hi[i]==0):
        klistinitial_hi[j]=dataprime_hi[i-1,0]
        j+=1;

klist_hi = klistinitial_hi[klistinitial_hi!=0]
# klist_hi

dataprime_separated_hi = np.zeros((np.shape(klist_hi)[0],np.shape(dataprime_hi)[0],Num_columns))
for l,p in enumerate(klist_hi):
    w = np.shape(dataprime_hi[dataprime_hi[:,0]==p])[0]
    dataprime_separated_hi[l,:w,:] = dataprime_hi[dataprime_hi[:,0]==p]
#     print("separated",dataprime_separated)
# np.shape(dataprime_separated_hi)
hiclass_cs0_fin=np.zeros((np.shape(klist_hi)[0],Num_columns)); # the final file for the fiels are initialized, klist is the list ok k without repitition
# Transfer_kess=np.zeros((np.shape(klist)[0],8)); # the final file for the fiels are initialized, klist is the list ok k without repitition
# Gev_cs0=np.zeros((np.shape(klist_hi)[0],3)); # the Gev appropriate file                                             #It must be in Newtonian gauge

for i in range(np.shape(klist_hi)[0]):
# #     print(i)
    Vec_x_hi = dataprime_separated_hi[i,dataprime_separated_hi[i,:,0]!=0,:]
    interp_psi =interp1d(Vec_x_hi[:,1],Vec_x_hi[:,2])
    interp_alpha =interp1d(Vec_x_hi[:,1],Vec_x_hi[:,3])
    interp_alpha_prime =interp1d(Vec_x_hi[:,1],Vec_x_hi[:,4])
    interp_hubble =interp1d(Vec_x_hi[:,1],Vec_x_hi[:,5])

    hiclass_cs0_fin[i,0]=klist_hi[i]
    hiclass_cs0_fin[i,1]=interp_psi(astar_hi)
    hiclass_cs0_fin[i,2]=interp_alpha(astar_hi);
    hiclass_cs0_fin[i,3]=interp_alpha_prime(astar_hi);
    hiclass_cs0_fin[i,4]=interp_hubble(astar_hi);
    hiclass_cs0_fin[i,5]=astar_hi;
    
#     Gev_cs0[i,0]=hiclass_cs0_fin[i,0];
#     Gev_cs0[i,1]=hiclass_cs0_fin[i,1];
#     Gev_cs0[i,2]=hiclass_cs0_fin[i,2];
    
Result=hiclass_cs0_fin[::-1,:];
np.savetxt('class_synch_cs2z0.dat', Result, fmt='%.12e', delimiter='\t', newline='\n')
