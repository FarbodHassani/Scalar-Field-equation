# %%
import numpy as np
import matplotlib.pylab as plt
from scipy.interpolate import interp1d

# %% [markdown]
# # d_total comparison (Class has a bug)- d_tot in hi-class goes wrong after adding output transfer function!

# %%
file_hiclass=np.loadtxt("/Users/farbod/Packages/hi_class/output/hi_kess_tk.dat")
file_class=np.loadtxt("/Users/farbod/Packages/class_public/output/class_kess_tk.dat")
file_classSyn=np.loadtxt("/Users/farbod/Packages/class_public/output/class_kess_tkSync.dat")
file_classSynz100=np.loadtxt("/Users/farbod/Packages/class_public/output/class_kess_z2_tk.dat")

Myfield=np.loadtxt("/Users/farbod/Packages/hi_class/JupyterNotebook/New_kessence.txt")
# lcdm=np.loadtxt("/Users/farbod/Packages/class_public/output/lcdm_tk.dat")
file_hiclass_org=np.loadtxt("/Users/farbod/Packages/hi_class/output/hi_kess_tk_org.dat")

# file_hiclass_2 = file_hiclass[file_hiclass[:,0].argsort()] # sorted in redshift
# file_hiclass=file_hiclass_2[np.logical_and(file_hiclass_2[:,0] < 0.09965908,file_hiclass_2[:,0] > 0.09965908-0.05),:];
# file_hiclass=sort_checkI[np.logical_and(sort_checkI[:,1]> 1./(101.),sort_checkI[:,1]< 1./(1.9)),:]
# sort_check=sort_checkI[sort_checkI[:,1]> 1./(101.),:]
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-14-b6b6f27c8fbc> in <module>()
#       6 Myfield=np.loadtxt("/Users/farbod/Packages/hi_class/JupyterNotebook/New_kessence.txt")
#       7 # lcdm=np.loadtxt("/Users/farbod/Packages/class_public/output/lcdm_tk.dat")
# ----> 8 file_hiclass_org=np.loadtxt("/Users/farbod/Packages/hi_class/output/hi_kess_tk_org.dat")
#       9
#      10 # file_hiclass_2 = file_hiclass[file_hiclass[:,0].argsort()] # sorted in redshift
#
# /Users/farbod/anaconda2/lib/python2.7/site-packages/numpy/lib/npyio.pyc in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     801                 fh = iter(bz2.BZ2File(fname))
#     802             elif sys.version_info[0] == 2:
# --> 803                 fh = iter(open(fname, 'U'))
#     804             else:
#     805                 fh = iter(open(fname))
#
# ...

# %%
# plt.plot(file_hiclass[:,0],np.abs(file_hiclass[:,6]),color="red",label=r"hi-class T_{tot},w_0=-0.9,cs=1, z=0")
plt.plot(file_class[:,0],(file_class[:,6]),color=r"black",label="Class, T_{tot},w_0=-0.9,cs=1, z=0")
# plt.plot(lcdm[:,0],np.abs(lcdm[:,5]),color="Blue",label=r"lcdm, T_{tot}, z=0")
plt.plot(file_hiclass[:,0],(file_hiclass[:,6]),color="red",label=r"hi-class T_{tot},w_0=-0.9,cs=1, z=0")
plt.plot(file_hiclass_org[:,0],(file_hiclass_org[:,5]),color="Blue",label=r"hi-class T_{tot},w_0=-0.9,cs=1, z=0")
# plt.plot(file_class[:,0],(file_class[:,6]),color=r"black",label="Class, T_{tot},w_0=-0.9,cs=1, z=0")
# plt.plot(lcdm[:,0],(lcdm[:,5]),color="Blue",label=r"lcdm, T_{tot}, z=0")


# plt.plot(file_hiclass[:,0],file_hiclass[:,6]/file_class[:,6],color="red",label=r"hi-class T_{tot},w_0=-0.9,cs=1, z=0")

plt.legend(bbox_to_anchor=(0., 1.21, 1., .102), loc=1,ncol=1, mode="expand", borderaxespad=0.)
plt.xscale('log')
# plt.yscale('log')

plt.xlabel("k[h/Mpc]")
plt.ylabel("$T_{dtot}$")
plt.savefig('Bug_class_hiclass.jpg',bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-cbcca777fc6f> in <module>()
#       3 # plt.plot(lcdm[:,0],np.abs(lcdm[:,5]),color="Blue",label=r"lcdm, T_{tot}, z=0")
#       4 plt.plot(file_hiclass[:,0],(file_hiclass[:,6]),color="red",label=r"hi-class T_{tot},w_0=-0.9,cs=1, z=0")
# ----> 5 plt.plot(file_hiclass_org[:,0],(file_hiclass_org[:,5]),color="Blue",label=r"hi-class T_{tot},w_0=-0.9,cs=1, z=0")
#       6 # plt.plot(file_class[:,0],(file_class[:,6]),color=r"black",label="Class, T_{tot},w_0=-0.9,cs=1, z=0")
#       7 # plt.plot(lcdm[:,0],(lcdm[:,5]),color="Blue",label=r"lcdm, T_{tot}, z=0")
#
# NameError: name 'file_hiclass_org' is not defined

# %% [markdown]
# # hi-class d_tot gets very small  after introducing d_smg in output transfer function! why?!

# %%
plt.plot(file_hiclass[:,0],file_hiclass[:,6],color="red",label="hi-class T_tot,w_0=-0.9,cs=1, z=0")
# plt.plot(file_class[:,0],file_class[:,6],color="black",label="Class, T_tot,w_0=-0.9,cs=1, z=0")
# plt.plot(lcdm[:,0],lcdm[:,5],color="Blue",label="lcdm, T_tot, z=0")
plt.legend(bbox_to_anchor=(0., 1.01, 1., .102), loc=1,ncol=1, mode="expand", borderaxespad=0.)
# plt.xscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel("$T_{dtot}$")
plt.savefig('Kessence-dtot_hi.jpg',bbox_inches='tight')
plt.show()

# %% [markdown]
# # How about the field "fld" and "smg" transfer functions?!

# %%
plt.plot(file_hiclass[:,0],file_hiclass[:,4],color="black",label="hi-class T_smg,w_0=-0.9,cs=1, z=0")
plt.plot(file_classNew[:,0],file_classNew[:,4],color="red",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")
plt.plot(file_classSyn[:,0],file_classSyn[:,4],color="Blue",label="Class_Sync, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(Myfield[:,0],Myfield[:,3],color="Green",label="Class_Sync, T_fld,w_0=-0.9,cs=1, z=0")

# plt.plot(Transfer_kess[:,0],Transfer_kess[:,2],color="Blue",label="hi-class, direct smg, z=0")
plt.legend(bbox_to_anchor=(0., 1.31, 1., .102), loc=1,ncol=1, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel("$T$")
# plt.ylim(-1.,0.22)
plt.savefig('Kessence-smgfld_comp.jpg',bbox_inches='tight')
plt.show()

# %%
# plt.plot(file_hiclass[:,0],file_hiclass[:,4],color="black",label="hi-class T_smg,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classNew[:,0],file_classNew[:,4],color="red",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")
plt.plot(file_classSyn[:,0],file_classSyn[:,4],color="red",label="Class_Sync_z=0, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(Myfield[:,0],Myfield[:,3]*Myfield[:,0]/(0.67)/(2*3.1415**2*np.sqrt(2.19*10**-9.)*(Myfield[:,0]/(0.05/0.67))**((0.96-1)/2.)),color="Green",label="MyResult_z100, T_fld,w_0=-0.9,cs=1, z=0")
plt.plot(file_classSynz100[:,0],file_classSynz100[:,4],color="Blue",label="Class_Sync_z=100, T_fld,w_0=-0.9,cs=1, z=0")
plt.plot(Myfield[:,0],Myfield[:,3]/(3.1415*(Myfield[:,0]/(0.05))**(0.96-1)),color="Green",label="MyResult_z100, T_fld,w_0=-0.9,cs=1, z=0")

# Myfield[:111,0]**3
# plt.plot(Transfer_kess[:,0],Transfer_kess[:,2],color="Blue",label="hi-class, direct smg, z=0")
plt.legend(bbox_to_anchor=(0., 1.31, 1., .102), loc=1,ncol=1, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel("$T$")
# plt.ylim(-1.,0.22)
# plt.savefig('Kessence-smgfld_comp.jpg',bbox_inches='tight')
plt.show()

# %%
# plt.plot(file_hiclass[:,0],file_hiclass[:,4],color="black",label="hi-class T_smg,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classNew[:,0],file_classNew[:,4],color="red",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")
plt.plot(Myfield[:,0],np.sqrt(2.19*10**-9.)*(Myfield[:,0]/(0.05/0.67))**((0.96-1)/2.),color="Green",label="MyResult_z100, T_fld,w_0=-0.9,cs=1, z=0")

# Myfield[:111,0]**3
# plt.plot(Transfer_kess[:,0],Transfer_kess[:,2],color="Blue",label="hi-class, direct smg, z=0")
plt.legend(bbox_to_anchor=(0., 1.31, 1., .102), loc=1,ncol=1, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel("$T$")
# plt.ylim(-1.,0.22)
# plt.savefig('Kessence-smgfld_comp.jpg',bbox_inches='tight')
plt.show()

# %%
np.sqrt(2.19*10**-9.)
# Out:
# 4.6797435827190363e-05

# %%
# file_hiclassz0=np.loadtxt("./New_kessencez0.txt")
# file_hiclassz100=np.loadtxt("./New_kessencez100.txt")
# file_hiclassz0=np.loadtxt("./New_kessencez0_.txt")
New_kessencezrho_=np.loadtxt("./New_kessencezrho1.txt")
New_kessencezrho2=np.loadtxt("./New_kessencezrho2.txt")
rho_T=np.loadtxt("./New_kessencezrho_New.txt")

# file_class=np.loadtxt("/Users/farbod/Packages/class_public/output/class_kess_tk.dat")
# file_classSyn=np.loadtxt("/Users/farbod/Packages/class_public/output/class_kess_tkSync.dat")
# MySync=file_hiclassz0Plus-(file_hiclassz0Plus-file_hiclassz0)/2.

# %%
# plt.plot(file_hiclass[:,0],file_hiclass[:,4],color="black",label="hi-class T_smg,w_0=-0.9,cs=1, z=0")
plt.plot(file_classNew[:,0],file_classNew[:,4],color="red",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")
plt.plot(rho_T[:,0],rho_T[:,2],color="Green",label="MyResult_Newtonian, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(New_kessencezrho_[:,0],New_kessencezrho_[:,3],color="Magenta",label="MyResult_z=0_Newtonian+, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(New_kessencezrho2[:,0],New_kessencezrho2[:,2],color="blue",label="Class Synch, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classNew[:,0],-file_classNew[:,0]**-1*np.sqrt(10*9)*file_classNew[:,4],color="red",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_hiclassz0Plus[:,0],file_hiclassz0Plus[:,2],color="Blue",label="MyResult_Newtonina, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(MySync[:,0],MySync[:,2],color="Red",label="My sync-_z=0, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(New_kessencezrho2[:,0],New_kessencezrho2[:,2],color="Black",label="Class 2, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classNew[:,0],file_classNew[:,4],color="red",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")
plt.plot(file_classSyn[:,0],file_classSyn[:,4],color="Blue",label="Class_Sync, T_fld,w_0=-0.9,cs=1, z=0")
# MyNewt# plt.plot(Transfer_kess[:,0],Transfer_kess[:,2],color="Blue",label="hi-class, direct smg, z=0")
plt.legend(bbox_to_anchor=(0., 1.31, 1., .102), loc=1,ncol=1, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel("$T$")
# plt.ylim(-1.,0.22)
# plt.savefig('Kessence-smgfld_comp.jpg',bbox_inches='tight')
plt.show()

# %%
# plt.plot(file_hiclass[:,0],file_hiclass[:,4],color="black",label="hi-class T_smg,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classNew[:,0],file_classNew[:,4],color="red",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")
plt.plot(file_hiclassz0[:,0],file_hiclassz0[:,2],color="Green",label="MyResult_z=0_Newtonian+, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_hiclassz100[:,0],file_hiclassz100[:,2],color="Black",label="MyResult_z=10, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classNew[:,0],-file_classNew[:,0]**-1*np.sqrt(10*9)*file_classNew[:,4],color="red",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")
plt.plot(file_hiclassz0Plus[:,0],file_hiclassz0Plus[:,2],color="Blue",label="MyResult_Newtonina, T_fld,w_0=-0.9,cs=1, z=0")
plt.plot(MySync[:,0],MySync[:,2],color="Red",label="My sync-_z=0, T_fld,w_0=-0.9,cs=1, z=0")

MyNewt# plt.plot(Transfer_kess[:,0],Transfer_kess[:,2],color="Blue",label="hi-class, direct smg, z=0")
plt.legend(bbox_to_anchor=(0., 1.31, 1., .102), loc=1,ncol=1, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel("$T$")
# plt.ylim(-1.,0.22)
# plt.savefig('Kessence-smgfld_comp.jpg',bbox_inches='tight')
plt.show()

# %%
# plt.plot(file_hiclass[:,0],file_hiclass[:,4],color="black",label="hi-class T_smg,w_0=-0.9,cs=1, z=0")
plt.plot(file_classNew[:,0],file_classNew[:,4],color="red",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_hiclassz0[:,0],file_hiclassz0[:,2],color="Green",label="MyResult_z=0, T_fld,w_0=-0.9,cs=1, z=0")
plt.plot(file_classSyn[:,0],file_classSyn[:,4],color="Blue",label="Class_Sync_z=9, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classSyn[:111,0],-file_classSyn[:111,0]**(-2)*file_classSyn[:111,4]/(file_hiclassz0[:111,2]),color="Blue",label="Class_Sync_z=9, T_fld,w_0=-0.9,cs=1, z=0")

# plt.plot(file_classNew[:,0],file_classNew[:,4],color="red",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")
# Myfield[:111,0]**3
# plt.plot(Transfer_kess[:,0],Transfer_kess[:,2],color="Blue",label="hi-class, direct smg, z=0")
plt.legend(bbox_to_anchor=(0., 1.31, 1., .102), loc=1,ncol=1, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel("$T$")
# plt.ylim(-1.,0.22)
# plt.savefig('Kessence-smgfld_comp.jpg',bbox_inches='tight')
plt.show()

# %%
# plt.plot(file_hiclass[:,0],file_hiclass[:,4],color="black",label="hi-class T_smg,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classNew[:,0],file_classNew[:,4],color="red",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_hiclassz0[:,0],file_hiclassz0[:,2],color="Green",label="MyResult_z=0, T_fld,w_0=-0.9,cs=1, z=0")
plt.plot(file_classSyn[:111,0],file_classSyn[:111,4],color="Blue",label="Class_Sync_z=9, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_hiclassz0Plus[:,0],file_hiclassz0Plus[:,2],color="Red",label="MyResult_z, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(MyNewt[:,0],MyNewt[:,2],color="Red",label="MyNewt_z=0, T_fld,w_0=-0.9,cs=1, z=0")
# MyNewt# plt.plot(Transfer_kess[:,0],Transfer_kess[:,2],color="Blue",label="hi-class, direct smg, z=0")
plt.legend(bbox_to_anchor=(0., 1.31, 1., .102), loc=1,ncol=1, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel("$T$")
# plt.ylim(-1.,0.22)
# plt.savefig('Kessence-smgfld_comp.jpg',bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-042a883cfc12> in <module>()
#       2 # plt.plot(file_classNew[:,0],file_classNew[:,4],color="red",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")
#       3 # plt.plot(file_hiclassz0[:,0],file_hiclassz0[:,2],color="Green",label="MyResult_z=0, T_fld,w_0=-0.9,cs=1, z=0")
# ----> 4 plt.plot(file_hiclassz100[:,0],file_hiclassz100[:,2],color="Black",label="MyResult_z=10, T_fld,w_0=-0.9,cs=1, z=0")
#       5 plt.plot(file_classSyn[:111,0],file_classSyn[:111,4],color="Blue",label="Class_Sync_z=9, T_fld,w_0=-0.9,cs=1, z=0")
#       6 # plt.plot(file_hiclassz0Plus[:,0],file_hiclassz0Plus[:,2],color="Red",label="MyResult_z, T_fld,w_0=-0.9,cs=1, z=0")
#
# NameError: name 'file_hiclassz100' is not defined

# %%
plt.plot(file_hiclassz0[:,0],(file_hiclassz0Plus[:111,2]-file_hiclassz0[:111,2])/2.,color="Green",label="MyResult_z=0_Newtonian+, T_fld,w_0=-0.9,cs=1, z=0")
plt.plot(file_classNew[:111,0],-file_classNew[:111,4]+file_classSyn[:111,4],color="red",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")

plt.legend(bbox_to_anchor=(0., 1.11, 1., .102), loc=1,ncol=1, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale('log')

plt.xlabel("k[h/Mpc]")
plt.ylabel("$T$")
# plt.ylim(-1.,0.22)
# plt.savefig('Kessence-smgfld_comp.jpg',bbox_inches='tight')
plt.show()

# %%
# plt.plot(file_hiclassz0[:111,0],-(file_hiclassz0[:111,2]),color="Green",label="MyResult_z=0_Newtonian+, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classNew[:111,0],-file_classNew[:111,4]+file_classSyn[:111,4],color="red",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")
plt.plot(file_classNew[:,0],(file_classNew[:,4]),color="red",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")

plt.legend(bbox_to_anchor=(0., 1.11, 1., .102), loc=1,ncol=1, mode="expand", borderaxespad=0.)
plt.xscale('log')
# plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel("$T$")
# plt.ylim(-1.,0.22)
# plt.savefig('Kessence-smgfld_comp.jpg',bbox_inches='tight')
plt.show()

# %%
plt.plot(file_classSyn[:,0],file_classSyn[:,4]*10**(4.3),color="Blue",label="Class_Sync_z=9, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classNew[:111,0],-file_classNew[:111,4]+file_classSyn[:111,4],color="red",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classNew[:,0],-(file_classNew[:,4]),color="red",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")
plt.plot(MySync[:,0],MySync[:,2],color="Red",label="My sync-_z=0, T_fld,w_0=-0.9,cs=1, z=0")

plt.legend(bbox_to_anchor=(0., 1.11, 1., .102), loc=1,ncol=1, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel("$T$")
# plt.ylim(-1.,0.22)
# plt.savefig('Kessence-smgfld_comp.jpg',bbox_inches='tight')
plt.show()

# %%
plt.plot(file_classSyn[:111,0],file_classSyn[:111,4]/MySync[:111,2],color="Blue",label="Class_Sync_z=9, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classNew[:111,0],-file_classNew[:111,4]+file_classSyn[:111,4],color="red",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classNew[:,0],-(file_classNew[:,4]),color="red",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(MySync[:,0],MySync[:,2],color="Red",label="My sync-_z=0, T_fld,w_0=-0.9,cs=1, z=0")

plt.legend(bbox_to_anchor=(0., 1.11, 1., .102), loc=1,ncol=1, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel("$T$")
# plt.ylim(-1.,0.22)
# plt.savefig('Kessence-smgfld_comp.jpg',bbox_inches='tight')
plt.show()

# %%
# file_hiclass=np.loadtxt("/Users/farbod/Packages/hi_class/output/hi_kess_tk.dat")
class_new=np.loadtxt("/Users/farbod/Packages/class_public/output/class_kess_z1_tk_new.dat")
class_syn=np.loadtxt("/Users/farbod/Packages/class_public/output/class_kess_z1_tk_Synch.dat")
# file_classSynz100=np.loadtxt("/Users/farbod/Packages/class_public/output/class_kess_z2_tk.dat")
New_kessencezrho_=np.loadtxt("./New_kessencezrho1.txt")
New_kessencezrho2=np.loadtxt("./New_kessencezrho2.txt")
rho_T=np.loadtxt("./New_kessencezrho_New.txt")
# Myfield=np.loadtxt("/Users/farbod/Packages/hi_class/JupyterNotebook/New_kessence.txt")
# lcdm=np.loadtxt("/Users/farbod/Packages/class_public/output/lcdm_tk.dat")
# file_hiclass_org=np.loadtxt("/Users/farbod/Packages/hi_class/output/hi_kess_tk_org.dat")

# %%
plt.plot(class_new[:,0],class_new[:,4],color="Blue",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")
plt.plot(class_syn[:,0],class_syn[:,4],color="Red",label="Class_Sync, T_fld,w_0=-0.9,cs=1, z=0")
plt.plot(rho_T[:,0],rho_T[:,2],color="green",label="hi-class- Sync, T_fld,w_0=-0.9,cs=1, z=0")

# plt.plot(file_classNew[:111,0],-file_classNew[:111,4]+file_classSyn[:111,4],color="red",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classNew[:,0],-(file_classNew[:,4]),color="red",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(MySync[:,0],MySync[:,2],color="Red",label="My sync-_z=0, T_fld,w_0=-0.9,cs=1, z=0")

plt.legend(bbox_to_anchor=(0., 1.21, 1., .102), loc=1,ncol=1, mode="expand", borderaxespad=0.)
plt.xscale('log')
# plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel("$T$")
# plt.ylim(-1.,0.22)
# plt.savefig('Kessence-smgfld_comp.jpg',bbox_inches='tight')
plt.show()

# %%
h=0.70
# plt.plot(rho_T[:,0],rho_T[:,2]-10**-4.33*rho_T[:,6],color="green",label="hi-class- Sync, T_fld,w_0=-0.9,cs=1, z=0")
# # plt.plot(rho_T[:,0],rho_T[:,2],color="green",label="hi-class- Sync, T_fld,w_0=-0.9,cs=1, z=0")
plt.plot(class_new[:,0],-(class_new[:,4]-class_syn[:,4])/(0.3*2.25*10**(-4)),color="Blue",label=r"$\alpha=\frac{T_{Syn}-T_{Newt}}{3(1+w)\mathcal{H}}$"+"  from class, w_0=-0.9, cs=1, z=0")
# plt.plot(class_syn[:,0],class_syn[:,4],color="Red",label="Class_Sync, T_fld,w_0=-0.9,cs=1, z=0")
plt.plot(rho_T[:,0]/h,(rho_T[:,6]),color="red",label=r"$\alpha$"+"  from hiclass, w_0=-0.9, cs=1, z=0")
# plt.plot(class_syn[:,0],class_new[:,4]-class_syn[:,4],color="Red",label="Class_Sync, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(rho_T[:,0],rho_T[:,6]/(-file_classNew[:111,4]+file_classSyn[:111,4]),color="green",label="hi-class- alpha, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_hiclassz0[:,0],(file_hiclassz0Plus[:111,2]-file_hiclassz0[:111,2])/2.,color="Blue",label="MyResult_z=0_Newtonian+, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classNew[:111,0],-file_classNew[:111,4]+file_classSyn[:111,4],color="red",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")

plt.legend(bbox_to_anchor=(0., 1.11, 1., .102), loc=1,ncol=1, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel(r"$\alpha$")
# plt.ylim(-1.,0.22)
plt.savefig('alpha_class.jpg',bbox_inches='tight')
plt.show()

# %%
Calss_1=-(class_new[:111,4]-class_syn[:111,4])/(0.3*2.25*10**(-4))
hi_class=rho_T[:111,6]
Error=(Calss_1-hi_class)/(hi_class)
# plt.plot(rho_T[:,0],rho_T[:,2]-10**-4.33*rho_T[:,6],color="green",label="hi-class- Sync, T_fld,w_0=-0.9,cs=1, z=0")
# # plt.plot(rho_T[:,0],rho_T[:,2],color="green",label="hi-class- Sync, T_fld,w_0=-0.9,cs=1, z=0")
plt.plot(class_new[:111,0],Error,color="Blue")
# plt.plot(class_syn[:,0],class_syn[:,4],color="Red",label="Class_Sync, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(rho_T[:,0],(rho_T[:,6]),color="green",label="hi-class- alpha, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(class_syn[:,0],class_new[:,4]-class_syn[:,4],color="Red",label="Class_Sync, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(rho_T[:,0],rho_T[:,6]/(-file_classNew[:111,4]+file_classSyn[:111,4]),color="green",label="hi-class- alpha, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_hiclassz0[:,0],(file_hiclassz0Plus[:111,2]-file_hiclassz0[:111,2])/2.,color="Blue",label="MyResult_z=0_Newtonian+, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classNew[:111,0],-file_classNew[:111,4]+file_classSyn[:111,4],color="red",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")

plt.legend(bbox_to_anchor=(0., 1.01, 1., .102), loc=1,ncol=1, mode="expand", borderaxespad=0.)
plt.xscale('log')
# plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel(r"$(\alpha_{class} -\alpha_{hiclass})/\alpha_{hiclass}$")
# plt.ylim(-1.,0.22)
plt.savefig('alphaerror.jpg',bbox_inches='tight')
plt.show()

# %% [markdown]
# #####

# %%
lass_new=np.loadtxt("/Users/farbod/Packages/class_public/output/class_kess_z1_tk_new.dat")
class_syn=np.loadtxt("/Users/farbod/Packages/class_public/output/class_kess_z1_tk_Synch.dat")
# file_classSynz100=np.loadtxt("/Users/farbod/Packages/class_public/output/class_kess_z2_tk.dat")
# New_kessencezrho_=np.loadtxt("./New_kessencezrho1.txt")
# New_kessencezrho2=np.loadtxt("./New_kessencezrho2.txt")
data_hi_field=np.loadtxt("./Kess_data.txt")
data_hi_field10=np.loadtxt("./Kess_dataz10.txt")
data_hi_field50=np.loadtxt("./Kess_dataz50.txt")
data_hi_field100=np.loadtxt("./Kess_dataz100.txt")
data_hi_field_gev=np.loadtxt("./Kessz100_gevol_ini.txt")

# Myfield=np.loadtxt("/Users/farbod/Packages/hi_class/JupyterNcotebook/New_kessence.txt")
# lcdm=np.loadtxt("/Users/farbod/Packages/class_public/output/lcdm_tk.dat")
# file_hiclass_org=np.loadtxt("/Users/farbod/Packages/hi_class/output/hi_kess_tk_org.dat")

# %%
plt.plot(data_hi_field[:,0],data_hi_field[:,3],color="red",label="z=0")
plt.plot(data_hi_field10[:,0],data_hi_field10[:,3],color="blue",label="z=10")
plt.plot(data_hi_field50[:,0],data_hi_field50[:,3],color="green",label="z=50")
plt.plot(data_hi_field100[:,0],data_hi_field100[:,3],color="black",label="z=50")
# 
# # plt.plot(rho_T[:,0],rho_T[:,2],color="green",label="hi-class- Sync, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(class_syn[:,0],class_syn[:,4],color="Red",label="Class_Sync, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(rho_T[:,0],(rho_T[:,6]),color="green",label="hi-class- alpha, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(class_syn[:,0],class_new[:,4]-class_syn[:,4],color="Red",label="Class_Sync, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(rho_T[:,0],rho_T[:,6]/(-file_classNew[:111,4]+file_classSyn[:111,4]),color="green",label="hi-class- alpha, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_hiclassz0[:,0],(file_hiclassz0Plus[:111,2]-file_hiclassz0[:111,2])/2.,color="Blue",label="MyResult_z=0_Newtonian+, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classNew[:111,0],-file_classNew[:111,4]+file_classSyn[:111,4],color="red",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")
# plt.text(0.01, 2, r' w_0=-0.9,cs=1')
plt.legend(bbox_to_anchor=(0.65, 0.89, 0.35, .102), loc=1,ncol=1, fontsize=8, mode="expand", borderaxespad=0.)
plt.title( r"$w_0=-0.9$"+", "+r"$c_s^2=1$")
plt.xscale('log')
# plt.yscale('log')
plt.xlabel(r"$k[1/Mpc]$")
plt.ylabel(r"$\pi(t,k)/\delta_\mathcal{R}(\tau,k)$")
# plt.xlim(,0.22)
plt.savefig('pitransfer.jpg',bbox_inches='tight')
plt.show()

# %%
plt.plot(data_hi_field[:,0],data_hi_field[:,2],color="green",label="hi-class_Newt")
# # plt.plot(rho_T[:,0],rho_T[:,2],color="green",label="hi-class- Sync, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(data_hi[:111,0],Error,color="Blue")
# plt.plot(class_syn[:,0],class_syn[:,4],color="Red",label="Class_Sync, w_0=-0.9,cs=1, z=0")
# plt.plot(rho_T[:,0],(rho_T[:,6]),color="green",label="hi-class- alpha, T_fld,w_0=-0.9,cs=1, z=0")
plt.plot(class_new[:,0],class_new[:,4],color="Red",label="Class_Newt")
# plt.plot(rho_T[:,0],rho_T[:,6]/(-file_classNew[:111,4]+file_classSyn[:111,4]),color="green",label="hi-class- alpha, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_hiclassz0[:,0],(file_hiclassz0Plus[:111,2]-file_hiclassz0[:111,2])/2.,color="Blue",label="MyResult_z=0_Newtonian+, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classNew[:111,0],-file_classNew[:111,4]+file_classSyn[:111,4],color="red",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")

# # plt.plot(rho_T[:,0],rho_T[:,2],color="green",label="hi-class- Sync, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(class_syn[:,0],class_syn[:,4],color="Red",label="Class_Sync, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(rho_T[:,0],(rho_T[:,6]),color="green",label="hi-class- alpha, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(class_syn[:,0],class_new[:,4]-class_syn[:,4],color="Red",label="Class_Sync, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(rho_T[:,0],rho_T[:,6]/(-file_classNew[:111,4]+file_classSyn[:111,4]),color="green",label="hi-class- alpha, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_hiclassz0[:,0],(file_hiclassz0Plus[:111,2]-file_hiclassz0[:111,2])/2.,color="Blue",label="MyResult_z=0_Newtonian+, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classNew[:111,0],-file_classNew[:111,4]+file_classSyn[:111,4],color="red",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")
# plt.text(0.01, 2, r' w_0=-0.9,cs=1')
plt.legend(bbox_to_anchor=(0.65, 0.7, 0.35, .102), loc=1,ncol=1, fontsize=8, mode="expand", borderaxespad=0.)
plt.title( r"$w_0=-0.9$"+", "+r"$c_s^2=1$"+", $z=0$")
plt.xscale('log')
# plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel(r"$\delta(t,k)/\delta_\mathcal{R}(\tau,k)$")
# plt.xlim(,0.22)
plt.savefig('newt_comp.jpg',bbox_inches='tight')
plt.show()

# %%
plt.plot(data_hi_field[:,0],data_hi_field[:,2]+data_hi_field[:,6]*(0.3*2.25*10**(-4)),color="green",label="hi-class_Sync")
# # plt.plot(rho_T[:,0],rho_T[:,2],color="green",label="hi-class- Sync, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(data_hi[:111,0],Error,color="Blue")
plt.plot(class_syn[:,0],class_syn[:,4],color="Red",label="Class_Sync")
# plt.plot(rho_T[:,0],(rho_T[:,6]),color="green",label="hi-class- alpha, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(class_new[:,0],class_new[:,4],color="Red",label="Class_Sync, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(rho_T[:,0],rho_T[:,6]/(-file_classNew[:111,4]+file_classSyn[:111,4]),color="green",label="hi-class- alpha, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_hiclassz0[:,0],(file_hiclassz0Plus[:111,2]-file_hiclassz0[:111,2])/2.,color="Blue",label="MyResult_z=0_Newtonian+, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classNew[:111,0],-file_classNew[:111,4]+file_classSyn[:111,4],color="red",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")

plt.legend(bbox_to_anchor=(0.65, 0.9, 0.35, .102), loc=1,ncol=1, fontsize=8, mode="expand", borderaxespad=0.)
plt.title( r"$w_0=-0.9$"+", "+r"$c_s^2=1$"+", $z=0$")
plt.xscale('log')
plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel(r"$\delta(t,k)/\delta_\mathcal{R}(\tau,k)$")
# plt.ylim(-0.16,0.01)
plt.savefig('sync_comp.jpg',bbox_inches='tight')
plt.show()
# (0.3*2.25*10**(-4))

# %%
# class_alph=np.loadtxt("/Users/farbod/Packages/class_public/output/alpha_class.dat")
# hi_alph=np.loadtxt("./../output/alpha_hi.dat")
camb_file=np.loadtxt("./Kesse__cache_PiSolution.dat")

# %%
np.shape(camb_file)
# Out:
# (84898, 6)

# %%
data_camb = camb_file
# print(np.shape(data))
# print(data_class[:,1].max(),data_class[:,1].min())

astar=1. # z=0, desired redshift
ainterval=0.01
mask = np.logical_and(data_camb[:,0]>astar-ainterval, data_camb[:,0]<astar+ainterval)
# print (mask)
dataprime = data_camb[mask]
# print(dataprime)
# print(np.shape(dataprime))
# dataprime[:100,:]
condition=np.zeros(np.shape(dataprime)[0])
# np.shape(dataprime)[0]
for i in range(0,np.shape(dataprime)[0]-1):
#     consition[ii] =np.array_equal(dataprime[i,0],dataprime[li+1,0])
    condition[i]=int(np.array_equal(dataprime[i,0],dataprime[i+1,0]))
# print(condition[:200])

klistinitial=np.zeros(np.shape(dataprime)[0]);
j=0;
for i in range (0,np.shape(dataprime)[0]-1):
    if (condition[i]==0):
        klistinitial[j]=dataprime[i-1,0]
        j+=1;

klist = klistinitial[klistinitial!=0]
# klist
dataprime_separated = np.zeros((np.shape(klist)[0],np.shape(dataprime)[0],6))
for l,p in enumerate(klist):
    w = np.shape(dataprime[dataprime[:,0]==p])[0]
    dataprime_separated[l,:w,:] = dataprime[dataprime[:,0]==p]
#     print("separated",dataprime_separated)

Final_file_cl=np.zeros((np.shape(klist)[0],3)); # the final file for the fiels are initialized, klist is the list ok k without repitition
# Transfer_kess=np.zeros((np.shape(klist)[0],8)); # the final file for the fiels are initialized, klist is the list ok k without repitition

for i in range(np.shape(klist)[0]):
#     print(i)
    Vec_x = dataprime_separated[i,dataprime_separated[i,:,0]!=0,:]
    alpha=interp1d(Vec_x[:,2], Vec_x[:,3])

#     interp_pi=interp1d(Vec_x[:,1],Vec_x[:,2], kind='cubic')
#     interp_pi_prime=interp1d(Vec_x[:,1], Vec_x[:,3], kind='cubic')
#     interp_pi_prime_prime=interp1d(Vec_x[:,1], Vec_x[:,4], kind='cubic')
    Final_file_cl[i,2]=klist[i]
    Final_file_cl[i,0]=astar
    Final_file_cl[i,3]=alpha(astar)
    #     interp_pi_prime_prime=interp1d(Vec_x[:,1], Vec_x[:,4])
# Final_file[:,2]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-ca8e7e2ab8ad> in <module>()
#      46     Final_file_cl[i,2]=klist[i]
#      47     Final_file_cl[i,0]=astar
# ---> 48     Final_file_cl[i,3]=alpha(astar)
#      49     #     interp_pi_prime_prime=interp1d(Vec_x[:,1], Vec_x[:,4])
#      50 # Final_file[:,2]
#
# /Users/farbod/anaconda2/lib/python2.7/site-packages/scipy/interpolate/polyint.pyc in __call__(self, x)
#      77         """
#      78         x, x_shape = self._prepare_x(x)
# ---> 79         y = self._evaluate(x)
#      80         return self._finish_y(y, x_shape)
#      81
#
# /Users/farbod/anaconda2/lib/python2.7/site-packages/scipy/interpolate/interpolate.pyc in _evaluate(self, x_new)
#     586         y_new = self._call(self, x_new)
#     587         if not self._extrapolate:
# ...

# %%
data_hi = class_alph
# print(np.shape(data_hi))
# print(data_hi[:,1].max(),data_hi[:,1].min())

astar_camb=1. # z=0, desired redshift
ainterval_hi=0.01
mask_hi = np.logical_and(data_hi[:,1]>astar_hi-ainterval_hi, data_hi[:,1]<astar_hi+ainterval_hi)
# print (mask)
dataprime_hi = data_hi[mask_hi]
# print(dataprime)
# print(np.shape(dataprime))

condition_hi=np.zeros(np.shape(dataprime_hi)[0])
for i in range(0,np.shape(dataprime_hi)[0]-1):
#     consition[ii] =np.array_equal(dataprime[i,0],dataprime[i+1,0])
    condition_hi[i]=int(np.array_equal(dataprime_hi[i,0],dataprime_hi[i+1,0]))
# print(condition[:200])

klistinitial_hi=np.zeros(np.shape(dataprime_hi)[0]);
j=0;
for i in range (0,np.shape(dataprime_hi)[0]-1):
    if (condition_hi[i]==0):
        klistinitial_hi[j]=dataprime_hi[i-1,0]
        j+=1;

klist_hi = klistinitial_hi[klistinitial_hi!=0]
# klist
dataprime_separated_hi = np.zeros((np.shape(klist_hi)[0],np.shape(dataprime_hi)[0],3))
for l,p in enumerate(klist_hi):
    w = np.shape(dataprime_hi[dataprime_hi[:,0]==p])[0]
    dataprime_separated_hi[l,:w,:] = dataprime_hi[dataprime_hi[:,0]==p]
#     print("separated",dataprime_separated)

Final_file_camb=np.zeros((np.shape(klist_hi)[0],3)); # the final file for the fiels are initialized, klist is the list ok k without repitition
# Transfer_kess=np.zeros((np.shape(klist)[0],8)); # the final file for the fiels are initialized, klist is the list ok k without repitition

for i in range(np.shape(klist_hi)[0]):
#     print(i)
    Vec_x_hi = dataprime_separated_hi[i,dataprime_separated_hi[i,:,0]!=0,:]
    pi_camb=interp1d(Vec_x_hi[:,1], Vec_x_hi[:,2])

#     interp_pi=interp1d(Vec_x[:,1],Vec_x[:,2], kind='cubic')
#     interp_pi_prime=interp1d(Vec_x[:,1], Vec_x[:,3], kind='cubic')
#     interp_pi_prime_prime=interp1d(Vec_x[:,1], Vec_x[:,4], kind='cubic')
    Final_file_camb[i,0]=klist_hi[i]
    Final_file_camb[i,1]=astar_camb
    Final_file_camb[i,2]=pi_camb(astar_camb)
    #     interp_pi_prime_prime=interp1d(Vec_x[:,1], Vec_x[:,4])
# Final_file[:,2]

# %%
lass_new=np.loadtxt("/Users/farbod/Packages/class_public/output/class_kess_z1_tk_new.dat")
class_syn=np.loadtxt("/Users/farbod/Packages/class_public/output/class_kess_z1_tk_Synch.dat")
# file_classSynz100=np.loadtxt("/Users/farbod/Packages/class_public/output/class_kess_z2_tk.dat")
# New_kessencezrho_=np.loadtxt("./New_kessencezrho1.txt")
# New_kessencezrho2=np.loadtxt("./New_kessencezrho2.txt")
data_hi_field=np.loadtxt("./Kess_data.txt")
data_hi_field10=np.loadtxt("./Kess_dataz10.txt")
data_hi_field50=np.loadtxt("./Kess_dataz50.txt")
data_hi_field100=np.loadtxt("./Kess_dataz100.txt")
data_hi_field_gev=np.loadtxt("./Kessz100_gevol_ini.txt")

# Myfield=np.loadtxt("/Users/farbod/Packages/hi_class/JupyterN

# %%
h=0.67
# Diff=(class_alph[:7546,1]-hi_alph[:7546,1])/hi_alph[:7546,1]
plt.plot(Final_file_camb[:,0],(Final_file_camb[:,2]),color="Blue",label=r"$\pi$"+"  from CAMB")
plt.plot(data_hi_field[:,0],data_hi_field[:,3],color="red",label="z=0")
# plt.plot(class_new[:,0],-(class_new[:,4]-class_syn[:,4])/(0.3*2.25*10**(-4)),color="green",label=r"$\alpha=\frac{T_{Syn}-T_{Newt}}{3(1+w)\mathcal{H}}$"+"  from class")
# plt.plot(class_syn[:,0],class_syn[:,4],color="Red",label="Class_Sync, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(rho_T[:,0],(rho_T[:,6]),color="red",label=r"$\alpha$"+"  from hiclass")
# plt.title( r"$w_0=-0.9$"+", "+r"$c_s^2=1$"+", $z=0$")

# # plt.plot(rho_T[:,0],rho_T[:,2],color="green",label="hi-class- Sync, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(data_hi[:111,0],Error,color="Blue")
# plt.plot(hi_alph[:,0],hi_alph[:,1],c7546olor="Red",label="Class_Sync, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(rho_T[:,0],(rho_T[:,6]),color="green",label="hi-class- alpha, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(class_new[:,0],class_new[:,4],color="Red",label="Class_Sync, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(rho_T[:,0],rho_T[:,6]/(-file_classNew[:111,4]+file_classSyn[:111,4]),color="green",label="hi-class- alpha, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_hiclassz0[:,0],(file_hiclassz0Plus[:111,2]-file_hiclassz0[:111,2])/2.,color="Blue",label="MyResult_z=0_Newtonian+, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classNew[:111,0],-file_classNew[:111,4]+file_classSyn[:111,4],color="red",label="Class_Newt, T_fld,w_0=-0.9,cs=1, z=0")

plt.legend(bbox_to_anchor=(0.65, 0.9, 0.35, .102), loc=1,ncol=1, fontsize=8, mode="expand", borderaxespad=0.)
plt.title( r"$w_0=-0.9$"+", "+r"$c_s^2=1$"+", $z=0$")

plt.xscale('log')
# plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel(r"$\alpha$")
# plt.ylim(-0.16,0.01)
plt.savefig('alpha_class.jpg',bbox_inches='tight')
plt.show()

# %%
np.shape(Final_file_cl)
# Out:
# (111, 3)

# %%
Diff=(class_alph[:7546,1]-hi_alph[:7546,1])/hi_alph[:7546,1]

# %%
Diff
# Out:
# array([  4.91467908e-06,   4.28730059e-06,  -2.82334429e-06, ...,
#          3.26528387e+01,   3.26832636e+01,   3.26543180e+01])
