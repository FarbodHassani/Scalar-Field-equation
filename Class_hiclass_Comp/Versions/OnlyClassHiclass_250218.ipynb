# %% [markdown]
# # Notebook for comparison beween hi-class and class and

# %%
import numpy as np
import matplotlib.pylab as plt
from scipy.interpolate import interp1d
from pylab import rcParams
tableau12 = [(0, 0, 0), (50, 0, 0), (0, 50, 0), (0, 0, 50),    
             (0, 50, 50), (50, 50, 0), (50, 0, 50), (50, 50, 50),    
             (100, 50, 50), (50, 100, 50), (50, 50, 100), (100, 100, 100)]    
  
# Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.    
for i in range(len(tableau12)):    
    r, g, b = tableau12[i]    
    tableau12[i] = (r / 255., g / 255., b / 255.) 
    
tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),    
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),    
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),    
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),    
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]    
  
# Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.    
for i in range(len(tableau20)):    
    r, g, b = tableau20[i]    
    tableau20[i] = (r / 255., g / 255., b / 255.)
# plt.style.available
plt.rcParams.update(plt.rcParamsDefault)

# plt.style.use('seaborn-paper')
plt.rcParams['font.serif'] = 'Ubuntu'

# %%
# hiclass kessence_IC_gevolution field files in different redshift
redshifts=["100"]
hiclass_cs6=[0 for i in range (np.shape(redshifts)[0])]
# for snap in range(np.shape(redshifts)[0]):
#     hiclass_cs6[snap]=np.loadtxt("./hi-Class/kessence_Allhiclass_cs0z"+redshifts(snap)+".dat")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-df19ebbd0ee4> in <module>()
#       3 hiclass_cs6=[0 for i in range (np.shape(redshifts)[0])]
#       4 for snap in range(np.shape(redshifts)[0]):
# ----> 5     hiclass_cs6[snap]=np.loadtxt("./hi-Class/kessence_Allhiclass_cs0z"+redshifts(snap)+".dat")
#
# TypeError: 'list' object is not callable

# %% [markdown]
# # Adding files

# %%
# hiclass kessence_IC_gevolution field files in different redshift
for i in range (4):
    hiclass_cs6_100=np.loadtxt("./hi-Class/kessence_Allhiclass_cs0z100.dat")
    hiclass_cs6_10=np.loadtxt("./hi-Class/kessence_Allhiclass_cs0z10.dat")
    hiclass_cs6_3=np.loadtxt("./hi-Class/kessence_Allhiclass_cs0z3.dat")
    hiclass_cs6_0=np.loadtxt("./hi-Class/kessence_Allhiclass_cs0z0.dat")

# hiclass kessence_IC_gevolution cs2=1.e-10 files in different redshift
hiclass_cs10_All_100=np.loadtxt("./hi-Class/kessence_Allhiclass_cs10z100.dat")
hiclass_cs10_All_10=np.loadtxt("./hi-Class/kessence_Allhiclass_cs10z10.dat")
hiclass_cs10_All_3=np.loadtxt("./hi-Class/kessence_Allhiclass_cs10z3.dat")
hiclass_cs10_All_0=np.loadtxt("./hi-Class/kessence_Allhiclass_cs10z0.dat")

# hiclass kessence_IC_gevolution cs2=1.e-2 files in different redshift
hiclass_cs2_All_100=np.loadtxt("./hi-Class/kessence_Allhiclass_cs2z100.dat")
hiclass_cs2_All_10=np.loadtxt("./hi-Class/kessence_Allhiclass_cs2z10.dat")
hiclass_cs2_All_3=np.loadtxt("./hi-Class/kessence_Allhiclass_cs2z3.dat")
hiclass_cs2_All_0=np.loadtxt("./hi-Class/kessence_Allhiclass_cs2z0.dat")


#Class output in synchronous and Newtonian gauge for comparison with hi-class results.
#Class output cs2=1.e-6
Class_newt_z100=np.loadtxt("./Class_Newt/class_kess_cs0_newt_z1_tk.dat")
Class_newt_z10=np.loadtxt("./Class_Newt/class_kess_cs0_newt_z2_tk.dat")
Class_newt_z3=np.loadtxt("./Class_Newt/class_kess_cs0_newt_z3_tk.dat")
Class_newt_z0=np.loadtxt("./Class_Newt/class_kess_cs0_newt_z4_tk.dat")

#Class output cs2=1.e-10
Class_newt_cs10_z100=np.loadtxt("./Class_Newt/class_kess_cs10_newt_z1_tk.dat")
Class_newt_cs10_z10=np.loadtxt("./Class_Newt/class_kess_cs10_newt_z2_tk.dat")
Class_newt_cs10_z3=np.loadtxt("./Class_Newt/class_kess_cs10_newt_z3_tk.dat")
Class_newt_cs10_z0=np.loadtxt("./Class_Newt/class_kess_cs10_newt_z4_tk.dat")

#Class output cs2=1.e-2
Class_newt_cs2_z100=np.loadtxt("./Class_Newt/class_kess_cs2_newt_z1_tk.dat")
Class_newt_cs2_z10=np.loadtxt("./Class_Newt/class_kess_cs2_newt_z2_tk.dat")
Class_newt_cs2_z3=np.loadtxt("./Class_Newt/class_kess_cs2_newt_z3_tk.dat")
Class_newt_cs2_z0=np.loadtxt("./Class_Newt/class_kess_cs2_newt_z4_tk.dat")

# Class Synchronous gauge cs2=1.e-2


# Class Synchronous gauge cs2=1.e-6
Class_synch_cs6_z100=np.loadtxt("./Class_Synch_cs6/class_kess_cs0_synch_z1_tk.dat")
Class_synch_cs6_z10=np.loadtxt("./Class_Synch_cs6/class_kess_cs0_synch_z2_tk.dat")
Class_synch_cs6_z3=np.loadtxt("./Class_Synch_cs6/class_kess_cs0_synch_z3_tk.dat")
Class_synch_cs6_z0=np.loadtxt("./Class_Synch_cs6/class_kess_cs0_synch_z4_tk.dat")

# Class Synchronous gauge cs2=1.e-10

#Alpha class cs2=1.e-6
Class_synch_cs6_z100_internal=
Class_synch_cs6_z10_internal=
Class_synch_cs6_z3_internal=
Class_synch_cs6_z0_interna=
# EFT_CAMB cs=1.e-2

# EFT_CAMB cs=1.e-6


# EFT_CAMB cs=1.e-10

# %% [markdown]
# # Phi comparison class and hiclass

# %%
# Columns: k ,pi_synch, pi'_synch, \alpha, \alpha', Psi
#Check the sound speed is the same!
#Run class with much smaller sound speed and see...

cs2=1.e-6;
w=-0.9;
h=0.67;
As=2.215*10.e-9;
ns=0.96;
kp=0.05/h;
Hubb=2.25e-4;



#Plot setting
plt.figure(figsize=(20,20))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)

#Plots z=100
plt.plot(Class_newt_z100[:,0]*h,Class_newt_z100[:,7],color=tableau12[0],linestyle='solid',lw=2.5,label=r"$\Phi_{Newt}$ class z=100 ")
plt.plot(hiclass_All_100[:,0],hiclass_All_100[:,5],color=tableau20[5],linestyle='dashed',lw=2.5,label=r"$\Phi_{Newt}$ hiclass z=100 ")

#Plots z=10
plt.plot(Class_newt_z10[:,0]*h,Class_newt_z10[:,7],color=tableau12[3],linestyle='solid',lw=2.5,label=r"$\Phi_{Newt}$ class z=10 ")
plt.plot(hiclass_All_10[:,0],hiclass_All_10[:,5],color=tableau20[8],linestyle='dashed',lw=2.5,label=r"$\Phi_{Newt}$ hiclass z=10 ")

# #Plots z=3
plt.plot(Class_newt_z3[:,0]*h,Class_newt_z3[:,7],color=tableau12[11],linestyle='solid',lw=2.5,label=r"$\Phi_{Newt}$ class z=3 ")
plt.plot(hiclass_All_3[:,0],hiclass_All_3[:,5],color=tableau20[17],linestyle='dashed',lw=2.5,label=r"$\Phi_{Newt}$ hiclass z=3 ")

# # #Plots z=0
plt.plot(Class_newt_z0[:,0]*h,Class_newt_z0[:,7],color=tableau12[9],linestyle='solid',lw=2.5,label=r"$\Phi_{Newt}$ class z=0 ")
plt.plot(hiclass_All_0[:,0],hiclass_All_0[:,5],color=tableau20[12],linestyle='dashed',lw=2.5,label=r"$\Phi_{Newt}$ hiclass z=0 ")

# Show the plots and save
plt.legend(bbox_to_anchor=(0.8, 0.90, 0.2, .102), loc=1,ncol=1,fontsize=15, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale("log")
# plt.yscale('log')
plt.xlabel("k[h/Mpc]",fontsize=20)
plt.ylabel(r"$\Phi/\mathcal{R}$",fontsize=20)
plt.xlim(0.0001,5)
# plt.ylim(1.e-27,1.e-1)
# plt.savefig('pi_kcomparison.jpg', format='eps', dpi=1000)
plt.show()

# %% [markdown]
# # Class-hiclass and \pi in Newtonian gauge via formula

# %%
# Columns: k ,pi_synch, pi'_synch, \alpha, \alpha', Psi
#Check the sound speed is the same!
#Run class with much smaller sound speed and see...

cs2=1.e-6;
w=-0.9;
h=0.67;
As=2.215*10.e-9;
ns=0.96;
kp=0.05/h;
Hubb=2.25e-4;

# \pi in Newtonian in class : -\theta/k^2
pi_class_Newt_cs0_z100=Class_newt_z100[:,12]/((Class_newt_z100[:,0]*h)**2);
pi_class_Newt_cs0_z10=Class_newt_z10[:,12]/((Class_newt_z10[:,0]*h)**2);
pi_class_Newt_cs0_z3=Class_newt_z3[:,12]/((Class_newt_z3[:,0]*h)**2);
pi_class_Newt_cs0_z0=Class_newt_z0[:,12]/((Class_newt_z0[:,0]*h)**2);
# \pi in Newtonian in class cs2=1e-10 : -\theta/k^2
pi_class_Newt_cs10_z100=Class_newt_cs10_z100[:,12]/((Class_newt_cs10_z100[:,0]*h)**2);
pi_class_Newt_cs10_z10=Class_newt_cs10_z10[:,12]/((Class_newt_cs10_z10[:,0]*h)**2);
pi_class_Newt_cs10_z3=Class_newt_cs10_z3[:,12]/((Class_newt_cs10_z3[:,0]*h)**2);
pi_class_Newt_cs10_z0=Class_newt_cs10_z0[:,12]/((Class_newt_cs10_z0[:,0]*h)**2);
# \pi in Newtonian in class cs2=1e-2 : -\theta/k^2
pi_class_Newt_cs2_z100=Class_newt_cs2_z100[:,12]/((Class_newt_cs2_z100[:,0]*h)**2);
pi_class_Newt_cs2_z10=Class_newt_cs2_z10[:,12]/((Class_newt_cs2_z10[:,0]*h)**2);
pi_class_Newt_cs2_z3=Class_newt_cs2_z3[:,12]/((Class_newt_cs2_z3[:,0]*h)**2);
pi_class_Newt_cs2_z0=Class_newt_cs2_z0[:,12]/((Class_newt_cs2_z0[:,0]*h)**2);

# \pi in Newtonian gauge in hi-class pi_Newt= pi_Synch +\alpha
pi_hiclass_Newt_cs0_z100=hiclass_All_100[:,1]+hiclass_All_100[:,3];
pi_hiclass_Newt_cs0_z10=hiclass_All_10[:,1]+hiclass_All_10[:,3];
pi_hiclass_Newt_cs0_z3=hiclass_All_3[:,1]+hiclass_All_3[:,3];
pi_hiclass_Newt_cs0_z0=hiclass_All_0[:,1]+hiclass_All_0[:,3];
# \pi in Newtonian gauge in hi-class cs2=1e-10 pi_Newt= pi_Synch +\alpha
pi_hiclass_cs10_Newt_z100=hiclass_cs10_All_100[:,1]+hiclass_cs10_All_100[:,3];
pi_hiclass_cs10_Newt_z10=hiclass_cs10_All_10[:,1]+hiclass_cs10_All_10[:,3];
pi_hiclass_cs10_Newt_z3=hiclass_cs10_All_3[:,1]+hiclass_cs10_All_3[:,3];
pi_hiclass_cs10_Newt_z0=hiclass_cs10_All_0[:,1]+hiclass_cs10_All_0[:,3];
# \pi in Newtonian gauge in hi-class cs2=1e-2 pi_Newt= pi_Synch +\alpha
pi_hiclass_cs2_Newt_z100=hiclass_cs2_All_100[:,1]+hiclass_cs2_All_100[:,3];
pi_hiclass_cs2_Newt_z10=hiclass_cs2_All_10[:,1]+hiclass_cs2_All_10[:,3];
pi_hiclass_cs2_Newt_z3=hiclass_cs2_All_3[:,1]+hiclass_cs2_All_3[:,3];
pi_hiclass_cs2_Newt_z0=hiclass_cs2_All_0[:,1]+hiclass_cs2_All_0[:,3];


#Plot setting
plt.figure(figsize=(20,20))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)

# plt.plot(hiclass_cs10_All_100[:,0]*h,hiclass_cs10_All_100[:,1],color=tableau12[7],linestyle='solid',lw=2.5,label=r"$\pi$ hi-class z=100, $c_s=10^{-4}$ ")
# plt.plot(hiclass_cs10_All_100[:,0]*h,hiclass_cs10_All_100[:,3],color=tableau12[9],linestyle='solid',lw=2.5,label=r"$\alpha$ hi-class z=100, $c_s=10^{-4}$ ")
# plt.plot(hiclass_All_100[:,0]*h,hiclass_cs2_All_0[:,1],color=tableau20[13],linestyle='solid',lw=2.5,label=r"$\pi$ hi-class z=100, $c_s=10^{-4}$ ")
# plt.plot(hiclass_All_100[:,0]*h,hiclass_cs2_All_0[:,3],color=tableau12[5],linestyle='solid',lw=2.5,label=r"$\alpha$ hi-class z=100, $c_s=10^{-4}$ ")


#Plots z=100
# #Class
# plt.plot(Class_newt_z100[:,0]*h,pi_class_Newt_cs0_z100[:],color=tableau12[3],linestyle='solid',lw=2.5,label=r"$\pi_{Newt}$ class z=100, $c_s=10^{-4}$ ")
# plt.plot(Class_newt_cs10_z100[:,0],pi_class_Newt_cs10_z100[:],color=tableau20[9],linestyle='dashed',lw=2.5,label=r"$\pi_{Newt}$ class z=100, $c_s=10^{-5}$ ")
# plt.plot(Class_newt_cs2_z100[:,0],pi_class_Newt_cs2_z100[:],color=tableau20[8],linestyle='dashed',lw=2.5,label=r"$\pi_{Newt}$ class z=100, $c_s=10^{-1}$ ")

# #hiclass
# plt.plot(hiclass_All_100[:,0]*h,pi_hiclass_Newt_cs0_z100[:],color=tableau12[9],linestyle='solid',lw=2.5,label=r"$\pi_{Newt}$ hi-class z=100, $c_s=10^{-4}$ ")
# plt.plot(hiclass_cs10_All_100[:,0],pi_hiclass_cs10_Newt_z100[:],color=tableau20[5],linestyle='dashed',lw=2.5,label=r"$\pi_{Newt}$ hi-class z=100, $c_s=10^{-5}$ ")
# plt.plot(hiclass_cs2_All_100[:,0],pi_hiclass_cs2_Newt_z100[:],color=tableau20[11],linestyle='dashed',lw=2.5,label=r"$\pi_{Newt}$ hi-class z=100, $c_s=10^{-1}$ ")

#Plots z=10
# plt.plot(Class_newt_z10[:,0]*h,pi_class_Newt_cs0_z10[:],color=tableau12[2],linestyle='solid',lw=2.5,label=r"$\pi_{Newt}$ class z=10 ")
# plt.plot(hiclass_All_10[:,0],pi_hiclass_Newt_cs0_z10[:],color=tableau20[7],linestyle='dashed',lw=2.5,label=r"$\pi_{Newt}$ hi-class z=10 ")
# plt.plot(Class_newt_cs10_z10[:,0]*h,pi_class_Newt_cs10_z10[:],color=tableau12[6],linestyle='solid',lw=2.5,label=r"$\pi_{Newt}$ class z=0, $cs^2=10^{-10}$ ")
# plt.plot(hiclass_cs10_All_10[:,0],pi_hiclass_cs10_Newt_cs0_z10[:],color=tableau20[11],linestyle='dashed',lw=2.5,label=r"$\pi_{Newt}$ hi-class z=0, $cs^2=10^{-10}$ ")

# #Plots z=3
# plt.plot(Class_newt_z3[:,0]*h,pi_class_Newt_cs0_z3[:],color=tableau12[4],linestyle='solid',lw=2.5,label=r"$\pi_{Newt}$ class z=3 ")
# plt.plot(hiclass_All_3[:,0],pi_hiclass_Newt_cs0_z3[:],color=tableau20[9],linestyle='dashed',lw=2.5,label=r"$\pi_{Newt}$ hi-class z=3 ")
# plt.plot(Class_newt_cs10_z3[:,0]*h,pi_class_Newt_cs10_z3[:],color=tableau12[6],linestyle='solid',lw=2.5,label=r"$\pi_{Newt}$ class z=0, $cs^2=10^{-10}$ ")
# plt.plot(hiclass_cs10_All_3[:,0],pi_hiclass_cs10_Newt_cs0_z3[:],color=tableau20[11],linestyle='dashed',lw=2.5,label=r"$\pi_{Newt}$ hi-class z=0, $cs^2=10^{-10}$ ")


# #Plots z=0
#Class
plt.plot(Class_newt_z0[:,0]*h,pi_class_Newt_cs0_z0[:],color=tableau12[0],linestyle='solid',lw=2.5,label=r"$\pi_{Newt}$ class z=0, $c_s=10^{-4}$ ")
# plt.plot(Class_newt_cs10_z0[:,0],pi_class_Newt_cs10_z0[:],color=tableau20[5],linestyle='dashed',lw=2.5,label=r"$\pi_{Newt}$ hiclass z=0, $c_s=10^{-5}$ ")
# plt.plot(Class_newt_cs2_z0[:,0],pi_class_Newt_cs2_z0[:],color=tableau20[9],linestyle='dashed',lw=2.5,label=r"$\pi_{Newt}$ hiclass z=0, $c_s=10^{-1}$ ")

#hiclass
plt.plot(hiclass_All_0[:,0]*h,hiclass_All_0[:,3],color=tableau20[13],linestyle='solid',lw=2.5,label=r"$\pi$ hi-class z=100, $c_s=10^{-4}$ ")
plt.plot(hiclass_All_0[:,0]*h,hiclass_All_0[:,1],color=tableau20[15],linestyle='solid',lw=2.5,label=r"$\pi$ hi-class z=100, $c_s=10^{-4}$ ")

plt.plot(hiclass_All_0[:,0]*h,pi_hiclass_Newt_cs0_z0[:],color=tableau12[6],linestyle='solid',lw=2.5,label=r"$\pi_{Newt}$ class z=0, $c_s=10^{-4}$ ")
# plt.plot(hiclass_cs10_All_0[:,0],pi_hiclass_cs10_Newt_z0[:],color=tableau20[5],linestyle='dashed',lw=2.5,label=r"$\pi_{Newt}$ hi-class z=0, $c_s=10^{-5}$ ")
# plt.plot(hiclass_cs2_All_0[:,0],pi_hiclass_cs2_Newt_z0[:],color=tableau20[14],linestyle='dashed',lw=2.5,label=r"$\pi_{Newt}$ hi-class z=0, $c_s=10^{-1}$ ")

# plt.plot(Class_newt_cs10_z0[:,0]*h,pi_class_Newt_cs10_z0[:],color=tableau12[6],linestyle='solid',lw=2.5,label=r"$\pi_{Newt}$ class z=0, $cs^2=10^{-10}$ ")
# plt.plot(hiclass_cs10_All_0[:,0],pi_hiclass_cs10_Newt_cs0_z0[:],color=tableau20[11],linestyle='solid',lw=2.5,label=r"$\pi_{Newt}$ hi-class z=0, $cs^2=10^{-10}$ ")
# plt.plot(Class_newt_z0[:,0]*h,pi_class_Newt_cs0_z0[:],color=tableau12[10],linestyle='solid',lw=2.5,label=r"$\pi_{Newt}$ class z=0 ")
# plt.plot(hiclass_All_0[:,0],pi_hiclass_cs10_Newt_z0[:],color=tableau20[11],linestyle='dashed',lw=2.5,label=r"$\pi_{Newt}$ hi-class z=0 ")

# Show the plots and save
plt.legend(bbox_to_anchor=(0.74, 0.90, 0.26, .102), loc=1,ncol=1,fontsize=15, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale("log")
# plt.yscale('log')
plt.xlabel("k[h/Mpc]",fontsize=20)
plt.ylabel(r"$\pi/\mathcal{R}$",fontsize=20)
plt.xlim(0.0001,5)
# plt.ylim(1.e-27,1.e-1)
# plt.savefig('pi_kcomparison.jpg', format='eps', dpi=1000)
plt.show()

# %% [markdown]
# # Alpha comparison hi-class (unternally) class (internally)

# %% [markdown]
# # Class-hiclass \pi in Synchronous gauge via formula

# %% [markdown]
# # EFT CAMB and hiclass comparison in \pi \pi' transfer function

# %% [markdown]
# # Class-hiclass \pi' in Newtonian gauge via formula

# %%
# Confused about the fomula! It seems the formula in Domeco's paper is different with mine! what is cs^2 in my calculation?
#Todo: \delta\P/\delta \rho= cs2 + ... do it in the formula. 

# Columns: k ,pi_synch, pi'_synch, \alpha, \alpha', Psi
cs2=1.e-6;
w=-0.9;
h=0.67;
As=2.215*10.e-9;
ns=0.96;
kp=0.05/h;

#Background quantities
Hubbz100=1.452411e-01;
a100=1./(1.+100.);
Hubbz10=4.633370e-03;
Hubz3=1.064036e-03;
Hubbz0=2.25e-4;
a0=1.;

coeff=(cs2)/(1+w);
# \pi in Newtonian in class : -\theta/k^2
pi_class_Newt_cs0_z100=Class_newt_z100[:,12]/((Class_newt_z100[:,0]*h)**2);
pi_class_Newt_cs0_z10=Class_newt_z10[:,12]/((Class_newt_z10[:,0]*h)**2);
pi_class_Newt_cs0_z3=Class_newt_z3[:,12]/((Class_newt_z3[:,0]*h)**2);
pi_class_Newt_cs0_z0=Class_newt_z0[:,12]/((Class_newt_z0[:,0]*h)**2);
# \pi in Newtonian in class cs2=1e-10 : -\theta/k^2
pi_class_Newt_cs10_z100=Class_newt_cs10_z100[:,12]/((Class_newt_cs10_z100[:,0]*h)**2);
pi_class_Newt_cs10_z10=Class_newt_cs10_z10[:,12]/((Class_newt_cs10_z10[:,0]*h)**2);
pi_class_Newt_cs10_z3=Class_newt_cs10_z3[:,12]/((Class_newt_cs10_z3[:,0]*h)**2);
pi_class_Newt_cs10_z0=Class_newt_cs10_z0[:,12]/((Class_newt_cs10_z0[:,0]*h)**2);

# Psi is Class_newt_z100[:,7] and delta=Class_newt_z100[:,4]
#pi' in class according to the formula: \delta*(cs2/1+w) + \Psi + 3 H cs2 \pi
# pi_prime_Newtonian_class_z100=coeff*Class_newt_z100[:,4] + 3.*cs2*Hubbz100*a100*pi_class_Newt_cs0_z100 + Class_newt_z100[:,7] ;
pi_prime_Newtonian_class_z100=coeff*Class_newt_z100[:,4] + 3.*cs2*Hubbz100*a100*pi_class_Newt_cs0_z100 + Class_newt_z100[:,8] ;
pi_prime_Newtonian_class_z0=coeff*Class_newt_z0[:,4] + 3.*cs2*Hubbz0*a0*pi_class_Newt_cs0_z0 + Class_newt_z0[:,7] ;

pi_prime_cs10_Newtonian_class_z100=coeff*Class_newt_cs10_z100[:,4] + 3.*cs2*Hubbz100*a100*pi_class_Newt_cs0_z100 + Class_newt_cs10_z100[:,8] ;
pi_prime_cs10_Newtonian_class_z0=coeff*Class_newt_cs10_z0[:,4] + 3.*cs2*Hubbz0*a0*pi_class_Newt_cs0_z0 + Class_newt_cs10_z0[:,7] ;

#pi' in hiclass according to the formula: pi'_synch + alpha'
pi_prime_Newtonian_hiclass_z100=hiclass_All_100[:,2]+hiclass_All_100[:,4];
pi_prime_Newtonian_hiclass_z0=hiclass_All_0[:,2]+hiclass_All_0[:,4];
pi_prime_cs10_Newtonian_hiclass_z100=hiclass_cs10_All_100[:,2]+hiclass_cs10_All_100[:,4];
pi_prime_cs10_Newtonian_hiclass_z0=hiclass_cs10_All_0[:,2]+hiclass_cs10_All_0[:,4];
#Plot setting
plt.figure(figsize=(20,20))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)

#Plots z=100
plt.plot(Class_newt_z100[:,0]*h,pi_prime_Newtonian_class_z100[:],color=tableau12[0],linestyle='solid',lw=2.5,label=r"$\pi'_{Newt}$ class z=100 ")
plt.plot(hiclass_All_100[:,0],pi_prime_Newtonian_hiclass_z100[:],color=tableau20[5],linestyle='dashed',lw=2.5,label=r"$\pi'_{Newt}$ hiclass z=100 ")
plt.plot(Class_newt_z100[:,0]*h,pi_prime_cs10_Newtonian_class_z100[:],color=tableau12[0],linestyle='solid',lw=2.5,label=r"$\pi'_{Newt}$ class z=100 ")
plt.plot(hiclass_cs10_All_100[:,0],pi_prime_cs10_Newtonian_hiclass_z0[:],color=tableau20[5],linestyle='dashed',lw=2.5,label=r"$\pi'_{Newt}$ hiclass z=100 ")

# #Plots z=10
# plt.plot(Class_newt_z10[:,0]*h,pi_prime_Newtonian_class_z10[:],color=tableau12[2],linestyle='solid',lw=2.5,label=r"$\pi_{Newt}$ class z=10 ")
# plt.plot(hiclass_All_10[:,0],pi_hiclass_Newt_cs0_z10[:],color=tableau20[7],linestyle='dashed',lw=2.5,label=r"$\pi_{Newt}$ hi-class z=10 ")

# #Plots z=3
# plt.plot(Class_newt_z3[:,0]*h,pi_class_Newt_cs0_z3[:],color=tableau12[4],linestyle='solid',lw=2.5,label=r"$\pi_{Newt}$ class z=3 ")
# plt.plot(hiclass_All_3[:,0],pi_hiclass_Newt_cs0_z3[:],color=tableau20[9],linestyle='dashed',lw=2.5,label=r"$\pi_{Newt}$ hi-class z=3 ")

# #Plots z=0
plt.plot(Class_newt_z0[:,0]*h,pi_prime_Newtonian_class_z0[:],color=tableau12[6],linestyle='solid',lw=2.5,label=r"$\pi'_{Newt}$ class z=0 ")
plt.plot(hiclass_All_0[:,0],pi_hiclass_Newt_cs0_z0[:],color=tableau20[11],linestyle='dashed',lw=2.5,label=r"$\pi'_{Newt}$ hi-class z=0 ")

# Show the plots and save
plt.legend(bbox_to_anchor=(0.8, 0.90, 0.2, .102), loc=1,ncol=1,fontsize=15, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale("log")
# plt.yscale('log')
plt.xlabel("k[h/Mpc]",fontsize=20)
plt.ylabel(r"$\pi'/\mathcal{R}$",fontsize=20)
plt.xlim(0.0001,5)
# plt.ylim(1.e-27,1.e-1)
# plt.savefig('pi_kcomparison.jpg', format='eps', dpi=1000)
plt.show()

# %% [markdown]
# # Class-hiclass \pi'  in Synchronous gauge via formula

# %%
# \delta_m class vs \delta_kessence and compare with Gevolution.
