# %% [markdown]
# # Notebook for comparison beween hi-class and Gevolution and agreement between class and hi-class

# %%
import numpy as np
import matplotlib.pylab as plt
from scipy.interpolate import interp1d
from pylab import rcParams
tableau12 = [(0, 0, 0), (50, 0, 0), (0, 50, 0), (0, 0, 50),    
             (0, 50, 50), (50, 50, 0), (50, 0, 50), (50, 50, 50),    
             (100, 50, 50), (50, 100, 50), (50, 50, 100), (100, 100, 100)]    
  
# Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.    
for i in range(len(tableau12)):    
    r, g, b = tableau12[i]    
    tableau12[i] = (r / 255., g / 255., b / 255.) 
    
tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),    
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),    
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),    
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),    
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]    
  
# Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.    
for i in range(len(tableau20)):    
    r, g, b = tableau20[i]    
    tableau20[i] = (r / 255., g / 255., b / 255.)
# plt.style.available
plt.rcParams.update(plt.rcParamsDefault)

# plt.style.use('seaborn-paper')
plt.rcParams['font.serif'] = 'Ubuntu'

# %% [markdown]
# # Adding files

# %%
backgr=np.loadtxt("./Gevolution_kessenc/lcdm_background.dat")

# Gevolution files for pi_k
piGev_z_100=np.loadtxt("./Gevolution_kessenc/lcdm_pk000_pi_k.dat")
piGev_z_10=np.loadtxt("./Gevolution_kessenc/lcdm_pk001_pi_k.dat")
piGev_z_3=np.loadtxt("./Gevolution_kessenc/lcdm_pk002_pi_k.dat")
piGev_z_0=np.loadtxt("./Gevolution_kessenc/lcdm_pk003_pi_k.dat")

# Linear kessence Gevolution files for pi_k
piGev_lin_z_100=np.loadtxt("./Gev_lienearKessence/lcdm_pk000_pi_k.dat")
piGev_lin_z_10=np.loadtxt("./Gev_lienearKessence/lcdm_pk001_pi_k.dat")
piGev_lin_z_3=np.loadtxt("./Gev_lienearKessence/lcdm_pk002_pi_k.dat")
piGev_lin_z_0=np.loadtxt("./Gev_lienearKessence/lcdm_pk003_pi_k.dat")

# Gevolution files for pi_v
pivGev_z_100=np.loadtxt("./Gevolution_kessenc/lcdm_pk000_pi_v_k.dat")
pivGev_z_10=np.loadtxt("./Gevolution_kessenc/lcdm_pk001_pi_v_k.dat")
pivGev_z_3=np.loadtxt("./Gevolution_kessenc/lcdm_pk002_pi_v_k.dat")
pivGev_z_0=np.loadtxt("./Gevolution_kessenc/lcdm_pk003_pi_v_k.dat")

# Linear kessence Gevolution  files for pi_v
pivGev_lin_z_100=np.loadtxt("./Gev_lienearKessence/lcdm_pk000_pi_v_k.dat")
pivGev_lin_z_10=np.loadtxt("./Gev_lienearKessence/lcdm_pk001_pi_v_k.dat")
pivGev_lin_z_3=np.loadtxt("./Gev_lienearKessence/lcdm_pk002_pi_v_k.dat")
pivGev_lin_z_0=np.loadtxt("./Gev_lienearKessence/lcdm_pk003_pi_v_k.dat")

Gev_iniz100=np.loadtxt("./kessence_gev_cs0z100.dat")
# Gevolution files for phi
phi_z_100=np.loadtxt("./Gevolution_kessenc/lcdm_pk000_phi.dat")
phi_z_10=np.loadtxt("./Gevolution_kessenc/lcdm_pk001_phi.dat")
phi_z_3=np.loadtxt("./Gevolution_kessenc/lcdm_pk002_phi.dat")
phi_z_0=np.loadtxt("./Gevolution_kessenc/lcdm_pk003_phi.dat")

# Gevolution files for T00
T00Gev_z_100=np.loadtxt("./Gevolution_kessenc/lcdm_pk000_T00_kess.dat")
T00Gev_z_10=np.loadtxt("./Gevolution_kessenc/lcdm_pk001_T00_kess.dat")
# piGev_z_3=np.loadtxt("./Gevolution_kessenc/lcdm_pk002_pi_k.dat")
# piGev_z_0=np.loadtxt("./Gevolution_kessenc/lcdm_pk003_pi_k.dat")

# Original phi of Gevolution
# phi_strd_z_100=np.loadtxt("./Standard_Gevolution/lcdm_pk000_phi.dat")
# phi_strd_z_10=np.loadtxt("./Standard_Gevolution/lcdm_pk001_phi.dat")
# phi_strd_z_3=np.loadtxt("./Standard_Gevolution/lcdm_pk002_phi.dat")
# phi_strd_z_0=np.loadtxt("./Standard_Gevolution/lcdm_pk003_phi.dat")

# hiclass kessence_IC_gevolution field files in different redshift
hiclass_z100=np.loadtxt("./hiClass/Gevolution_IC/kessence_gev_cs0z100.dat")
hiclass_z10=np.loadtxt("./hiClass/Gevolution_IC/kessence_gev_cs0z10.dat")
hiclass_z3=np.loadtxt("./hiClass/Gevolution_IC/kessence_gev_cs0z3.dat")
hiclass_z0=np.loadtxt("./hiClass/Gevolution_IC/kessence_gev_cs0z0.dat")

# hiclass phi field files in different redshift
hiclass_phi_z100=np.loadtxt("./hiClass/Psi_files/psi_hiclass_cs0z100.dat")
hiclass_phi_z10=np.loadtxt("./hiClass/Psi_files/psi_hiclass_cs0z10.dat")
hiclass_phi_z3=np.loadtxt("./hiClass/Psi_files/psi_hiclass_cs0z3.dat")
hiclass_phi_z0=np.loadtxt("./hiClass/Psi_files/psi_hiclass_cs0z0.dat")

# hiclass All informatio files in different redshift for comparison with Class
hiclass_All_100=np.loadtxt("./hiClass/All_information_files/kessence_Allhiclass_cs0z100.dat")
hiclass_All_10=np.loadtxt("./hiClass/All_information_files/kessence_Allhiclass_cs0z10.dat")
hiclass_All_3=np.loadtxt("./hiClass/All_information_files/kessence_Allhiclass_cs0z3.dat")
hiclass_All_0=np.loadtxt("./hiClass/All_information_files/kessence_Allhiclass_cs0z0.dat")

#Class output in synchronous and Newtonian gauge for comparison with hi-class results.
Class_newt_z100=np.loadtxt("./Class_files/class_kess_cs0_newt_z1_tk.dat")
Class_newt_z10=np.loadtxt("./Class_files/class_kess_cs0_newt_z2_tk.dat")
Class_newt_z3=np.loadtxt("./Class_files/class_kess_cs0_newt_z3_tk.dat")
Class_newt_z0=np.loadtxt("./Class_files/class_kess_cs0_newt_z4_tk.dat")

Class_synch_z100=np.loadtxt("./Class_files/class_kess_cs0_synch_z1_tk.dat")
Class_synch_z10=np.loadtxt("./Class_files/class_kess_cs0_synch_z2_tk.dat")
Class_synch_z3=np.loadtxt("./Class_files/class_kess_cs0_synch_z3_tk.dat")
Class_synch_z0=np.loadtxt("./Class_files/class_kess_cs0_synch_z4_tk.dat")


#class powerspectra, Gevolution IC from class
class_z100=np.loadtxt("./Class_files/class_tk.dat")

# %% [markdown]
# # Background comparison

# %%
# a=backgr[:,2]
h=0.67556
Omega_m=0.312046;
Omega_kessence=0.67;
# (1-Omega_m-Omega_kessence)*a*a
a = np.arange(0., 15., 0.001)
myHa=np.sqrt(Omega_m/a+(Omega_kessence)*a**(-3*(1-0.9))*a*a)

plt.loglog(backgr[:,2],backgr[:,3],color="blue")
plt.loglog(a,myHa,color="red")

plt.xlim(0.008,2.05)
#plt.ylim(1.e-17,1.e-1)
plt.show()
# Out:
# /Users/farbod/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in divide
#   import sys
# /Users/farbod/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in power
#   import sys
# /Users/farbod/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in multiply
#   import sys

# %% [markdown]
# # \pi_k dynamic from linear equation in Gevolution compared with hi-class

# %%
# params for makin power dimensionless
# Nothin matches! Check the calculations and equations with Martin.
As=2.19*10**-9;
h=0.67;
kp=0.05/h; 
ns=0.96;

#Plot setting


plt.figure(figsize=(20,20))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)

#Making related hi-class powerspectra
P_hiclass_z100_dimensionless=As*(hiclass_z100[:,1]**2)*((hiclass_z100[:,0]/kp)**(ns-1.));
P_hiclass_z10_dimensionless=As*(hiclass_z10[:,1]**2)*((hiclass_z10[:,0]/kp)**(ns-1.));
P_hiclass_z3_dimensionless=As*(hiclass_z3[:,1]**2)*((hiclass_z3[:,0]/kp)**(ns-1.));
P_hiclass_z0_dimensionless=As*(hiclass_z0[:,1]**2)*((hiclass_z0[:,0]/kp)**(ns-1.));

#Plots z=100
plt.plot(hiclass_z100[:,0],P_hiclass_z100_dimensionless[:],color=tableau12[0],linestyle='solid',lw=2.5,label=r"$\pi_k$ hiclass z=100 ")
plt.plot(piGev_lin_z_100[:,0],piGev_lin_z_100[:,1],color=tableau20[19],linestyle='dashed',lw=2.5,label=r"$\pi_k$ Linear_Gev z=100 ")

#Plots z=10
plt.plot(hiclass_z10[:,0],P_hiclass_z10_dimensionless[:],color=tableau12[8],linestyle='solid',lw=2.5,label=r"$\pi_k$ hiclass z=10 ")
plt.plot(piGev_lin_z_10[:,0],piGev_lin_z_10[:,1],color=tableau20[14],linestyle='dashed',lw=2.5,label=r"$\pi_k$ Linear_Gev z=10 ")

# # #Plots z=3
plt.plot(hiclass_z3[:,0],P_hiclass_z3_dimensionless[:],color=tableau12[3],linestyle='solid',lw=2.5,label=r"$\pi_k$ hiclass z=3 ")
plt.plot(piGev_lin_z_3[:,0],piGev_lin_z_3[:,1],color=tableau20[5],linestyle='dashed',lw=2.5,label=r"$\pi_k$ Linear_Gev z=3 ")

# # #Plots z=0
plt.plot(hiclass_z0[:,0],P_hiclass_z0_dimensionless[:],color=tableau12[0],linestyle='solid',lw=2.5,label=r"$\pi_k$ hiclass z=0 ")
plt.plot(piGev_lin_z_0[:,0],piGev_lin_z_0[:,1],color=tableau20[17],linestyle='dashed',lw=2.5,label=r"$\pi_k$ Linear_Gev z=0 ")

# Show the plots and save
plt.legend(bbox_to_anchor=(0.8, 0.90, 0.2, .102), loc=1,ncol=1,fontsize=15, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale("log")
# plt.yscale('log')
plt.xlabel("k[h/Mpc]",fontsize=20)
plt.ylabel(r"$P_{\pi}[Mpc^3]$",fontsize=20)
plt.xlim(0.0001,5)
plt.ylim(1.e-17,1.e-1)
# plt.savefig('pi_kcomparison.jpg', format='eps', dpi=1000)
plt.show()

# %% [markdown]
# # \pi_k dynamic from Nonlinear equation in Gevolution compared with hi-class

# %%
# params for makin power dimensionless
# Nothin matches! Check the calculations and equations with Martin.
As=2.19*10**-9;
h=0.67;
kp=0.05/h; 
ns=0.96;

#Plot setting


plt.figure(figsize=(20,20))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)

#Making related hi-class powerspectra
P_hiclass_z100_dimensionless=As*(hiclass_z100[:,1]**2)*((hiclass_z100[:,0]/kp)**(ns-1.));
P_hiclass_z10_dimensionless=As*(hiclass_z10[:,1]**2)*((hiclass_z10[:,0]/kp)**(ns-1.));
P_hiclass_z3_dimensionless=As*(hiclass_z3[:,1]**2)*((hiclass_z3[:,0]/kp)**(ns-1.));
P_hiclass_z0_dimensionless=As*(hiclass_z0[:,1]**2)*((hiclass_z0[:,0]/kp)**(ns-1.));

#Plots z=100
plt.plot(hiclass_z100[:,0],P_hiclass_z100_dimensionless[:],color=tableau12[0],linestyle='solid',lw=2.5,label=r"$\pi_k$ hiclass z=100 ")
plt.plot(piGev_z_100[:,0],piGev_z_100[:,1],color=tableau20[0],linestyle='dashed',lw=2.5,label=r"$\pi_k$ Gev_Non linear z=100 ")
# plt.plot(pivGev_lin_z_100[:,0],pivGev_lin_z_100[:,1],color=tableau20[19],linestyle='dashed',lw=2.5,label=r"$\pi_k$ Linear_Gev z=100 ")

#Plots z=10
plt.plot(hiclass_z10[:,0],P_hiclass_z10_dimensionless[:],color=tableau12[2],linestyle='solid',lw=2.5,label=r"$\pi_k$ hiclass z=10 ")
plt.plot(piGev_z_10[:,0],piGev_z_10[:,1],color=tableau20[2],linestyle='dashed',lw=2.5,label=r"$\pi_k$ Gev_Non linear z=10 ")
# plt.plot(pivGev_lin_z_10[:,0],pivGev_lin_z_10[:,1],color=tableau20[18],linestyle='dashed',lw=2.5,label=r"$\pi_k$ Linear_Gev z=10 ")

# #Plots z=3
plt.plot(hiclass_z3[:,0],P_hiclass_z3_dimensionless[:],color=tableau12[5],linestyle='solid',lw=2.5,label=r"$\pi_k$ hiclass z=3 ")
plt.plot(piGev_z_3[:,0],piGev_z_3[:,1],color=tableau20[5],linestyle='dashed',lw=2.5,label=r"$\pi_k$ Gev_Non linear z=3 ")
# plt.plot(pivGev_lin_z_3[:,0],pivGev_lin_z_3[:,1],color=tableau20[15],linestyle='dashed',lw=2.5,label=r"$\pi_k$ Linear_Gev z=3 ")

# #Plots z=0
plt.plot(hiclass_z0[:,0],P_hiclass_z0_dimensionless[:],color=tableau12[8],linestyle='solid',lw=2.5,label=r"$\pi_k$ hiclass z=0 ")
plt.plot(piGev_z_0[:,0],piGev_z_0[:,1],color=tableau20[8],linestyle='dashed',lw=2.5,label=r"$\pi_k$ Gev_Non linear z=0 ")
# plt.plot(pivGev_lin_z_0[:,0],pivGev_lin_z_0[:,1],color=tableau20[10],linestyle='dashed',lw=2.5,label=r"$\pi_k$ Linear_Gev z=3 ")

# Show the plots and save
plt.legend(bbox_to_anchor=(0.8, 0.90, 0.2, .102), loc=1,ncol=1,fontsize=15, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale("log")
# plt.yscale('log')
plt.xlabel("k[h/Mpc]",fontsize=20)
plt.ylabel(r"$P_{\pi}[Mpc^3]$",fontsize=20)
plt.xlim(0.0001,5)
plt.ylim(1.e-17,1.e-1)
# plt.savefig('pi_kcomparison.jpg', format='eps', dpi=1000)
# plt.show();
# Out:
# (1e-17, 0.1)

# %% [markdown]
# # \pi_v dynamic from Linear equation in Gevolution compared with hi-class

# %%
# params for makin power dimensionless
As=2.19*10**-9;
h=0.67;
kp=0.05/h; 
ns=0.96;

#Plot setting
plt.figure(figsize=(20,20))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)

#Making related hi-class powerspectra

Pv_hiclass_z100_dimensionless=As*(hiclass_z100[:,2]**2)*((hiclass_z100[:,0]/kp)**(ns-1.));
Pv_hiclass_z10_dimensionless=As*(hiclass_z10[:,2]**2)*((hiclass_z10[:,0]/kp)**(ns-1.));
Pv_hiclass_z3_dimensionless=As*(hiclass_z3[:,2]**2)*((hiclass_z3[:,0]/kp)**(ns-1.));
Pv_hiclass_z0_dimensionless=As*(hiclass_z0[:,2]**2)*((hiclass_z0[:,0]/kp)**(ns-1.));

P_hiclassGev=As*(Gev_iniz100[:,2]**2)*((Gev_iniz100[:,0]/kp)**(ns-1.));

#Plots z=100
plt.plot(hiclass_z100[:,0],Pv_hiclass_z100_dimensionless[:],color=tableau12[0],linestyle='solid',lw=2.5,label=r"$\pi'_k$ hiclass z=100 ")
plt.plot(pivGev_lin_z_100[:,0],pivGev_lin_z_100[:,1],color=tableau20[19],linestyle='dashed',lw=2.5,label=r"$\pi'_k$ Linear_Gev z=100 ")
plt.plot(Gev_iniz100[:,0],P_hiclassGev[:],color=tableau12[11],linestyle='solid',lw=2.5,label=r"$\pi'_k$ hiclass z=100 ")

#Plots z=10
# plt.plot(hiclass_z10[:,0],Pv_hiclass_z10_dimensionless[:],color=tableau12[8],linestyle='solid',lw=2.5,label=r"$\pi'_k$ hiclass z=10 ")
# plt.plot(pivGev_lin_z_10[:,0],pivGev_lin_z_10[:,1],color=tableau20[15],linestyle='dashed',lw=2.5,label=r"$\pi'_k$ Linear_Gev z=10 ")

# # # #Plots z=3
# plt.plot(hiclass_z3[:,0],Pv_hiclass_z3_dimensionless[:],color=tableau12[5],linestyle='solid',lw=2.5,label=r"$\pi'_k$ hiclass z=3 ")
# plt.plot(pivGev_lin_z_3[:,0],pivGev_lin_z_3[:,1],color=tableau20[7],linestyle='dashed',lw=2.5,label=r"$\pi'_k$ Linear_Gev z=3 ")

# # # #Plots z=0
# plt.plot(hiclass_z0[:,0],Pv_hiclass_z0_dimensionless[:],color=tableau12[11],linestyle='solid',lw=2.5,label=r"$\pi'_k$ hiclass z=0 ")
# plt.plot(pivGev_lin_z_0[:,0],pivGev_lin_z_0[:,1],color=tableau20[9],linestyle='dashed',lw=2.5,label=r"$\pi'_k$ Linear_Gev z=0 ")

# Show the plots and save
plt.legend(bbox_to_anchor=(0.8, 0.90, 0.2, .102), loc=1,ncol=1,fontsize=15, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale("log")
# plt.yscale('log')
plt.xlabel("k[h/Mpc]",fontsize=20)
plt.ylabel(r"$P_{\pi}[Mpc^3]$",fontsize=20)
plt.xlim(0.0001,5)
plt.ylim(1.e-27,1.e-1)
# plt.savefig('pi_kcomparison.jpg', format='eps', dpi=1000)
plt.show()

# %% [markdown]
# # \pi_v dynamic from Non-Linear equation in Gevolution compared with hi-class

# %%
# params for makin power dimensionless
As=2.19*10**-9;
h=0.67;
kp=0.05/h; 
ns=0.96;

#Plot setting
plt.figure(figsize=(20,20))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)

#Making related hi-class powerspectra
Pv_hiclass_z100_dimensionless=As*(hiclass_z100[:,2]**2)*((hiclass_z100[:,0]/kp)**(ns-1.));
Pv_hiclass_z10_dimensionless=As*(hiclass_z10[:,2]**2)*((hiclass_z10[:,0]/kp)**(ns-1.));
Pv_hiclass_z3_dimensionless=As*(hiclass_z3[:,2]**2)*((hiclass_z3[:,0]/kp)**(ns-1.));
Pv_hiclass_z0_dimensionless=As*(hiclass_z0[:,2]**2)*((hiclass_z0[:,0]/kp)**(ns-1.));

#Plots z=100
plt.plot(hiclass_z100[:,0],Pv_hiclass_z100_dimensionless[:],color=tableau12[0],linestyle='solid',lw=2.5,label=r"$\pi'_k$ hiclass z=100 ")
plt.plot(pivGev_z_100[:,0],pivGev_z_100[:,1],color=tableau20[0],linestyle='dashed',lw=2.5,label=r"$\pi'_k$ Gev_non linear z=100 ")

#Plots z=10
plt.plot(hiclass_z10[:,0],Pv_hiclass_z10_dimensionless[:],color=tableau12[8],linestyle='solid',lw=2.5,label=r"$\pi'_k$ hiclass z=10 ")
plt.plot(pivGev_z_10[:,0],pivGev_z_10[:,1],color=tableau20[2],linestyle='dashed',lw=2.5,label=r"$\pi'_k$ Gev_non linear z=10 ")

# # #Plots z=3
plt.plot(hiclass_z3[:,0],Pv_hiclass_z3_dimensionless[:],color=tableau12[5],linestyle='solid',lw=2.5,label=r"$\pi'_k$ hiclass z=3 ")
plt.plot(pivGev_z_3[:,0],pivGev_z_3[:,1],color=tableau20[5],linestyle='dashed',lw=2.5,label=r"$\pi'_k$ Gev_non linear z=3 ")

# # #Plots z=0
plt.plot(hiclass_z0[:,0],Pv_hiclass_z0_dimensionless[:],color=tableau12[11],linestyle='solid',lw=2.5,label=r"$\pi'_k$ hiclass z=0 ")
plt.plot(pivGev_z_0[:,0],pivGev_z_0[:,1],color=tableau20[8],linestyle='dashed',lw=2.5,label=r"$\pi'_k$ Gev_non linear z=0 ")

# Show the plots and save
plt.legend(bbox_to_anchor=(0.8, 0.90, 0.2, .102), loc=1,ncol=1,fontsize=15, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale("log")
# plt.yscale('log')
plt.xlabel("k[h/Mpc]",fontsize=20)
plt.ylabel(r"$P_{\pi}[Mpc^3]$",fontsize=20)
plt.xlim(0.0001,5)
plt.ylim(1.e-27,1.e-1)
# plt.savefig('pi_kcomparison.jpg', format='eps', dpi=1000)
plt.show()

# %% [markdown]
# # Phi comparison class and hi-class

# %%
# params for makin power dimensionless
As=2.19*10**-9;
h=0.67;
kp=0.05/h; 
ns=0.96;

#Plot setting
plt.figure(figsize=(20,20))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)


#Plots z=100
plt.plot(hiclass_phi_z100[:,0],hiclass_phi_z100[:,1],color=tableau12[0],linestyle='solid',lw=2.5,label=r"$\Phi$ hiclass z=100 ")
plt.plot(Class_newt_z100[:,0]*h,Class_newt_z100[:,7],color=tableau20[5],linestyle='dashed',lw=2.5,label=r"$\Phi$ class z=100 ")

#Plots z=10
# plt.plot(hiclass_phi_z10[:,0],Phi_hiclass_dimensionless_z10[:],color=tableau12[3],linestyle='solid',lw=2.5,label=r"$\Phi$ hiclass z=10 ")
# plt.plot(Class_newt_z10[:,0]*h,Phi_class_dimensionless_z10[:],color=tableau20[8],linestyle='dashed',lw=2.5,label=r"$\Phi$ class z=10 ")

# # #Plots z=3
# plt.plot(hiclass_z3[:,0],Pv_hiclass_z3_dimensionless[:],color=tableau12[5],linestyle='solid',lw=2.5,label=r"$\pi'_k$ hiclass z=3 ")
# plt.plot(pivGev_z_3[:,0],pivGev_z_3[:,1],color=tableau20[5],linestyle='dashed',lw=2.5,label=r"$\pi'_k$ Gev z=3 ")

# # #Plots z=0
plt.plot(hiclass_phi_z0[:,0],hiclass_phi_z0[:,1],color=tableau12[3],linestyle='solid',lw=2.5,label=r"$\Phi$ hiclass z=0 ")
plt.plot(Class_newt_z0[:,0]*h,Class_newt_z0[:,7],color=tableau20[8],linestyle='dashed',lw=2.5,label=r"$\Phi$ class z=0 ")

# Show the plots and save
plt.legend(bbox_to_anchor=(0.8, 0.90, 0.2, .102), loc=1,ncol=1,fontsize=15, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale("log")
# plt.yscale('log')
plt.xlabel("k[h/Mpc]",fontsize=20)
plt.ylabel(r"$\Phi/\mathcal{R}$",fontsize=20)
plt.xlim(0.0001,5)
# plt.ylim(1.e-27,1.e-1)
# plt.savefig('pi_kcomparison.jpg', format='eps', dpi=1000)
plt.show()

# %% [markdown]
# # \phi power comparison between class (output), hiclass (internally) and Gevolution

# %%
# params for makin power dimensionless
As=2.19*10**-9;
h=0.67;
kp=0.05/h; 
ns=0.96;

#Plot setting
plt.figure(figsize=(20,20))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)

#Making related hi-class powerspectra
Phi_hiclass_dimensionless_z100=As*(hiclass_phi_z100[:,1]**2)*((hiclass_phi_z100[:,0]/kp)**(ns-1.));
Phi_hiclass_dimensionless_z10=As*(hiclass_phi_z10[:,1]**2)*((hiclass_phi_z10[:,0]/kp)**(ns-1.));
Phi_hiclass_dimensionless_z3=As*(hiclass_phi_z3[:,1]**2)*((hiclass_phi_z3[:,0]/kp)**(ns-1.));
Phi_hiclass_dimensionless_z0=As*(hiclass_phi_z0[:,1]**2)*((hiclass_phi_z0[:,0]/kp)**(ns-1.));

#Making related class powerspectra
Phi_class_dimensionless_z100=As*(Class_newt_z100[:,7]**2)*((Class_newt_z100[:,0]/kp)**(ns-1.));
Phi_class_dimensionless_z10=As*(Class_newt_z10[:,7]**2)*((Class_newt_z10[:,0]/kp)**(ns-1.));
Phi_class_dimensionless_z3=As*(Class_newt_z3[:,7]**2)*((Class_newt_z3[:,0]/kp)**(ns-1.));
Phi_class_dimensionless_z0=As*(Class_newt_z0[:,7]**2)*((Class_newt_z0[:,0]/kp)**(ns-1.));

Phi_class_ICz100=As*(class_z100[:,7]**2)*((class_z100[:,0]/kp)**(ns-1.));


#Plots z=100
plt.plot(hiclass_phi_z100[:,0],Phi_hiclass_dimensionless_z100[:],color=tableau12[0],linestyle='solid',lw=2.5,label=r"$\Phi$ hiclass z=100 ")
plt.plot(Class_newt_z100[:,0]*h,Phi_class_dimensionless_z100[:],color=tableau20[5],linestyle='dashed',lw=2.5,label=r"$\Phi$ class z=100 ")
plt.plot(phi_strd_z_100[:,0],phi_strd_z_100[:,1],color=tableau20[0],linestyle='dashed',lw=2.5,label=r"$\Phi$ Gev standard z=100 ")
plt.plot(phi_z_100[:,0],phi_z_100[:,1],color=tableau12[4],linestyle='dashed',lw=2.5,label=r"$\Phi$ Gev kessence z=100 ")
plt.plot(class_z100[:,0],Phi_class_ICz100[:],color=tableau12[9],linestyle='dashed',lw=2.5,label=r"$\Phi$ Class_IC z=100 ")


#Plots z=10
# plt.plot(hiclass_phi_z10[:,0],Phi_hiclass_dimensionless_z10[:],color=tableau12[3],linestyle='solid',lw=2.5,label=r"$\Phi$ hiclass z=10 ")
# plt.plot(Class_newt_z10[:,0]*h,Phi_class_dimensionless_z10[:],color=tableau20[8],linestyle='dashed',lw=2.5,label=r"$\Phi$ class z=10 ")
# plt.plot(phi_strd_z_10[:,0],phi_strd_z_10[:,1],color=tableau20[3],linestyle='dashed',lw=2.5,label=r"$\Phi$ Gev standard z=10 ")
# plt.plot(phi_z_10[:,0],phi_z_10[:,1],color=tableau12[9],linestyle='dashed',lw=2.5,label=r"$\Phi$ Gev kessence z=10 ")

# # #Plots z=3
# plt.plot(hiclass_z3[:,0],Pv_hiclass_z3_dimensionless[:],color=tableau12[5],linestyle='solid',lw=2.5,label=r"$\pi'_k$ hiclass z=3 ")
# plt.plot(pivGev_z_3[:,0],pivGev_z_3[:,1],color=tableau20[5],linestyle='dashed',lw=2.5,label=r"$\pi'_k$ Gev z=3 ")

# # #Plots z=0
# plt.plot(hiclass_phi_z0[:,0],Phi_hiclass_dimensionless_z0[:],color=tableau12[3],linestyle='solid',lw=2.5,label=r"$\Phi$ hiclass z=10 ")
# plt.plot(Class_newt_z0[:,0]*h,Phi_class_dimensionless_z0[:],color=tableau20[8],linestyle='dashed',lw=2.5,label=r"$\Phi$ class z=10 ")
# plt.plot(phi_strd_z_0[:,0],phi_strd_z_0[:,1],color=tableau20[3],linestyle='dashed',lw=2.5,label=r"$\Phi$ Gev standard z=10 ")
# plt.plot(phi_z_0[:,0],phi_z_0[:,1],color=tableau12[9],linestyle='dashed',lw=2.5,label=r"$\Phi$ Gev kessence z=10 ")

# Show the plots and save
plt.legend(bbox_to_anchor=(0.8, 0.90, 0.2, .102), loc=1,ncol=1,fontsize=15, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale("log")
# plt.yscale('log')
plt.xlabel("k[h/Mpc]",fontsize=20)
plt.ylabel(r"$P{_{\Phi}$",fontsize=20)
plt.xlim(0.0001,5)
# plt.ylim(1.e-27,1.e-1)
# plt.savefig('pi_kcomparison.jpg', format='eps', dpi=1000)
plt.show()

# %% [markdown]
# # \delta_kessence power Comparison, Gevolution with hiclass and class.

# %%
# Something in the definition of T00 is wrong maybe!
# I assume \delta in the class output is the transfer function.
# params for makin power dimensionless
As=2.19*10**-9;
h=0.67;
kp=0.05/h; 
ns=0.96;

#Plot setting
plt.figure(figsize=(20,20))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)

# Class normalizartion to be compare with Geviolution we need to multiply to R^2, R is curvature perturbation.
Class_newt_z100_gev=(Class_newt_z100[:,4]**2)*As*((Class_newt_z100[:,0]/kp)**(ns-1.));
Class_newt_z10_gev=(Class_newt_z10[:,4]**2)*As*((Class_newt_z10[:,0]/kp)**(ns-1.));

#Plots z=100
plt.plot(T00Gev_z_100[:,0],T00Gev_z_100[:,1],color=tableau12[0],linestyle='solid',lw=2.5,label=r"$T00$ Gevoution z=100 ")
plt.plot(Class_newt_z100[:,0]*h,Class_newt_z100_gev[:],color=tableau20[5],linestyle='dashed',lw=2.5,label=r"$\delta_{class}$ class z=100 ")

#Plots z=10
plt.plot(T00Gev_z_10[:,0],T00Gev_z_10[:,1],color=tableau12[11],linestyle='solid',lw=2.5,label=r"$T00$ Gevoution z=10 ")
plt.plot(Class_newt_z10[:,0]*h,Class_newt_z10_gev[:],color=tableau20[19],linestyle='dashed',lw=2.5,label=r"$\delta_{class}$ class z=10 ")

# # #Plots z=3
# plt.plot(hiclass_z3[:,0],Pv_hiclass_z3_dimensionless[:],color=tableau12[5],linestyle='solid',lw=2.5,label=r"$\pi'_k$ hiclass z=3 ")
# plt.plot(pivGev_z_3[:,0],pivGev_z_3[:,1],color=tableau20[5],linestyle='dashed',lw=2.5,label=r"$\pi'_k$ Gev z=3 ")

# # #Plots z=0
# plt.plot(hiclass_phi_z0[:,0],Phi_hiclass_dimensionless_z0[:],color=tableau12[3],linestyle='solid',lw=2.5,label=r"$\Phi$ hiclass z=10 ")
# plt.plot(Class_newt_z0[:,0]*h,Phi_class_dimensionless_z0[:],color=tableau20[8],linestyle='dashed',lw=2.5,label=r"$\Phi$ class z=10 ")
# plt.plot(phi_strd_z_0[:,0],phi_strd_z_0[:,1],color=tableau20[3],linestyle='dashed',lw=2.5,label=r"$\Phi$ Gev standard z=10 ")
# plt.plot(phi_z_0[:,0],phi_z_0[:,1],color=tableau12[9],linestyle='dashed',lw=2.5,label=r"$\Phi$ Gev kessence z=10 ")

# Show the plots and save
plt.legend(bbox_to_anchor=(0.8, 0.90, 0.2, .102), loc=1,ncol=1,fontsize=15, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale("log")
plt.xlabel("k[h/Mpc]",fontsize=20)
plt.ylabel(r"$P_{\delta}$",fontsize=20)
plt.xlim(0.0001,5)
# plt.ylim(1.e-27,1.e-1)
# plt.savefig('pi_kcomparison.jpg', format='eps', dpi=1000)
plt.show()

# %% [markdown]
# # Class-hiclass and \pi in Newtonian gauge via formula

# %%
# Columns: k ,pi_synch, pi'_synch, \alpha, \alpha', Psi
#Check the sound speed is the same!
#Run class with much smaller sound speed and see...

cs2=1.e-6;
w=-0.9;
h=0.67;
As=2.215*10.e-9;
ns=0.96;
kp=0.05/h;
Hubb=2.25e-4;

# \pi in Newtonian in class : -\theta/k^2
pi_class_Newt_cs0_z100=Class_newt_z100[:,12]/((Class_newt_z100[:,0]*h)**2);
pi_class_Newt_cs0_z10=Class_newt_z10[:,12]/((Class_newt_z10[:,0]*h)**2);
pi_class_Newt_cs0_z3=Class_newt_z3[:,12]/((Class_newt_z3[:,0]*h)**2);
pi_class_Newt_cs0_z0=Class_newt_z0[:,12]/((Class_newt_z0[:,0]*h)**2);


# \pi in Newtonian gauge in hi-class pi_Newt= pi_Synch +\alpha
pi_hiclass_Newt_cs0_z100=hiclass_All_100[:,1]+hiclass_All_100[:,3];
pi_hiclass_Newt_cs0_z10=hiclass_All_10[:,1]+hiclass_All_10[:,3];
pi_hiclass_Newt_cs0_z3=hiclass_All_3[:,1]+hiclass_All_3[:,3];
pi_hiclass_Newt_cs0_z0=hiclass_All_0[:,1]+hiclass_All_0[:,3];

#Plot setting
plt.figure(figsize=(20,20))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)

#Plots z=100
plt.plot(Class_newt_z100[:,0]*h,pi_class_Newt_cs0_z100[:],color=tableau12[0],linestyle='solid',lw=2.5,label=r"$\pi_{Newt}$ class z=100 ")
plt.plot(hiclass_All_100[:,0],pi_hiclass_Newt_cs0_z100[:],color=tableau20[5],linestyle='dashed',lw=2.5,label=r"$\pi_{Newt}$ hiclass z=100 ")

#Plots z=10
# plt.plot(Class_newt_z10[:,0]*h,pi_class_Newt_cs0_z10[:],color=tableau12[2],linestyle='solid',lw=2.5,label=r"$\pi_{Newt}$ class z=10 ")
# plt.plot(hiclass_All_10[:,0],pi_hiclass_Newt_cs0_z10[:],color=tableau20[7],linestyle='dashed',lw=2.5,label=r"$\pi_{Newt}$ hi-class z=10 ")

# #Plots z=3
plt.plot(Class_newt_z3[:,0]*h,pi_class_Newt_cs0_z3[:],color=tableau12[4],linestyle='solid',lw=2.5,label=r"$\pi_{Newt}$ class z=3 ")
plt.plot(hiclass_All_3[:,0],pi_hiclass_Newt_cs0_z3[:],color=tableau20[9],linestyle='dashed',lw=2.5,label=r"$\pi_{Newt}$ hi-class z=3 ")

# #Plots z=0
plt.plot(Class_newt_z0[:,0]*h,pi_class_Newt_cs0_z0[:],color=tableau12[6],linestyle='solid',lw=2.5,label=r"$\pi_{Newt}$ class z=0 ")
plt.plot(hiclass_All_0[:,0],pi_hiclass_Newt_cs0_z0[:],color=tableau20[11],linestyle='dashed',lw=2.5,label=r"$\pi_{Newt}$ hi-class z=0 ")

# Show the plots and save
plt.legend(bbox_to_anchor=(0.8, 0.90, 0.2, .102), loc=1,ncol=1,fontsize=15, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale("log")
# plt.yscale('log')
plt.xlabel("k[h/Mpc]",fontsize=20)
plt.ylabel(r"$\pi/\mathcal{R}$",fontsize=20)
plt.xlim(0.0001,5)
# plt.ylim(1.e-27,1.e-1)
# plt.savefig('pi_kcomparison.jpg', format='eps', dpi=1000)
plt.show()

# %% [markdown]
# # Class-hiclass \pi' in Newtonian gauge via formula

# %%
# Confused about the fomula! It seems the formula in Domeco's paper is different with mine! what is cs^2 in my calculation?
#Todo: \delta\P/\delta \rho= cs2 + ... do it in the formula. 

# Columns: k ,pi_synch, pi'_synch, \alpha, \alpha', Psi
cs2=1.e-6;
w=-0.9;
h=0.67;
As=2.215*10.e-9;
ns=0.96;
kp=0.05/h;

#Background quantities
Hubbz100=1.452411e-01;
a100=1./(1.+100.);
Hubbz10=4.633370e-03;
Hubz3=1.064036e-03;
Hubbz0=2.25e-4;
a0=1.;

coeff=(cs2)/(1+w);
# \pi in Newtonian in class : -\theta/k^2
pi_class_Newt_cs0_z100=Class_newt_z100[:,12]/((Class_newt_z100[:,0]*h)**2);
pi_class_Newt_cs0_z10=Class_newt_z10[:,12]/((Class_newt_z10[:,0]*h)**2);
pi_class_Newt_cs0_z3=Class_newt_z3[:,12]/((Class_newt_z3[:,0]*h)**2);
pi_class_Newt_cs0_z0=Class_newt_z0[:,12]/((Class_newt_z0[:,0]*h)**2);

# Psi is Class_newt_z100[:,7] and delta=Class_newt_z100[:,4]
#pi' in class according to the formula: \delta*(cs2/1+w) + \Psi + 3 H cs2 \pi
# pi_prime_Newtonian_class_z100=coeff*Class_newt_z100[:,4] + 3.*cs2*Hubbz100*a100*pi_class_Newt_cs0_z100 + Class_newt_z100[:,7] ;
pi_prime_Newtonian_class_z100=coeff*Class_newt_z100[:,4] + 3.*cs2*Hubbz100*a100*pi_class_Newt_cs0_z100 + Class_newt_z100[:,8] ;

pi_prime_Newtonian_class_z0=coeff*Class_newt_z0[:,4] + 3.*cs2*Hubbz0*a0*pi_class_Newt_cs0_z0 + Class_newt_z0[:,7] ;

#pi' in hiclass according to the formula: pi'_synch + alpha'
pi_prime_Newtonian_hiclass_z100=hiclass_All_100[:,2]+hiclass_All_100[:,4];

pi_prime_Newtonian_hiclass_z0=hiclass_All_0[:,2]+hiclass_All_0[:,4];

#Plot setting
plt.figure(figsize=(20,20))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)

#Plots z=100
plt.plot(Class_newt_z100[:,0]*h,pi_prime_Newtonian_class_z100[:],color=tableau12[0],linestyle='solid',lw=2.5,label=r"$\pi'_{Newt}$ class z=100 ")
plt.plot(hiclass_All_100[:,0],pi_prime_Newtonian_hiclass_z100[:],color=tableau20[5],linestyle='dashed',lw=2.5,label=r"$\pi'_{Newt}$ hiclass z=100 ")

# #Plots z=10
# plt.plot(Class_newt_z10[:,0]*h,pi_class_Newt_cs0_z10[:],color=tableau12[2],linestyle='solid',lw=2.5,label=r"$\pi_{Newt}$ class z=10 ")
# plt.plot(hiclass_All_10[:,0],pi_hiclass_Newt_cs0_z10[:],color=tableau20[7],linestyle='dashed',lw=2.5,label=r"$\pi_{Newt}$ hi-class z=10 ")

# #Plots z=3
# plt.plot(Class_newt_z3[:,0]*h,pi_class_Newt_cs0_z3[:],color=tableau12[4],linestyle='solid',lw=2.5,label=r"$\pi_{Newt}$ class z=3 ")
# plt.plot(hiclass_All_3[:,0],pi_hiclass_Newt_cs0_z3[:],color=tableau20[9],linestyle='dashed',lw=2.5,label=r"$\pi_{Newt}$ hi-class z=3 ")

# #Plots z=0
# plt.plot(Class_newt_z0[:,0]*h,pi_prime_Newtonian_class_z0[:],color=tableau12[6],linestyle='solid',lw=2.5,label=r"$\pi'_{Newt}$ class z=0 ")
# plt.plot(hiclass_All_0[:,0],pi_prime_Newtonian_hiclass_z0[:],color=tableau20[11],linestyle='dashed',lw=2.5,label=r"$\pi'_{Newt}$ hi-class z=0 ")

# Show the plots and save
plt.legend(bbox_to_anchor=(0.8, 0.90, 0.2, .102), loc=1,ncol=1,fontsize=15, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale("log")
# plt.yscale('log')
plt.xlabel("k[h/Mpc]",fontsize=20)
plt.ylabel(r"$\pi'/\mathcal{R}$",fontsize=20)
plt.xlim(0.0001,5)
# plt.ylim(1.e-27,1.e-1)
# plt.savefig('pi_kcomparison.jpg', format='eps', dpi=1000)
plt.show()

# %% [markdown]
# # Class-hiclass \pi in Synchronous gauge via formula

# %% [markdown]
# # Class-hiclass \pi'  in Synchronous gauge via formula

# %% [markdown]
# # EFT CAMB and hiclass comparison in \pi \pi' transfer function

# %%
# \delta_m class vs \delta_kessence and compare with Gevolution.
