# %% [markdown]
# # Notebook for comparison beween  Gevolution and class and agreement between class and hi-class

# %%
import numpy as np
import matplotlib.pylab as plt
from scipy.interpolate import interp1d
from pylab import rcParams
import scipy.integrate as integrate
ColorsI = ["red","blue","green","purple","darkcyan","gold","maroon","black"]
ColorsII = ["salmon","dodgerblue","springgreen","plum","cyan","khaki","lightcoral","gray"]

# plt.style.use('seaborn-paper')
plt.rcParams['font.serif'] = 'Ubuntu'

# %% [markdown]
# # Gevolution linear and class reading

# %%
# Gevolution Linear
# addressGev="Daint_Runs/Kessence_Linear_Ngrid_1920_DT_0.04/output";
addressGev="Gevolution_outputs/Gev_kess";

########
# z=100
########
Gev_lin_delta_m_z100=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_000_delta.dat")
Gev_lin_delta_m_z50=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_001_delta.dat")
Gev_lin_delta_m_z10=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_002_delta.dat")


Gev_lin_phi_z100=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_000_phi.dat")
Gev_lin_phi_z50=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_001_phi.dat")
Gev_lin_phi_z10=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_002_phi.dat")

########
# z=50
########
# Gev_lin_delta_m_z50=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_001_delta.dat")
# Gev_lin_phi_z50=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_001_phi.dat")


Gev_normal="Gevolution_outputs/gev_normal";
########
# z=100
########
Gev_fld_delta_z100=np.loadtxt("./"+Gev_normal+"/kess_pk_cs_e3_000_delta.dat")
Gev_fld_delta_z50=np.loadtxt("./"+Gev_normal+"/kess_pk_cs_e3_001_delta.dat")
Gev_fld_delta_z10=np.loadtxt("./"+Gev_normal+"/kess_pk_cs_e3_002_delta.dat")


Gev_fld_phi_z100=np.loadtxt("./"+Gev_normal+"/kess_pk_cs_e3_000_phi.dat")
Gev_fld_phi_z50=np.loadtxt("./"+Gev_normal+"/kess_pk_cs_e3_001_phi.dat")
Gev_fld_phi_z10=np.loadtxt("./"+Gev_normal+"/kess_pk_cs_e3_002_phi.dat")

# Gev_fld_phi_z100=np.loadtxt("./"+Gev_normal+"/kess_pk_cs_e3_000_phi.dat")
Juliandelta_m=np.loadtxt("./Gevolution_outputs/2018.07.09.13.06.04/kess_pk_cs_e3_000_delta.dat")

########
# Gev_fld_delta_z50=np.loadtxt("./"+Gev_normal+"/kess_pk_cs_e3_001_delta.dat")
# Gev_fld_phi_z50=np.loadtxt("./"+Gev_normal+"/kess_pk_cs_e3_001_phi.dat")

# %% [markdown]
# # Background and cosmological parameters

# %%
plt.figure(figsize=(15,15))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)


string=r"$N_{grid} =1920, boxsize= 1600.0 \,, \, nKe_numsteps=10 \, , \, time step limit = 0.04$";

plt.figure(1)
#####################
#####################
#####################
#Blue,red,purple,olivedrab,darkblue,salmon,blueviolet,yellowgreen

#SubplotI Check the pi in class and Gevolution
# Hconf*pi comparison
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 12)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 12)
# plt.loglog(Gev_lin_delta_m_z100[:,0], Gev_lin_delta_m_z100[:,1],color="red",linestyle='dashed',lw=1.5,  label=r"$\delta_{m}$,kessence,  z=100 ")
plt.loglog(Gev_lin_delta_m_z50[:,0], Gev_lin_delta_m_z50[:,1],color="magenta",linestyle='dashed',lw=1.5,  label=r"$\delta_{m}$,kessence,  z=50 ")

#Class
# plt.loglog(Gev_lin_deltakess_z10[:,0], Class_power_z100[:,3],color="blue",linestyle='solid',lw=1.5,label=r"$\delta_{kess}$ class z=100 ")
# plt.loglog(Gev_lin_deltakess_z_all[0][:,0], np.abs(Class_Matter_power_z_all[:,0]),color="green",linestyle='solid',lw=1.5,label=r"$\delta_{m}$ class z=100 ")

# plt.loglog(Gev_fld_delta_z100[:,0], Gev_fld_delta_z100[:,1],color="green",linestyle='dashed',lw=1.5,label=r"$Gev Normal$  z=100 ")
plt.loglog(Gev_fld_delta_z50[:,0], Gev_fld_delta_z50[:,1],color="blue",linestyle='dashed',lw=1.5,label=r"$Gev Normal$  z=50 ")

# plt.loglog(Juliandelta_m[:,0], Juliandelta_m[:,1],color="purple",linestyle='dashed',lw=1.5,label=r"$Julian$  z=100 ")

#Fluid
# plt.loglog(Gev_fld_delta_z100[:,0], Gev_fld_delta_z100[:,1],color="blue",linestyle='solid',lw=1.5,label=r"$\delta_{m}$ Julian z=100 ")


# lt.axvline(x=Hubble_conf_Mpc(a_all[i])/h, color='brown', linestyle='-',label=r"Hubble-horizon")
# plt.axvline(x=Hubble_conf_Mpc(a_all[i])/np.sqrt(cs2_e3)/h, color='tomato', linestyle='-',label=r"Sound-horizon")
# # plt.axvline(x=Hubble_conf_Mpc(a_all[0])/np.sqrt(cs2_e3)/h, color='firebrick', linestyle='-',label=r"sound-horizon (z="+str(z_list[0])+")")#a_all[2] z=10
# plt.axvline(x=Hubble_conf_Mpc(a_all[2])/np.sqrt(cs2_e3)/h, color='brown', linestyle='-',label=r"sound-horizon (z="+str(z_list[2])+")")#a_all[2] z=10
# plt.axvline(x=Hubble_conf_Mpc(a_all[5])/np.sqrt(cs2_e3)/h, color='tomato', linestyle='-',label=r"sound-horizon(z="+str(z_list[5])+")")    

plt.legend(bbox_to_anchor=(0.1, 0.80, 0.3, .102), loc=1,ncol=1,fontsize=10, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=14)
plt.ylabel(r"$\mathcal{P} $",fontsize=14)
# plt.xlim(0.01,5.e-1)
# plt.ylim(1.e-15,1.e-9)
plt.grid(True)
plt.title(string)


# plt.savefig('./Gev-Class_Images/Kessence_evolution_Ngrid_1912.jpg', format='jpg', dpi=100)
plt.show()

# %%
plt.figure(figsize=(15,15))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)


string=r"$N_{grid} =1920, boxsize= 1600.0 \,, \, nKe_numsteps=10 \, , \, time step limit = 0.04$";

plt.figure(1)
#####################
#####################
#####################
#Blue,red,purple,olivedrab,darkblue,salmon,blueviolet,yellowgreen

#SubplotI Check the pi in class and Gevolution
# Hconf*pi comparison
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 12)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 12)
# plt.loglog(Gev_lin_delta_m_z100[:,0], Gev_lin_delta_m_z100[:,1],color="red",linestyle='dashed',lw=1.5,  label=r"$\delta_{m}$,kessence,  z=100 ")
plt.loglog(Gev_lin_phi_z50[:,0], Gev_lin_phi_z50[:,1],color="magenta",linestyle='dashed',lw=1.5,  label=r"$\Phi$,kessence,  z=100 ")

#Class
# plt.loglog(Gev_lin_deltakess_z10[:,0], Class_power_z100[:,3],color="blue",linestyle='solid',lw=1.5,label=r"$\delta_{kess}$ class z=100 ")
# plt.loglog(Gev_lin_deltakess_z_all[0][:,0], np.abs(Class_Matter_power_z_all[:,0]),color="green",linestyle='solid',lw=1.5,label=r"$\delta_{m}$ class z=100 ")

# plt.loglog(Gev_fld_delta_z100[:,0], Gev_fld_delta_z100[:,1],color="green",linestyle='dashed',lw=1.5,label=r"$Gev Normal$  z=100 ")
plt.loglog(Gev_fld_phi_z50[:,0], Gev_fld_phi_z50[:,1],color="blue",linestyle='dashed',lw=1.5,label=r"$Gev Normal$  z=100 ")

# plt.loglog(Juliandelta_m[:,0], Juliandelta_m[:,1],color="purple",linestyle='dashed',lw=1.5,label=r"$Julian$  z=100 ")

#Fluid
# plt.loglog(Gev_fld_delta_z100[:,0], Gev_fld_delta_z100[:,1],color="blue",linestyle='solid',lw=1.5,label=r"$\delta_{m}$ Julian z=100 ")


# lt.axvline(x=Hubble_conf_Mpc(a_all[i])/h, color='brown', linestyle='-',label=r"Hubble-horizon")
# plt.axvline(x=Hubble_conf_Mpc(a_all[i])/np.sqrt(cs2_e3)/h, color='tomato', linestyle='-',label=r"Sound-horizon")
# # plt.axvline(x=Hubble_conf_Mpc(a_all[0])/np.sqrt(cs2_e3)/h, color='firebrick', linestyle='-',label=r"sound-horizon (z="+str(z_list[0])+")")#a_all[2] z=10
# plt.axvline(x=Hubble_conf_Mpc(a_all[2])/np.sqrt(cs2_e3)/h, color='brown', linestyle='-',label=r"sound-horizon (z="+str(z_list[2])+")")#a_all[2] z=10
# plt.axvline(x=Hubble_conf_Mpc(a_all[5])/np.sqrt(cs2_e3)/h, color='tomato', linestyle='-',label=r"sound-horizon(z="+str(z_list[5])+")")    

plt.legend(bbox_to_anchor=(0.1, 0.80, 0.3, .102), loc=1,ncol=1,fontsize=10, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=14)
plt.ylabel(r"$\mathcal{P} $",fontsize=14)
# plt.xlim(0.01,5.e-1)
# plt.ylim(1.e-15,1.e-9)
plt.grid(True)
plt.title(string)


# plt.savefig('./Gev-Class_Images/Kessence_evolution_Ngrid_1912.jpg', format='jpg', dpi=100)
plt.show()

# %%
#################################
#################################
# Cosmological parameters.
As=2.215*1.e-9;
h=0.67556;
kp=0.05/h; 
ns=0.9619;
cs2_e3=1.e-6;
c=2.99792458*1.e5; #Km/s
# Boxsize=320.;
# c_gev=2997.92458; #[100km/s]
# H0_conf_Gev=np.sqrt(Boxsize**2/c**2); #0.10677 rho_crit in Gev=1
H0=100*h/c; #H0 in 1/Mpc unit. 0.00022593979933110373
# print("H0[1/Mpc]=100h/c: ",H0);
w=-0.9;
print("H0[1/Mpc]=100h/c: ",H0);
def Hubble_conf_Mpc(a):
    c=2.99792458*1.e5;h=0.67556;H0=100*h/c;w=-0.9;
    Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
    Omega_m=Omega_b+Omega_cdm; Omega_Lambda=0;
    Omega_rad=9.1671353942930788e-05; Omega_kessence=1.-Omega_m-Omega_rad;
    return H0*np.sqrt(Omega_m*(a**-3)+Omega_rad*(a**-4)+Omega_kessence*(a**(-3*(1+w))))*a
Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
Omega_m=Omega_b + Omega_cdm;
z_all=[99.597220, 48.322258, 9.951253, 5.808126, 0.988975, 0.]
z_list=[100, 50, 10, 6, 1, 0]
# List of scale factor
a100=(1./(1.+z_all[0])); a50=(1./(1.+z_all[1])); a10=(1./(1.+z_all[2])); a6=(1./(1.+z_all[3]));
a1=(1./(1.+z_all[4])); a0=(1./(1.+z_all[5]));
a_all=[a100,a50,a10,a6,a1,a0]
H_conf_z100=Hubble_conf_Mpc(1./(1.+z_all[0])); # Unit=1/Mpc Hconf=a*H
H_conf_z50=Hubble_conf_Mpc(1./(1.+z_all[1])); # Unit=1/Mpc Hconf=a*H
H_conf_z10=Hubble_conf_Mpc(1./(1.+z_all[2])); # Unit=1/Mpc Hconf=a*H
H_conf_z6=Hubble_conf_Mpc(1./(1.+z_all[3])); # Unit=1/Mpc Hconf=a*H
H_conf_z1=Hubble_conf_Mpc(1./(1.+z_all[4])); # Unit=1/Mpc Hconf=a*H
H_conf_z0=Hubble_conf_Mpc(1./(1.+z_all[5])); # Unit=1/Mpc Hconf=a*H
H_conf_zall_list=[H_conf_z100, H_conf_z50, H_conf_z10,
                  H_conf_z6, H_conf_z1, H_conf_z0];
# Out:
# ('H0[1/Mpc]=100h/c: ', 0.00022534256015206366)

# %% [markdown]
# # Class extrapolation

# %%
# #################################
# #Making power of phi_prime field to compare with Gev
# interp_class_phiprime_z100 =interp1d(class_phi_prime_z100[:,0],class_phi_prime_z100[:,2])
# interp_class_phiprime_z50 =interp1d(class_phi_prime_z50[:,0],class_phi_prime_z50[:,2])
# interp_class_phiprime_z10 =interp1d(class_phi_prime_z10[:,0],class_phi_prime_z10[:,2])
# interp_class_phiprime_z6 =interp1d(class_phi_prime_z6[:,0],class_phi_prime_z6[:,2])
# interp_class_phiprime_z1 =interp1d(class_phi_prime_z1[:,0],class_phi_prime_z1[:,2])
# interp_class_phiprime_z0 =interp1d(class_phi_prime_z0[:,0],class_phi_prime_z0[:,2])

# Class_power_phiprime_z100=As*((interp_class_phiprime_z100(Gev_lin_phi_prime_z100[:,0]))**2)*((Gev_lin_phi_prime_z100[:,0]/kp)**(ns-1.));
# Class_power_phiprime_z50=As*((interp_class_phiprime_z50(Gev_lin_phi_prime_z50[:,0]))**2)*((Gev_lin_phi_prime_z50[:,0]/kp)**(ns-1.));
# Class_power_phiprime_z10=As*((interp_class_phiprime_z10(Gev_lin_phi_prime_z10[:,0]))**2)*((Gev_lin_phi_prime_z10[:,0]/kp)**(ns-1.));
# Class_power_phiprime_z6=As*((interp_class_phiprime_z6(Gev_lin_phi_prime_z6[:,0]))**2)*((Gev_lin_phi_prime_z6[:,0]/kp)**(ns-1.));
# Class_power_phiprime_z1=As*((interp_class_phiprime_z1(Gev_lin_phi_prime_z1[:,0]))**2)*((Gev_lin_phi_prime_z1[:,0]/kp)**(ns-1.));
# Class_power_phiprime_z0=As*((interp_class_phiprime_z0(Gev_lin_phi_prime_z0[:,0]))**2)*((Gev_lin_phi_prime_z0[:,0]/kp)**(ns-1.));
# Class_power_phiprime_z_all=[Class_power_phiprime_z100,Class_power_phiprime_z50,
#                             Class_power_phiprime_z10,Class_power_phiprime_z6,Class_power_phiprime_z1,Class_power_phiprime_z0]

# #Making power of class field to compare with Gev
# Class_power_z100=np.zeros((np.shape(Gev_lin_deltakess_z100)[0],8))
# Class_power_z50=np.zeros((np.shape(Gev_lin_deltakess_z50)[0],8))
# Class_power_z10=np.zeros((np.shape(Gev_lin_deltakess_z10)[0],8))
# Class_power_z6=np.zeros((np.shape(Gev_lin_deltakess_z6)[0],8))
# Class_power_z1=np.zeros((np.shape(Gev_lin_deltakess_z1)[0],8))
# Class_power_z0=np.zeros((np.shape(Gev_lin_deltakess_z0)[0],8))
# Class_Matter_power_z_all=np.zeros((np.shape(Gev_lin_delta_m_z100)[0],6))


# # Making interpolation, for delta!
# for i in range (1,7):
#     interp_class_100 =interp1d(class_newt_z100[:,0],class_newt_z100[:,i])
#     interp_class_50 =interp1d(class_newt_z50[:,0],class_newt_z50[:,i])
#     interp_class_10 =interp1d(class_newt_z10[:,0],class_newt_z10[:,i])
#     interp_class_6 =interp1d(class_newt_z6[:,0],class_newt_z6[:,i])
#     interp_class_1 =interp1d(class_newt_z1[:,0],class_newt_z1[:,i])
#     interp_class_0 =interp1d(class_newt_z0[:,0],class_newt_z0[:,i])
    
#     Class_power_z100[:,i]=As*((interp_class_100(Gev_lin_deltakess_z100[:,0]))**2)*((Gev_lin_deltakess_z100[:,0]/kp)**(ns-1.));
#     Class_power_z50[:,i]=As*((interp_class_50(Gev_lin_deltakess_z50[:,0]))**2)*((Gev_lin_deltakess_z50[:,0]/kp)**(ns-1.));
#     Class_power_z10[:,i]=As*((interp_class_10(Gev_lin_deltakess_z10[:,0]))**2)*((Gev_lin_deltakess_z10[:,0]/kp)**(ns-1.));
#     Class_power_z6[:,i]=As*((interp_class_6(Gev_lin_deltakess_z6[:,0]))**2)*((Gev_lin_deltakess_z6[:,0]/kp)**(ns-1.));
#     Class_power_z1[:,i]=As*((interp_class_1(Gev_lin_deltakess_z1[:,0]))**2)*((Gev_lin_deltakess_z1[:,0]/kp)**(ns-1.));
#     Class_power_z0[:,i]=As*((interp_class_0(Gev_lin_deltakess_z0[:,0]))**2)*((Gev_lin_deltakess_z0[:,0]/kp)**(ns-1.));

# # Class_power_z_all=[Class_power_z100,Class_power_z50,Class_power_z10,Class_power_z6,Class_power_z1,Class_power_z0]
# # #np.shape(Class_power_z_all)

# # ##############################
# # ###POISSON EQUATION Gevolution
# # ##############################
# # #Making power of class field to compare with Gev. dimensionless power of phi from matter power!
# # phi_Gev_poisson_zall=np.zeros((np.shape(Gev_lin_deltakess_z100)[0],6))
# for i in range (0,6):
#     C_poiss=(9./4.)* (Omega_m)**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4);
# #     phi_Gev_poisson_zall[:,i]=C_poiss* (a_all[i]**-1)**2 * Gev_lin_delta_m_z_all[i][:,1]/((Gev_lin_delta_m_z_all[i][:,0]*h)**4);
# # phi_class_poisson_z100= phi_class_poisson_zall[:,0]
# # phi_class_poisson_z10= phi_class_poisson_zall[:,2]
# # plt.loglog(Gev_lin_deltakess_z100[:,0],phi_class_poisson_zall[:,3] )
# # plt.loglog(Gev_lin_deltakess_z100[:,0],Class_power_z6[:,5] )
# # plt.show()


# # ###########################
# # ###POISSON EQUATION CLASS #
# # ###########################
# # #Making power of class field to compare with Gev. dimensionless power of phi from matter power!
# # #k^3/2 pi^2 to make Class power dimensionless
# # phi_class_poisson_zall=np.zeros((np.shape(Gev_lin_deltakess_z100)[0],6))
# for i in range (0,6):
#     interp_class_matter_power=interp1d(class_matter_pow_zall[i][:,0],class_matter_pow_zall[i][:,1])
# #     interp_class_phi_poisson =interp1d(class_matter_pow_zall[i][:,0],class_matter_pow_zall[i][:,1])
#     C_poiss=(9./4.)* (Omega_m)**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)/(2.*np.pi**2);
    
# #     #dimensionless class matter power, Class_Matter_power_z_all[:,0] ->z=100
#     Class_Matter_power_z_all[:,i] = (Gev_lin_delta_m_z100[:,0])**3* interp_class_matter_power(Gev_lin_delta_m_z100[:,0])/(2.*np.pi**2)
# #     phi_class_poisson_zall[:,i]=C_poiss* (a_all[i]**-1)**2 * (Gev_lin_deltakess_z_all[i][:,0])**3* interp_class_phi_poisson(Gev_lin_deltakess_z_all[i][:,0])/((Gev_lin_deltakess_z_all[i][:,0]*h)**4);
# # phi_class_poisson_z100= phi_class_poisson_zall[:,0]
# # phi_class_poisson_z10= phi_class_poisson_zall[:,2]
# #Class TEST
# # plt.loglog(Gev_lin_deltakess_z100[:,0],phi_class_poisson_zall[:,3] )
# # plt.loglog(Gev_lin_deltakess_z100[:,0],Class_power_z6[:,5] )

# #Gev Poisson TEST
# # i=0
# # plt.loglog(Gev_lin_phi_z_all[i][:,0],phi_Gev_poisson_zall[:,0] )
# # plt.loglog(Gev_lin_phi_z_all[i][:,0],Gev_lin_phi_z_all[i][:,1] )

# #Matter power TEST
# # plt.loglog(Gev_lin_phi_z_all[i][:,0],Gev_lin_delta_m_z_all[0][:,1] )
# # plt.loglog(Gev_lin_phi_z_all[i][:,0],Class_Matter_power_z_all[:,0] )

# # plt.show()

# %% [markdown]
# # Check power at ini redshift and low k
