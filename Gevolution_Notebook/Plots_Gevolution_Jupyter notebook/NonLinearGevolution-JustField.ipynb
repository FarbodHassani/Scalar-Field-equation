# %% [markdown]
# # Notebook for comparison beween Non-linear Gevolution and class and agreement between class and hi-class

# %%
import numpy as np
import matplotlib.pylab as plt
from scipy.interpolate import interp1d
from pylab import rcParams
# tableau12 = [(0, 0, 0), (50, 0, 0), (0, 50, 0), (0, 0, 50),    
#              (0, 50, 50), (50, 50, 0), (50, 0, 50), (50, 50, 50),    
#              (100, 50, 50), (50, 100, 50), (50, 50, 100), (100, 100, 100)]    
  
# # Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.    
# for i in range(len(tableau12)):    
#     r, g, b = tableau12[i]    
#     tableau12[i] = (r / 255., g / 255., b / 255.) 
    
# tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),    
#              (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),    
#              (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),    
#              (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),    
#              (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]    
  
# # Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.    
# for i in range(len(tableau20)):    
#     r, g, b = tableau20[i]    
#     tableau20[i] = (r / 255., g / 255., b / 255.)
# # plt.style.available
# plt.rcParams.update(plt.rcParamsDefault)

# # plt.style.use('seaborn-paper')
# plt.rcParams['font.serif'] = 'Ubuntu'

# %% [markdown]
# # Gevolution Nonlinear and class reading

# %%
# Gevolution Linear
addressGev="Gevolution_outputs/2018.07.04.14.15.58";
# addressGev2="Daint_Runs/NL_Kess_Ngrid_1296_DT_0.01_output";

# addressGev3="Daint_Runs/NL_Kess_Ngrid_1296_DT_0.005_output";
addressGev2="Gevolution_outputs/2018.07.04.14.03.57";


########
# z=100
########
Gev_nl_deltakess_z100=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_000_delta_kess.dat")
Gev_nl_zeta_z100=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_000_zeta.dat")
Gev_nl_Hpi_z100=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_000_pi_k.dat")
Gev_nl_delta_m_z100=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_000_delta.dat")
Gev_nl_phi_z100=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_000_phi.dat")
Gev_nl_phi_prime_z100=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_000_phi_prime.dat")

########
# z=50
########
Gev_nl_deltakess_z50=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_001_delta_kess.dat")
Gev_nl_zeta_z50=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_001_zeta.dat")
Gev_nl_Hpi_z50=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_001_pi_k.dat")
Gev_nl_delta_m_z50=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_001_delta.dat")
Gev_nl_phi_z50=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_001_phi.dat")
Gev_nl_phi_prime_z50=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_001_phi_prime.dat")


########
# z=100
########
# Gev2_nl_deltakess_z100=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_000_delta_kess.dat")
Gev2_nl_zeta_z100=np.loadtxt("./"+addressGev2+"/kess_pk_cs_e3_000_zeta.dat")
Gev2_nl_Hpi_z100=np.loadtxt("./"+addressGev2+"/kess_pk_cs_e3_000_pi_k.dat")


# Gev2_nl_delta_m_z100=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_000_delta.dat")
# Gev2_nl_phi_z100=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_000_phi.dat")
# Gev2_nl_phi_prime_z100=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_000_phi_prime.dat")

########
# z=50
########
# Gev2_nl_deltakess_z50=np.loadtxt("./"+addressGev2+"/kess_pk_cs_e3_001_delta_kess.dat")
Gev2_nl_zeta_z50=np.loadtxt("./"+addressGev2+"/kess_pk_cs_e3_001_zeta.dat")
Gev2_nl_Hpi_z50=np.loadtxt("./"+addressGev2+"/kess_pk_cs_e3_001_pi_k.dat")

# Gev2_nl_zeta_z10=np.loadtxt("./"+addressGev2+"/kess_pk_cs_e3_002_zeta.dat")
# Gev2_nl_Hpi_z10=np.loadtxt("./"+addressGev2+"/kess_pk_cs_e3_002_pi_k.dat")


########
# z=100
########
# # # Gev2_nl_deltakess_z100=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_000_delta_kess.dat")
# Gev3_nl_zeta_z100=np.loadtxt("./"+addressGev3+"/kess_pk_cs_e3_000_zeta.dat")
# Gev3_nl_Hpi_z100=np.loadtxt("./"+addressGev3+"/kess_pk_cs_e3_000_pi_k.dat")
# # ########
# # # z=50
# # ########
# Gev3_nl_zeta_z50=np.loadtxt("./"+addressGev3+"/kess_pk_cs_e3_001_zeta.dat")
# Gev3_nl_Hpi_z50=np.loadtxt("./"+addressGev3+"/kess_pk_cs_e3_001_pi_k.dat")

# # Gev3_nl_zeta_z10=np.loadtxt("./"+addressGev3+"/kess_pk_cs_e3_002_zeta.dat")
# # Gev3_nl_Hpi_z10=np.loadtxt("./"+addressGev3+"/kess_pk_cs_e3_002_pi_k.dat")
# # # Gev2_nl_deltakess_z100=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_000_delta_kess.dat")
# Gev4_nl_zeta_z100=np.loadtxt("./"+addressGev4+"/kess_pk_cs_e3_000_zeta.dat")
# Gev4_nl_Hpi_z100=np.loadtxt("./"+addressGev4+"/kess_pk_cs_e3_000_pi_k.dat")
# ########
# # z=50
# ########
# Gev4_nl_zeta_z50=np.loadtxt("./"+addressGev3+"/kess_pk_cs_e3_001_zeta.dat")
# Gev4_nl_Hpi_z50=np.loadtxt("./"+addressGev3+"/kess_pk_cs_e3_001_pi_k.dat")

########
# z=10
########
# Gev_nl_deltakess_z10=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_002_delta_kess.dat")
# Gev_nl_zeta_z10=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_002_zeta.dat")
# Gev_nl_Hpi_z10=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_002_pi_k.dat")
# Gev_nl_delta_m_z10=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_002_delta.dat")
# Gev_nl_phi_z10=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_002_phi.dat")
# Gev_nl_phi_prime_z10=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_002_phi_prime.dat")

# Gev4_nl_zeta_z_all=[Gev4_nl_zeta_z100, Gev4_nl_zeta_z50];
# #                    , Gev_nl_zeta_z10];
# #                          Gev_nl_zeta_z6, Gev_nl_zeta_z1, Gev_nl_zeta_z0];
# Gev4_nl_Hpi_z_all=[Gev4_nl_Hpi_z100, Gev4_nl_Hpi_z50];



# Gev3_nl_zeta_z_all=[Gev3_nl_zeta_z100, Gev3_nl_zeta_z50, Gev3_nl_zeta_z10];
# #                    , Gev_nl_zeta_z10];
# #                          Gev_nl_zeta_z6, Gev_nl_zeta_z1, Gev_nl_zeta_z0];
# Gev3_nl_Hpi_z_all=[Gev3_nl_Hpi_z100, Gev3_nl_Hpi_z50, Gev3_nl_Hpi_z10];

Gev2_nl_zeta_z_all=[Gev2_nl_zeta_z100, Gev2_nl_zeta_z50, Gev2_nl_zeta_z10];
#                    , Gev_nl_zeta_z10];
#                          Gev_nl_zeta_z6, Gev_nl_zeta_z1, Gev_nl_zeta_z0];
Gev2_nl_Hpi_z_all=[Gev2_nl_Hpi_z100, Gev2_nl_Hpi_z50, Gev2_nl_Hpi_z10];

# Gev_nl_deltakess_z_all=[Gev_nl_deltakess_z100, Gev_nl_deltakess_z50];
#                         , Gev_nl_deltakess_z10];
#                          Gev_nl_deltakess_z6, Gev_nl_deltakess_z1, Gev_nl_deltakess_z0];
Gev_nl_zeta_z_all=[Gev_nl_zeta_z100, Gev_nl_zeta_z50, Gev_nl_zeta_z50];
#                    , Gev_nl_zeta_z10];
#                          Gev_nl_zeta_z6, Gev_nl_zeta_z1, Gev_nl_zeta_z0];
Gev_nl_Hpi_z_all=[Gev_nl_Hpi_z100, Gev_nl_Hpi_z50, Gev_nl_Hpi_z50];
#                   , Gev_nl_Hpi_z10];
#                          Gev_nl_Hpi_z6, Gev_nl_Hpi_z1, Gev_nl_Hpi_z0];
# Gev_nl_delta_m_z_all=[Gev_nl_delta_m_z100, Gev_nl_delta_m_z50];
#                       , Gev_nl_delta_m_z10]
#                          Gev_nl_delta_m_z6, Gev_nl_delta_m_z1, Gev_nl_delta_m_z0];
# Gev_nl_phi_prime_z_all=[Gev_nl_phi_prime_z100, Gev_nl_phi_prime_z50];
# , Gev_nl_phi_prime_z10]
#                          Gev_nl_phi_prime_z6, Gev_nl_phi_prime_z1, Gev_nl_phi_prime_z0];
# Gev_nl_phi_z_all=[Gev_nl_phi_z100, Gev_nl_phi_z50];
#                   , Gev_nl_phi_z10]
#                          Gev_nl_phi_z6, Gev_nl_phi_z1, Gev_nl_phi_z0];

#class:
#class powerspectra
addressClass="./Making_IC_Class"
class_newt_z100=np.loadtxt(addressClass+"/Class_kess_cs_e3_z100_newt_Gev.dat")
class_newt_z50=np.loadtxt(addressClass+"/Class_kess_cs_e3_z50_newt_Gev.dat")
class_newt_z10=np.loadtxt(addressClass+"/Class_kess_cs_e3_z10_newt_Gev.dat")
# class_newt_z6=np.loadtxt(addressClass+"/Class_kess_cs_e3_z6_newt_Gev.dat")
# class_newt_z1=np.loadtxt(addressClass+"/Class_kess_cs_e3_z1_newt_Gev.dat")
# class_newt_z0=np.loadtxt(addressClass+"/Class_kess_cs_e3_z0_newt_Gev.dat")
class_z_all=[class_newt_z100, class_newt_z50, class_newt_z10]
#              class_newt_z6, class_newt_z1, class_newt_z0];
#Phi_prime
class_phi_prime_z100=np.loadtxt(addressClass+"/Kessence_field_class_phi_prime_z99.dat")
class_phi_prime_z50=np.loadtxt(addressClass+"/Kessence_field_class_phi_prime_z50.dat")
class_phi_prime_z10=np.loadtxt(addressClass+"/Kessence_field_class_phi_prime_z10.dat")
# class_phi_prime_z6=np.loadtxt(addressClass+"/Kessence_field_class_phi_prime_z6.dat")
# class_phi_prime_z1=np.loadtxt(addressClass+"/Kessence_field_class_phi_prime_z1.dat")
# class_phi_prime_z0=np.loadtxt(addressClass+"/Kessence_field_class_phi_prime_z0.dat")
# class_phi_prime_z_all=[class_phi_prime_z100,class_phi_prime_z50,class_phi_prime_z10,
#                        class_phi_prime_z6,class_phi_prime_z1,class_phi_prime_z0]
#Backgrounds:
Class_Bg_newt_cs_e3=np.loadtxt(addressClass+"/class_kess_cs_e3_newt_background.dat")
bg_Gevolution=np.loadtxt("./"+addressGev+"/kess_cs_e3_background.dat")

# %% [markdown]
# # Making dimensionless power

# %%
# params for makin power dimensionless
# H_0 in Gevolution unit.
h=0.67556
Boxsize=320.;
c=2997.; #[100km/s]
HGev=np.sqrt(Boxsize**2/c**2) #0.10677, H0 Gevolution in code's unit
def Hubble_conf_Mpc(a):
    H0=0.00022593979933110373;w=-0.9;h=0.67556;
    Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
    Omega_m=Omega_b+Omega_cdm; Omega_Lambda=0.0;
    Omega_rad=9.16681e-05; Omega_kessence=1.-Omega_m-Omega_rad;
    return H0*np.sqrt(Omega_m*(a**-3)+Omega_rad*(a**-4)+Omega_Lambda+Omega_kessence*(a**(-3*(1+w))))*a
z_all=[100, 50, 10, 6, 1, 0]
# List of scale factor
a100=(1./(1.+100.)); a50=(1./(1.+50.)); a10=(1./(1.+10.)); a6=(1./(1.+6.)); a1=(1./(1.+1.)); a0=(1./(1.+0.));
a_all=[a100,a50,a10,a6,a1,a0]
H_conf_z100=Hubble_conf_Mpc(1./(1.+100.)); # Unit=1/Mpc Hconf=a*H
H_conf_z50=Hubble_conf_Mpc(1./(1.+50.)); # Unit=1/Mpc Hconf=a*H
H_conf_z10=Hubble_conf_Mpc(1./(1.+10.)); # Unit=1/Mpc Hconf=a*H
H_conf_z6=Hubble_conf_Mpc(1./(1.+6.)); # Unit=1/Mpc Hconf=a*H
H_conf_z1=Hubble_conf_Mpc(1./(1.+1.)); # Unit=1/Mpc Hconf=a*H
H_conf_z0=Hubble_conf_Mpc(1./(1.+0.)); # Unit=1/Mpc Hconf=a*H
H_conf_zall_list=[H_conf_z100, H_conf_z50, H_conf_z10,
                  H_conf_z6, H_conf_z1, H_conf_z0];
z_list=[100, 50, 10, 6, 1, 0]
# List of scale factor
a100=(1./(1.+100.)); a50=(1./(1.+50.)); a10=(1./(1.+10.)); a6=(1./(1.+6.)); a1=(1./(1.+1.)); a0=(1./(1.+0.));
a_all=[a100,a50,a10,a6,a1,a0];
#################################
#################################
# Parameters for converting to dimensionless power.
As=2.19*10**-9;
h=0.67556
kp=0.05/h; 
ns=0.96;
cs2=1.e-6;
#################################
#Making power of phi_prime field to compare with Gev
interp_class_phiprime_z100 =interp1d(class_phi_prime_z100[:,0],class_phi_prime_z100[:,2])
interp_class_phiprime_z50 =interp1d(class_phi_prime_z50[:,0],class_phi_prime_z50[:,2])
interp_class_phiprime_z10 =interp1d(class_phi_prime_z10[:,0],class_phi_prime_z10[:,2])
# interp_class_phiprime_z6 =interp1d(class_phi_prime_z6[:,0],class_phi_prime_z6[:,2])
# interp_class_phiprime_z1 =interp1d(class_phi_prime_z1[:,0],class_phi_prime_z1[:,2])
# interp_class_phiprime_z0 =interp1d(class_phi_prime_z0[:,0],class_phi_prime_z0[:,2])

Class_power_phiprime_z100=As*((interp_class_phiprime_z100(Gev_nl_phi_prime_z100[:,0]))**2)*((Gev_nl_phi_prime_z100[:,0]/kp)**(ns-1.));
Class_power_phiprime_z50=As*((interp_class_phiprime_z50(Gev_nl_phi_prime_z50[:,0]))**2)*((Gev_nl_phi_prime_z50[:,0]/kp)**(ns-1.));
Class_power_phiprime_z10=As*((interp_class_phiprime_z10(Gev_nl_phi_prime_z10[:,0]))**2)*((Gev_nl_phi_prime_z10[:,0]/kp)**(ns-1.));
# Class_power_phiprime_z6=As*((interp_class_phiprime_z6(Gev_nl_phi_prime_z6[:,0]))**2)*((Gev_nl_phi_prime_z6[:,0]/kp)**(ns-1.));
# Class_power_phiprime_z1=As*((interp_class_phiprime_z1(Gev_nl_phi_prime_z1[:,0]))**2)*((Gev_nl_phi_prime_z1[:,0]/kp)**(ns-1.));
# Class_power_phiprime_z0=As*((interp_class_phiprime_z0(Gev_nl_phi_prime_z0[:,0]))**2)*((Gev_nl_phi_prime_z0[:,0]/kp)**(ns-1.));
Class_power_phiprime_z_all=[Class_power_phiprime_z100,Class_power_phiprime_z50,Class_power_phiprime_z10];
# ,Class_power_phiprime_z6,Class_power_phiprime_z1,Class_power_phiprime_z0]

#Making power of class field to compare with Gev
Class_power_z100=np.zeros((np.shape(Gev_nl_deltakess_z100)[0],8))
Class_power_z50=np.zeros((np.shape(Gev_nl_deltakess_z50)[0],8))
Class_power_z10=np.zeros((np.shape(Gev_nl_deltakess_z10)[0],8))
# Class_power_z6=np.zeros((np.shape(Gev_nl_deltakess_z6)[0],8))
# Class_power_z1=np.zeros((np.shape(Gev_nl_deltakess_z1)[0],8))
# Class_power_z0=np.zeros((np.shape(Gev_nl_deltakess_z0)[0],8))

# Making interpolation, for delta!
for i in range (1,7):
    interp_class_100 =interp1d(class_newt_z100[:,0],class_newt_z100[:,i])
    interp_class_50 =interp1d(class_newt_z50[:,0],class_newt_z50[:,i])
    interp_class_10 =interp1d(class_newt_z10[:,0],class_newt_z10[:,i])
#     interp_class_6 =interp1d(class_newt_z6[:,0],class_newt_z6[:,i])
#     interp_class_1 =interp1d(class_newt_z1[:,0],class_newt_z1[:,i])
#     interp_class_0 =interp1d(class_newt_z0[:,0],class_newt_z0[:,i])
    
    Class_power_z100[:,i]=As*((interp_class_100(Gev_nl_deltakess_z100[:,0]))**2)*((Gev_nl_deltakess_z100[:,0]/kp)**(ns-1.));
    Class_power_z50[:,i]=As*((interp_class_50(Gev_nl_deltakess_z50[:,0]))**2)*((Gev_nl_deltakess_z50[:,0]/kp)**(ns-1.));
    Class_power_z10[:,i]=As*((interp_class_10(Gev_nl_deltakess_z10[:,0]))**2)*((Gev_nl_deltakess_z10[:,0]/kp)**(ns-1.));
#     Class_power_z6[:,i]=As*((interp_class_6(Gev_nl_deltakess_z6[:,0]))**2)*((Gev_nl_deltakess_z6[:,0]/kp)**(ns-1.));
#     Class_power_z1[:,i]=As*((interp_class_1(Gev_nl_deltakess_z1[:,0]))**2)*((Gev_nl_deltakess_z1[:,0]/kp)**(ns-1.));
#     Class_power_z0[:,i]=As*((interp_class_0(Gev_nl_deltakess_z0[:,0]))**2)*((Gev_nl_deltakess_z0[:,0]/kp)**(ns-1.));
Class_power_z_all=[Class_power_z100,Class_power_z50,Class_power_z10];
#                    Class_power_z6,Class_power_z1,Class_power_z0]
#np.shape(Class_power_z_all)

# %%
np.shape(Class_power_z50)
# Out:
# (1000, 8)

# %% [markdown]
# # Linear Class vs Linear Gevolution kessence_source_gravity= 1

# %%
# plt.figure(figsize=(30,30))
# ax = plt.gca()
# ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
# ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)

#Class Hubble factor, H in unit 1/Mpc!
# It is phsyical hubble, to make it conformal need to multiply to a. Hconf = H_phys * a
H_conf_z100=Hubble_conf_Mpc(1./(1.+100.)); # Unit=1/Mpc Hconf=a*H
H_conf_z50=Hubble_conf_Mpc(1./(1.+50.)); # Unit=1/Mpc Hconf=a*H
H_conf_z10=Hubble_conf_Mpc(1./(1.+10.)); # Unit=1/Mpc Hconf=a*H
H_conf_z6=Hubble_conf_Mpc(1./(1.+6.)); # Unit=1/Mpc Hconf=a*H
H_conf_z1=Hubble_conf_Mpc(1./(1.+1.)); # Unit=1/Mpc Hconf=a*H
H_conf_z0=Hubble_conf_Mpc(1./(1.+0.)); # Unit=1/Mpc Hconf=a*H
H_conf_zall_list=[H_conf_z100, H_conf_z50, H_conf_z10,
                  H_conf_z6, H_conf_z1, H_conf_z0];

# Theta Calculation Theta = pi * k^2
# Gev_nl_theta_z_all=np.zeros((np.shape(Gev_nl_Hpi_z100)[0],6))
cs2_e3=1.e-6;
# Making interpolation, for delta!
# for i in range (0,1):
#     Gev_nl_theta_z_all[:,i] =Gev_nl_Hpi_z_all[i][:,1] * (Gev_nl_Hpi_z_all[i][:,0]*h)**4/(H_conf_zall_list[i]**2)


string=r"$ N_{grid} =256, boxsize= 1600.0, \, nKe_numsteps=10, \, time step limit = 0.04, \, $ Kessence source gravity= 0, NL_kessence = 1";
plt.figure(figsize=(20,25))

for i in range (0,2):
    print(i)
    plt.subplot(310+(i+1))
    ax = plt.gca()
    ax.tick_params(axis = 'both', which = 'major', labelsize = 16)
    ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)
    plt.figure(1)
    plt.title(string)
    
    #     plt.loglog(Gev_nl_deltakess_z100[:,0], Gev_nl_theta_z_all[:,i],color="darkblue",linestyle='dashed',lw=1.5, label=r"$\theta$, Gevolution-NL, z="+str(z_list[i]))
    plt.loglog(Gev_nl_Hpi_z_all[i][:,0], Gev_nl_Hpi_z_all[i][:,1],color="red",linestyle='dashed',lw=1.5,  label=r"$\pi \mathcal{H}$, Gevolution-NL, z="+str(z_list[i]))
    plt.loglog(Gev_nl_zeta_z_all[i][:,0], Gev_nl_zeta_z_all[i][:,1],color="green",linestyle='dashed',lw=1.5, label=r"$\zeta$, Gevolution-NL, $d\tau =0.04$, z="+str(z_list[i]))
    
    plt.loglog(Gev2_nl_Hpi_z_all[i][:,0], Gev2_nl_Hpi_z_all[i][:,1],color="blue",linestyle='dashed',lw=1.5,  label=r"$\pi \mathcal{H}$, Just $c_s^2$ NL terms, z="+str(z_list[i]))
    plt.loglog(Gev2_nl_zeta_z_all[i][:,0], Gev2_nl_zeta_z_all[i][:,1],color="brown",linestyle='dashed',lw=1.5, label=r"$\zeta$, Just $c_s^2$ NL terms, z="+str(z_list[i]))

#     plt.loglog(Gev3_nl_Hpi_z_all[i][:,0], Gev3_nl_Hpi_z_all[i][:,1],color="deeppink",linestyle='dashed',lw=1.5,  label=r"$\pi \mathcal{H}$, Gevolution-NL, $d\tau =0.005$, z="+str(z_list[i]))
#     plt.loglog(Gev3_nl_zeta_z_all[i][:,0], Gev3_nl_zeta_z_all[i][:,1],color="darkmagenta",linestyle='dashed',lw=1.5, label=r"$\zeta$, Gevolution-NL, $d\tau =0.005$, z="+str(z_list[i]))

    
#     plt.loglog(Gev4_nl_Hpi_z_all[i][:,0], Gev4_nl_Hpi_z_all[i][:,1],color="crimson",linestyle='dashed',lw=1.5,  label=r"$\pi \mathcal{H}$, Gevolution-NL, $N_{grid} =128$, z="+str(z_list[i]))
#     plt.loglog(Gev4_nl_zeta_z_all[i][:,0], Gev4_nl_zeta_z_all[i][:,1],color="plum",linestyle='dashed',lw=1.5, label=r"$\zeta$, Gevolution-NL, $N_{grid} =128$, z="+str(z_list[i]))

    # Class 
    #     plt.loglog(Gev_nl_Hpi_z_all[i][:,0], Class_power_z_all[i][:,4],color="blue",linestyle='solid',lw=1.5,label=r"$\theta$ class z="+str(z_list[i]))
    plt.loglog(Gev_nl_Hpi_z_all[i][:,0], Class_power_z_all[i][:,1]*H_conf_zall_list[i]**2,color="salmon",linestyle='solid',lw=1.5,label=r"$\pi \mathcal{H}$ class, z="+str(z_list[i]))
    plt.loglog(Gev_nl_Hpi_z_all[i][:,0], Class_power_z_all[i][:,2],color="blueviolet",linestyle='solid',lw=1.5,label=r"$\zeta$, class z="+str(z_list[i]))
    #salmon blueviolet
    plt.axvline(x=Hubble_conf_Mpc(a_all[i])/h, color='brown', linestyle='-',label=r"Hubble-horizon")
    plt.axvline(x=Hubble_conf_Mpc(a_all[i])/np.sqrt(cs2_e3)/h, color='tomato', linestyle='-',label=r"Sound-horizon")

    #     plt.title(string)
    plt.legend(bbox_to_anchor=(0.0, 0.30, 0.4, .102), loc=1,ncol=1,fontsize=10, mode="expand", borderaxespad=0.)
    plt.xlabel("k[h/Mpc]",fontsize=16)
    plt.ylabel(r"$\mathcal{P} $",fontsize=16)
    # plt.xlim(0.01,5.e-1)
    #     plt.ylim(2.e-14,1.e-7)
    plt.grid(True)

plt.savefig("NL_test_004_solver.jpg", format='jpg', dpi=100)
plt.show()
# Out:
# 0
# 1

# %%
# plt.figure(figsize=(30,30))
# ax = plt.gca()
# ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
# ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)

#Class Hubble factor, H in unit 1/Mpc!
# It is phsyical hubble, to make it conformal need to multiply to a. Hconf = H_phys * a
H_conf_z100=Hubble_conf_Mpc(1./(1.+100.)); # Unit=1/Mpc Hconf=a*H
H_conf_z50=Hubble_conf_Mpc(1./(1.+50.)); # Unit=1/Mpc Hconf=a*H
H_conf_z10=Hubble_conf_Mpc(1./(1.+10.)); # Unit=1/Mpc Hconf=a*H
H_conf_z6=Hubble_conf_Mpc(1./(1.+6.)); # Unit=1/Mpc Hconf=a*H
H_conf_z1=Hubble_conf_Mpc(1./(1.+1.)); # Unit=1/Mpc Hconf=a*H
H_conf_z0=Hubble_conf_Mpc(1./(1.+0.)); # Unit=1/Mpc Hconf=a*H
H_conf_zall_list=[H_conf_z100, H_conf_z50, H_conf_z10,
                  H_conf_z6, H_conf_z1, H_conf_z0];

# Theta Calculation Theta = pi * k^2
# Gev_nl_theta_z_all=np.zeros((np.shape(Gev_nl_Hpi_z100)[0],6))
cs2_e3=1.e-6;
# Making interpolation, for delta!
# for i in range (0,1):
#     Gev_nl_theta_z_all[:,i] =Gev_nl_Hpi_z_all[i][:,1] * (Gev_nl_Hpi_z_all[i][:,0]*h)**4/(H_conf_zall_list[i]**2)


string=r"$ N_{grid} =1296, boxsize= 1600.0, \, nKe_numsteps=10, \, time step limit = 0.04, \, $ Kessence source gravity= 0, NL_kessence = 1";
plt.figure(figsize=(18,10))


# plt.subplot(310+(i+1))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 16)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)
plt.figure(1)
plt.title(string)
i=2
#     plt.loglog(Gev_nl_deltakess_z100[:,0], Gev_nl_theta_z_all[:,i],color="darkblue",linestyle='dashed',lw=1.5, label=r"$\theta$, Gevolution-NL, z="+str(z_list[i]))

plt.loglog(Gev2_nl_Hpi_z_all[i][:,0], Gev2_nl_Hpi_z_all[i][:,1],color="blue",linestyle='dashed',lw=1.5,  label=r"$\pi \mathcal{H}$, Gevolution-NL, $d\tau =0.01$, z="+str(z_list[i]))
plt.loglog(Gev2_nl_zeta_z_all[i][:,0], Gev2_nl_zeta_z_all[i][:,1],color="black",linestyle='dashed',lw=1.5, label=r"$\zeta$, Gevolution-NL, $d\tau =0.01$, z="+str(z_list[i]))

plt.loglog(Gev3_nl_Hpi_z_all[i][:,0], Gev3_nl_Hpi_z_all[i][:,1],color="deeppink",linestyle='dashed',lw=1.5,  label=r"$\pi \mathcal{H}$, Gevolution-NL, $d\tau =0.005$, z="+str(z_list[i]))
plt.loglog(Gev3_nl_zeta_z_all[i][:,0], Gev3_nl_zeta_z_all[i][:,1],color="pink",linestyle='dashed',lw=1.5, label=r"$\zeta$, Gevolution-NL, $d\tau =0.005$, z="+str(z_list[i]))


#     plt.loglog(Gev4_nl_Hpi_z_all[i][:,0], Gev4_nl_Hpi_z_all[i][:,1],color="crimson",linestyle='dashed',lw=1.5,  label=r"$\pi \mathcal{H}$, Gevolution-NL, $N_{grid} =128$, z="+str(z_list[i]))
#     plt.loglog(Gev4_nl_zeta_z_all[i][:,0], Gev4_nl_zeta_z_all[i][:,1],color="plum",linestyle='dashed',lw=1.5, label=r"$\zeta$, Gevolution-NL, $N_{grid} =128$, z="+str(z_list[i]))

# Class 
#     plt.loglog(Gev_nl_Hpi_z_all[i][:,0], Class_power_z_all[i][:,4],color="blue",linestyle='solid',lw=1.5,label=r"$\theta$ class z="+str(z_list[i]))
plt.loglog(Gev_nl_deltakess_z10[:,0], Class_power_z10[:,1]*H_conf_zall_list[i]**2,color="salmon",linestyle='solid',lw=1.5,label=r"$\pi \mathcal{H}$ class, z="+str(z_list[i]))
plt.loglog(Gev_nl_deltakess_z10[:,0], Class_power_z10[:,2],color="blueviolet",linestyle='solid',lw=1.5,label=r"$\zeta$, class z="+str(z_list[i]))
#salmon blueviolet
plt.axvline(x=Hubble_conf_Mpc(a_all[i])/h, color='brown', linestyle='-',label=r"Hubble-horizon")
plt.axvline(x=Hubble_conf_Mpc(a_all[i])/np.sqrt(cs2_e3)/h, color='tomato', linestyle='-',label=r"Sound-horizon")

#     plt.title(string)
plt.legend(bbox_to_anchor=(0.0, 0.30, 0.4, .102), loc=1,ncol=1,fontsize=10, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=16)
plt.ylabel(r"$\mathcal{P} $",fontsize=16)
# plt.xlim(0.01,5.e-1)
#     plt.ylim(2.e-14,1.e-7)
plt.grid(True)
# Class_power_z10[:,i]=As*((interp_class_10(Gev_nl_deltakess_z10[:,0]))**2)
# plt.savefig("NL_test_001_solver.jpg", format='jpg', dpi=100)
plt.show()
