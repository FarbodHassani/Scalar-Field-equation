# %% [markdown]
# # Notebook for comparison beween  Gevolution and class and agreement between class and hi-class

# %%
import numpy as np
import matplotlib.pylab as plt
from scipy.interpolate import interp1d
from pylab import rcParams
tableau12 = [(0, 0, 0), (50, 0, 0), (0, 50, 0), (0, 0, 50),    
             (0, 50, 50), (50, 50, 0), (50, 0, 50), (50, 50, 50),    
             (100, 50, 50), (50, 100, 50), (50, 50, 100), (100, 100, 100)]    
  
# Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.    
for i in range(len(tableau12)):    
    r, g, b = tableau12[i]    
    tableau12[i] = (r / 255., g / 255., b / 255.) 
    
tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),    
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),    
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),    
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),    
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]    
  
# Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.    
for i in range(len(tableau20)):    
    r, g, b = tableau20[i]    
    tableau20[i] = (r / 255., g / 255., b / 255.)
# plt.style.available
plt.rcParams.update(plt.rcParamsDefault)

# plt.style.use('seaborn-paper')
plt.rcParams['font.serif'] = 'Ubuntu'

# %%
class_matter_z50=np.loadtxt("./P_22_JoycePower/Power_class_z50.dat")
class_phi_z50=np.loadtxt("./P_22_JoycePower/lcdm_field_class_phi_prime_z50.dat")
P_22_power=np.loadtxt("./P_22_JoycePower/P_22_power.dat")
Gev_power_phi_prime=np.loadtxt("./P_22_JoycePower/output_masterGev_phi_prime_256_256_0.04/output/lcdm_pk_cs_e3_000_phi_prime.dat")
Gev_power_phi=np.loadtxt("./P_22_JoycePower/output_masterGev_phi_prime_256_256_0.04/output/lcdm_pk_cs_e3_000_phi.dat")

#Files for testing Gev that \phi_ini+\phi' dtau =\phi_f
phi_gev_pow_z88=np.loadtxt("./Gevolution_class_phi_prime_test/lcdm_pk000_phi.dat")
phi_prime_gev_pow_z88=np.loadtxt("./Gevolution_class_phi_prime_test/lcdm_pk000_phi_prime.dat")

phi_gev_pow_z54=np.loadtxt("./Gevolution_class_phi_prime_test/lcdm_pk002_phi.dat")
phi_prime_gev_pow_z54=np.loadtxt("./Gevolution_class_phi_prime_test/lcdm_pk002_phi_prime.dat")


phi_gev_pow_z50=np.loadtxt("./Gevolution_class_phi_prime_test/lcdm_pk003_phi.dat")
phi_prime_gev_powz50=np.loadtxt("./Gevolution_class_phi_prime_test/lcdm_pk003_phi_prime.dat")


phi_gev_pow_z48=np.loadtxt("./Gevolution_class_phi_prime_test/lcdm_pk004_phi.dat")
phi_prime_gev_pow_z48=np.loadtxt("./Gevolution_class_phi_prime_test/lcdm_pk004_phi_prime.dat")

# Class w-=1.e-8 cs=1.e-8 Comparison, matter and \delta_kess solution!
class_delta_All_z10=np.loadtxt("./Class_results/class_cs_e8_w_e8/Class_kess_cs_e8_z10_newt_Gev.dat")

#Gevolution matter and kessc comparison,
Gev_z10_delta_m=np.loadtxt("./Gevolution_w_e8_cs_e8/cs_e6_w_e8/kess_pk_cs_e8_w_e8003_delta.dat")
Gev_z10_delta_kess=np.loadtxt("./Gevolution_w_e8_cs_e8/cs_e6_w_e8/kess_pk_cs_e8_w_e8003_delta_kess.dat")

# Kumatsu oneloop_results: k, P_11, P_22, P_13
Kumatsu_oneloop=np.loadtxt("./Kumatsu_one_loop/wavenumber_pk11_pk22_pk13.txt")

#Poisson equation check:
phi_gev_pow_z10=np.loadtxt("./Check_poissoneq_Gev/Gevolution/lcdm_pk005_phi.dat")
# phi_gev_pow_z0=np.loadtxt("./Check_poissoneq_Gev/lcdm_pk006_phi.dat")
phi_gev_pow_z0=np.loadtxt("./Check_poissoneq_Gev/Gevolution/kess_pk_cs_e0_001_phi.dat")
phi_gev_pow_z01=np.loadtxt("./Check_poissoneq_Gev/Gevolution/lcdm_pk00_z1_phi.dat")


deltam_gev_pow_z88=np.loadtxt("./Check_poissoneq_Gev/Gevolution/lcdm_pk000_delta.dat")
deltam_gev_pow_z54=np.loadtxt("./Check_poissoneq_Gev/Gevolution/lcdm_pk002_delta.dat")
deltam_gev_pow_z50=np.loadtxt("./Check_poissoneq_Gev/Gevolution/lcdm_pk003_delta.dat")
deltam_gev_pow_z48=np.loadtxt("./Check_poissoneq_Gev/Gevolution/lcdm_pk004_delta.dat")
deltam_gev_pow_z10=np.loadtxt("./Check_poissoneq_Gev/Gevolution/lcdm_pk005_delta.dat")
deltam_gev_pow_z01=np.loadtxt("./Check_poissoneq_Gev/Gevolution/lcdm_pk00_z1_delta.dat")
deltam_gev_pow_z0=np.loadtxt("./Check_poissoneq_Gev/Gevolution/kess_pk_cs_e0_001_delta.dat")


#Class Poisson equation test:
class_all_z100=np.loadtxt("./Check_poissoneq_Gev/Class/lcdm_z1_tk.dat")
class_all_z10=np.loadtxt("./Check_poissoneq_Gev/Class/lcdm_z2_tk.dat")
class_all_z1=np.loadtxt("./Check_poissoneq_Gev/Class/lcdm_z3_tk.dat")
class_all_z0=np.loadtxt("./Check_poissoneq_Gev/Class/lcdm_z4_tk.dat")

class_pow_z100=np.loadtxt("./Check_poissoneq_Gev/Class/lcdm_z1_pk.dat")
class_pow_z10=np.loadtxt("./Check_poissoneq_Gev/Class/lcdm_z2_pk.dat")
class_pow_z1=np.loadtxt("./Check_poissoneq_Gev/Class/lcdm_z3_pk.dat")
class_pow_z0=np.loadtxt("./Check_poissoneq_Gev/Class/lcdm_z4_pk.dat")
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-4689bb75e3d9> in <module>()
#      21
#      22 # Class w-=1.e-8 cs=1.e-8 Comparison, matter and \delta_kess solution!
# ---> 23 class_delta_All_z10=np.loadtxt("./Class_results/class_cs_e8_w_e8/Class_kess_cs_e8_z10_newt_Gev.dat")
#      24
#      25 #Gevolution matter and kessc comparison,
#
# /Users/farbod/anaconda2/lib/python2.7/site-packages/numpy/lib/npyio.pyc in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     894                 fh = iter(bz2.BZ2File(fname))
#     895             elif sys.version_info[0] == 2:
# --> 896                 fh = iter(open(fname, 'U'))
#     897             else:
#     898                 fh = iter(open(fname))
#
# IOError: [Errno 2] No such file or directory: './Class_results/class_cs_e8_w_e8/Class_kess_cs_e8_z10_newt_Gev.dat'

# %%
def Hubble_conf_Mpc(a):
    w=-1.;h=0.7;
    c=2.99792458*10**5; # Light velocity H_0=100*h/c;
    H0=100.*h/c;
    c=2.99792458*10**5;
    Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
    Omega_m=0.30; Omega_Lambda=0.0;
    Omega_rad=9.16681e-05; Omega_kessence=1.-Omega_m-Omega_rad;
    return H0*np.sqrt(Omega_m*(a**-3)+Omega_rad*(a**-4)+Omega_Lambda+Omega_kessence*(a**(-3.*(1.+w))))*a
# Class power!
h=0.7;
Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
Omega_m=0.3;
a100=1./(1.+100.)
a10=1./(1.+10.)
a1=1./(1.+1.)
a0=1./(1.+0.)
#phi from Poisson equation: 
As=2.3e-9;
w=-1.
# h=0.67556
kp=0.05/h; 
ns=1;
cs2_e3=1.e-6;
#################################
#Making power of class field to compare with Gev. dimensionless power of phi from matter power!
phi_class_poisson_z100= (9./4.)* (Omega_m*(a0**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)* ((class_pow_z100[:,0])**3/(2.*np.pi**2)) * class_pow_z100[:,1]/((class_pow_z100[:,0]*h)**4)
phi_class_poisson_z10= (9./4.)* (Omega_m*(a0**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)* ((class_pow_z10[:,0])**3/(2.*np.pi**2)) * class_pow_z10[:,1]/((class_pow_z10[:,0]*h)**4)
phi_class_poisson_z1= (9./4.)* (Omega_m*(a0**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)* ((class_pow_z1[:,0])**3/(2.*np.pi**2)) * class_pow_z1[:,1]/((class_pow_z1[:,0]*h)**4)
phi_class_poisson_z0= (9./4.)* (Omega_m*(a0**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)* ((class_pow_z0[:,0])**3/(2.*3.1415**2)) * class_pow_z0[:,1]/((class_pow_z0[:,0]*h)**4)

power_class_z100_direct= (class_all_z100[:,6])**2;
power_class_z10_direct= As*(class_all_z10[:,6])**2*((class_all_z10[:,0]/kp)**(ns-1.));
power_class_z1_direct= As*(class_all_z1[:,6])**2*((class_all_z1[:,0]/kp)**(ns-1.));
power_class_z0_direct= As*(class_all_z0[:,6])**2*((class_all_z0[:,0]/kp)**(ns-1.));

power_class_z100_poisson= phi_class_poisson_z100;
power_class_z10_poisson= As*phi_class_poisson_z10*((class_all_z10[:,0]/kp)**(ns-1.));
power_class_z1_poisson= As*phi_class_poisson_z1*((class_all_z1[:,0]/kp)**(ns-1.));
power_class_z0_poisson= As*phi_class_poisson_z0*((class_all_z0[:,0]/kp)**(ns-1.));


#Making power for Gevolution Poisson equation
a88=1./(1.+88.);a50=1./(1.+50.);a48=1./(1.+48.);a10=1./(1.+10.);a1=1./(1.+1.);a0=1./(1.+0.)
#phi from Poisson equation: 
# phi_poisson_z88= (9./4.) * (Omega_m*(a88**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)*deltam_gev_pow_z88[:,1]/((deltam_gev_pow_z88[:,0]*h)**4)
# phi_poisson_z50= (9./4.) * (Omega_m*(a50**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)*deltam_gev_pow_z50[:,1]/((deltam_gev_pow_z50[:,0]*h)**4)
# phi_poisson_z48= (9./4.) * (Omega_m*(a48**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)*deltam_gev_pow_z50[:,1]/((deltam_gev_pow_z50[:,0]*h)**4)
# phi_poisson_z10= (9./4.) * (Omega_m*(a10**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)*deltam_gev_pow_z10[:,1]/((deltam_gev_pow_z10[:,0]*h)**4)
# phi_poisson_z01= (9./4.) * (Omega_m*(a1**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)*deltam_gev_pow_z01[:,1]/((deltam_gev_pow_z01[:,0]*h)**4)
# phi_poisson_z0 = (9./4.) * (Omega_m*(a0**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)*deltam_gev_pow_z0[:,1]/((deltam_gev_pow_z0[:,0]*h)**4)


#Plotting
plt.figure(figsize=(24,24))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)
# plt.loglog(phi_gev_pow_z88[:,0],np.abs(phi_poisson_z88[:]-phi_gev_pow_z88[:,1])/(phi_gev_pow_z88[:,1]) ,color="red",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi (gev)$, z=88")
# # plt.loglog(phi_gev_pow_z50[:,0],np.abs(phi_poisson_z50[:]-phi_gev_pow_z50[:,1])/(phi_gev_pow_z50[:,1]) ,color="black",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi (gev)$, z=50 ")
# # plt.loglog(phi_gev_pow_z10[:,0],np.abs(phi_poisson_z10[:]-phi_gev_pow_z10[:,1])/(phi_gev_pow_z10[:,1]) ,color="blue",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi (gev)$, z=10 ")
# # plt.loglog(phi_gev_pow_z01[:,0],np.abs(phi_poisson_z01[:]-phi_gev_pow_z01[:,1])/(phi_gev_pow_z01[:,1]) ,color="magenta",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi (gev)$, z=1 ")
# # plt.loglog(phi_gev_pow_z0[:,0],np.abs(phi_poisson_z0[:] - phi_gev_pow_z0[:,1])/( phi_gev_pow_z0[:,1]) ,color="green",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi (gev)$, z=0 ")


plt.loglog(class_all_z100[:,0],np.abs(phi_class_poisson_z100[:]-power_class_z100_direct[:])/(power_class_z100_direct[:]) ,color="red",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi$ class, z=100")
plt.loglog(class_all_z100[:,0],np.abs(phi_class_poisson_z10[:]-power_class_z10_direct[:])/(power_class_z10_direct[:]) ,color="blue",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi$ class, z=10")
plt.loglog(class_all_z100[:,0],np.abs(phi_class_poisson_z1[:]-power_class_z1_direct[:])/(power_class_z1_direct[:]) ,color="black",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi$ class, z=1")
plt.loglog(class_all_z100[:,0],np.abs(phi_class_poisson_z0[:]-power_class_z0_direct[:])/(power_class_z0_direct[:]) ,color="purple",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi$ class, z=0")
# #################################
# plt.legend(bbox_to_anchor=(0.7, 0.15, 0.3, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)
# # plt.title('tiling factor=512, N_grid=2048, boxsize =1400.0, time step limit=0.04')
plt.xlim(1.e-4,1.e1)
# plt.ylim(1.e-3,2.e-1)

plt.xlabel("k[1/Mpc]",fontsize=14)
plt.ylabel(r"$|\Delta \mathcal{P}(\Phi)|/\mathcal{P}(\Phi)$ (Class)",fontsize=23)
plt.grid(True)


# plt.savefig('Class_Gev_Poisson.jpg', format='jpg', dpi=500)
plt.show()

# %% [markdown]
# # Comparing Joyce code with Kumatsu one-loop at z=50

# %%
#Plotting
plt.figure(figsize=(15,10))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 12)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 12)
plt.loglog(Kumatsu_oneloop[:,0],Kumatsu_oneloop[:,1] ,color="blue",linestyle='dashed',lw=1.5,label=r"$P_{11}$, Kumatsu ")
plt.loglog(Kumatsu_oneloop[:,0],Kumatsu_oneloop[:,2] ,color="red",linestyle='dashed',lw=1.5,label=r"$P_{22}$, Kumatsu ")
plt.loglog(Kumatsu_oneloop[:,0],np.abs(Kumatsu_oneloop[:,3]) ,color="purple",linestyle='dashed',lw=1.5,label=r"$-P_{13}$, Kumatsu ")

plt.loglog(P_22_power[:,0],P_22_power[:,1] ,color="black",linestyle='dashed',lw=1.5,label=r"$P_{11}$, Joyce ")
plt.loglog(P_22_power[:,0],P_22_power[:,2] ,color="green",linestyle='dashed',lw=1.5,label=r"$P_{22}$, Joyce ")

plt.legend(bbox_to_anchor=(0.8, 0.25, 0.20, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)
# plt.title('tiling factor=512, N_grid=2048, boxsize =1400.0, time step limit=0.04')
plt.xlabel("k[h/Mpc]",fontsize=14)
plt.ylabel(r"$ P[Mpc^3/h^3]$",fontsize=23)
plt.grid(True)
# plt.savefig('one_loop_comp.jpg', format='jpg', dpi=500)
plt.show()

# %% [markdown]
# # Conformal Hubble claculation

# %%
def Hubble_conf_Mpc(a):
    H0=0.00022593979933110373;w=-1;h=0.67556;
    Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
    Omega_m=Omega_b+Omega_cdm; Omega_Lambda=0.7;
    Omega_rad=9.16681e-05; Omega_kessence=1.-Omega_m-Omega_rad;
    return H0*np.sqrt(Omega_m*(a**-3)+Omega_rad*(a**-4)+Omega_Lambda+Omega_kessence*(a**(-3*(1+w))))*a

# %% [markdown]
# # Comparing  class delta_kess and delta_matter for cs->0 and w->0

# %%
# Parameters for converting to dimensionless power.
As=2.19*10**-9;
h=0.67556
kp=0.05/h; 
ns=0.96;
cs2=1.e-6;

def Hubble_conf_Mpc(a):
    H0=0.00022593979933110373;w=-1;h=0.67556;
    Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
    Omega_m=Omega_b+Omega_cdm; Omega_Lambda=0.7;
    Omega_rad=9.16681e-05; Omega_kessence=1.-Omega_m-Omega_rad;
    return H0*np.sqrt(Omega_m*(a**-3)+Omega_rad*(a**-4)+Omega_Lambda+Omega_kessence*(a**(-3*(1+w))))*a
# Class power!
# classpower_delta_kess_z10=As*((class_delta_All_z10[:,3])**2)*((class_delta_All_z10[:,0]/(kp*h))**(ns-1.));
# classpower_delta_matt_z10=As*((class_delta_All_z10[:,3])**2)*((class_delta_All_z10[:,0]/(kp*h))**(ns-1.));

#Plotting
plt.figure(figsize=(15,10))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 12)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 12)
plt.loglog(class_delta_All_z10[:,0],np.abs(class_delta_All_z10[:,3]) ,color="red",linestyle='dashed',lw=1.5,label=r"$|\delta_{kess}|$ class, w=$10^{-8}$, $c_s^2$=$10^{-16}$ ")
plt.loglog(class_delta_All_z10[:,0],np.abs(class_delta_All_z10[:,6]) ,color="blue",linestyle='dashed',lw=1.5,label=r"$|\delta_{matter}|$ class, w=$10^{-8}$, $c_s^2$=$10^{-16}$ ")

plt.legend(bbox_to_anchor=(0.0, 0.85, 0.4, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)
# plt.title('tiling factor=512, N_grid=2048, boxsize =1400.0, time step limit=0.04')
plt.xlabel("k[h/Mpc]",fontsize=14)
plt.ylabel(r"$ |\delta|$",fontsize=23)
plt.grid(True)
# plt.savefig('class.jpg', format='jpg', dpi=500)
plt.show()

# %% [markdown]
# # Comparing  class delta_kess and delta_matter for cs->0 and w->0

# %%
# Parameters for converting to dimensionless power.
As=2.19*10**-9;
h=0.67556
kp=0.05/h; 
ns=0.96;
cs2=1.e-6;

def Hubble_conf_Mpc(a):
    H0=0.00022593979933110373;w=-1;h=0.67556;
    Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
    Omega_m=Omega_b+Omega_cdm; Omega_Lambda=0.7;
    Omega_rad=9.16681e-05; Omega_kessence=1.-Omega_m-Omega_rad;
    return H0*np.sqrt(Omega_m*(a**-3)+Omega_rad*(a**-4)+Omega_Lambda+Omega_kessence*(a**(-3*(1+w))))*a
# Class power!
# classpower_delta_kess_z10=As*((class_delta_All_z10[:,3])**2)*((class_delta_All_z10[:,0]/(kp*h))**(ns-1.));
# classpower_delta_matt_z10=As*((class_delta_All_z10[:,3])**2)*((class_delta_All_z10[:,0]/(kp*h))**(ns-1.));

#Plotting
plt.figure(figsize=(15,10))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 12)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 12)
plt.loglog(Gev_z10_delta_m[:,0],np.abs(Gev_z10_delta_m[:,1]) ,color="red",linestyle='dashed',lw=1.5,label=r"$|P({\delta_{matter}})|$ Gevolution, w=$10^{-8}$, $c_s^2$=$10^{-6}$ ")
plt.loglog(Gev_z10_delta_kess[:,0],np.abs(Gev_z10_delta_kess[:,1]) ,color="blue",linestyle='dashed',lw=1.5,label=r"$|P(\delta_{kess})|$ Gevolution, w=$10^{-8}$, $c_s^2$=$10^{-6}$ ")

plt.legend(bbox_to_anchor=(0.5, 0.05, 0.4, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)
# plt.title('tiling factor=512, N_grid=2048, boxsize =1400.0, time step limit=0.04')
plt.xlabel("k[h/Mpc]",fontsize=14)
plt.ylabel(r"$ |P(\delta)|$",fontsize=23)
plt.grid(True)
# plt.savefig('class_10_e6.jpg', format='jpg', dpi=500)
plt.show()

# %%
def Hubble_conf_Mpc(a):
#     H0=0.00022593979933110373
    c=2.99792458*10**5; # Light velocity H_0=100*h/c;
    w=-1.;h=0.67556;
    H0=100.*h/c;
    Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
    Omega_m=0.30; Omega_Lambda=0.0;
    Omega_rad=9.16681e-05; Omega_kessence=1.-Omega_m-Omega_rad;
    return H0*np.sqrt(Omega_m*(a**-3)+Omega_rad*(a**-4)+Omega_Lambda+Omega_kessence*(a**(-3.*(1.+w))))*a
# Class power!
Hubble_conf_Mpc(1.)
# Out:
# 0.00022534256015206363

# %% [markdown]
# # Checking Poisson equation in Class:

# %%
def Hubble_conf_Mpc(a):
#     H0=0.00022593979933110373
    c=2.99792458*10**5; # Light velocity H_0=100*h/c;
    w=-1.;h=0.67556;
    H0=100.*h/c;
    Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
    Omega_m=0.30; Omega_Lambda=0.0;
    Omega_rad=9.16681e-05; Omega_kessence=1.-Omega_m-Omega_rad;
    return H0*np.sqrt(Omega_m*(a**-3)+Omega_rad*(a**-4)+Omega_Lambda+Omega_kessence*(a**(-3.*(1.+w))))*a
# Class power!

h=0.67556;
Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
Omega_m=Omega_b+Omega_cdm;
a100=1./(1.+100.)
a10=1./(1.+10.)
a1=1./(1.+1.)
a0=1./(1.+ -0.029939)
#phi from Poisson equation: 
As=2.3e-9;
w=-1.
# h=0.67556
kp=0.05/h; 
ns=1;
cs2_e3=1.e-6;
#################################
a88=1./(1.+88.687978);a50=1./(1.+50.);a48=1./(1.+48.);a10=1./(1.+10.);a1=1./(1.+1.);a0=1./(1.+0.)
#phi from Poisson equation: 
phi_poisson_z88= (9./4.) * (Omega_m*(a88**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)*deltam_gev_pow_z88[:,1]/((deltam_gev_pow_z88[:,0]*h)**4)
phi_poisson_z50= (9./4.) * (Omega_m*(a50**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)*deltam_gev_pow_z50[:,1]/((deltam_gev_pow_z50[:,0]*h)**4)
phi_poisson_z48= (9./4.) * (Omega_m*(a48**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)*deltam_gev_pow_z50[:,1]/((deltam_gev_pow_z50[:,0]*h)**4)
phi_poisson_z10= (9./4.) * (Omega_m*(a10**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)*deltam_gev_pow_z10[:,1]/((deltam_gev_pow_z10[:,0]*h)**4)
phi_poisson_z01= (9./4.) * (Omega_m*(a1**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)*deltam_gev_pow_z01[:,1]/((deltam_gev_pow_z01[:,0]*h)**4)
phi_poisson_z0 = (9./4.) * (Omega_m*(a0**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)*deltam_gev_pow_z0[:,1]/((deltam_gev_pow_z0[:,0]*h)**4)

#Plotting
plt.figure(figsize=(24,24))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)
#################################
#################################
#################################
# plt.subplot(312)
plt.loglog(phi_gev_pow_z88[:,0],np.abs(phi_poisson_z88[:]-phi_gev_pow_z88[:,1])/(phi_gev_pow_z88[:,1]) ,color="red",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi (gev)$, z=88")
# plt.loglog(phi_gev_pow_z50[:,0],np.abs(phi_poisson_z50[:]-phi_gev_pow_z50[:,1])/(phi_gev_pow_z50[:,1]) ,color="black",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi (gev)$, z=50 ")
plt.loglog(phi_gev_pow_z10[:,0],np.abs(phi_poisson_z10[:]-phi_gev_pow_z10[:,1])/(phi_gev_pow_z10[:,1]) ,color="blue",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi (gev)$, z=10 ")
plt.loglog(phi_gev_pow_z01[:,0],np.abs(phi_poisson_z01[:]-phi_gev_pow_z01[:,1])/(phi_gev_pow_z01[:,1]) ,color="magenta",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi (gev)$, z=1 ")
plt.loglog(phi_gev_pow_z0[:,0],np.abs(phi_poisson_z0[:] - phi_gev_pow_z0[:,1])/( phi_gev_pow_z0[:,1]) ,color="green",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi (gev)$, z=0 ")
#################################
plt.legend(bbox_to_anchor=(0.0, 0.2, 0.3, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)
# plt.title('tiling factor=512, N_grid=2048, boxsize =1400.0, time step limit=0.04')
# plt.xlim(1.e-4,1.e1)
# plt.ylim(1.e-3,2.e-1)
plt.xlabel("k[1/Mpc]",fontsize=14)
plt.ylabel(r"$|\Delta \Phi|/\Phi$(Gev)",fontsize=23)
plt.grid(True)

# plt.savefig('Class_Gev_Poisson.jpg', format='jpg', dpi=500)
plt.show()

# %%
# def Hubble_conf_Mpc(a):
#     H0=0.00022593979933110373;w=-1.;h=0.7;
#     Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
#     Omega_m=Omega_b+Omega_cdm; Omega_Lambda=0.0;
#     Omega_rad=9.16681e-05; Omega_kessence=1.-Omega_m-Omega_rad;
#     return H0*np.sqrt(Omega_m*(a**-3)+Omega_rad*(a**-4)+Omega_Lambda+Omega_kessence*(a**(-3.*(1.+w))))*a
def Hubble_conf_Mpc(a):
    w=-1.;h=0.7;
    c=2.99792458*10**5; # Light velocity H_0=100*h/c;
    H0=100.*h/c;
    c=2.99792458*10**5;
    Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
    Omega_m=0.30; Omega_Lambda=0.0;
    Omega_rad=9.16681e-05; Omega_kessence=1.-Omega_m-Omega_rad;
    return H0*np.sqrt(Omega_m*(a**-3)+Omega_rad*(a**-4)+Omega_Lambda+Omega_kessence*(a**(-3.*(1.+w))))*a
# Class power!
h=0.7;
Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
Omega_m=0.3;
a100=1./(1.+100.)
a10=1./(1.+10.)
a1=1./(1.+1.)
a0=1./(1.+0.)
#phi from Poisson equation: 
As=2.3e-9;
w=-1.
# h=0.67556
kp=0.05/h; 
ns=1;
cs2_e3=1.e-6;
#################################

#Making power of class field to compare with Gev. dimensionless power of phi from matter power!
phi_class_poisson_z100= (9./4.)* (Omega_m*(a0**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)* ((class_pow_z100[:,0])**3/(2.*np.pi**2)) * class_pow_z100[:,1]/((class_pow_z100[:,0]*h)**4)
phi_class_poisson_z10= (9./4.)* (Omega_m*(a0**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)* ((class_pow_z10[:,0])**3/(2.*np.pi**2)) * class_pow_z10[:,1]/((class_pow_z10[:,0]*h)**4)
phi_class_poisson_z1= (9./4.)* (Omega_m*(a0**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)* ((class_pow_z1[:,0])**3/(2.*np.pi**2)) * class_pow_z1[:,1]/((class_pow_z1[:,0]*h)**4)
phi_class_poisson_z0= (9./4.)* (Omega_m*(a0**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)* ((class_pow_z0[:,0])**3/(2.*3.1415**2)) * class_pow_z0[:,1]/((class_pow_z0[:,0]*h)**4)

power_class_z100_direct= (class_all_z100[:,6])**2;
power_class_z10_direct= As*(class_all_z10[:,6])**2*((class_all_z10[:,0]/kp)**(ns-1.));
power_class_z1_direct= As*(class_all_z1[:,6])**2*((class_all_z1[:,0]/kp)**(ns-1.));
power_class_z0_direct= As*(class_all_z0[:,6])**2*((class_all_z0[:,0]/kp)**(ns-1.));

power_class_z100_poisson= phi_class_poisson_z100;
power_class_z10_poisson= As*phi_class_poisson_z10*((class_all_z10[:,0]/kp)**(ns-1.));
power_class_z1_poisson= As*phi_class_poisson_z1*((class_all_z1[:,0]/kp)**(ns-1.));
power_class_z0_poisson= As*phi_class_poisson_z0*((class_all_z0[:,0]/kp)**(ns-1.));


#Making power for Gevolution Poisson equation
a88=1./(1.+88.);a50=1./(1.+50.);a48=1./(1.+48.);a10=1./(1.+10.);a1=1./(1.+1.);a0=1./(1.+0.)
#phi from Poisson equation: 
# phi_poisson_z88= (9./4.) * (Omega_m*(a88**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)*deltam_gev_pow_z88[:,1]/((deltam_gev_pow_z88[:,0]*h)**4)
# phi_poisson_z50= (9./4.) * (Omega_m*(a50**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)*deltam_gev_pow_z50[:,1]/((deltam_gev_pow_z50[:,0]*h)**4)
# phi_poisson_z48= (9./4.) * (Omega_m*(a48**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)*deltam_gev_pow_z50[:,1]/((deltam_gev_pow_z50[:,0]*h)**4)
# phi_poisson_z10= (9./4.) * (Omega_m*(a10**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)*deltam_gev_pow_z10[:,1]/((deltam_gev_pow_z10[:,0]*h)**4)
# phi_poisson_z01= (9./4.) * (Omega_m*(a1**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)*deltam_gev_pow_z01[:,1]/((deltam_gev_pow_z01[:,0]*h)**4)
# phi_poisson_z0 = (9./4.) * (Omega_m*(a0**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)*deltam_gev_pow_z0[:,1]/((deltam_gev_pow_z0[:,0]*h)**4)


#Plotting
plt.figure(figsize=(24,24))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)
#################################
#################################
#################################
# plt.subplot(321)
# plt.loglog(class_all_z100[:,0],power_class_z100_direct[:]*1.2 ,color="red",linestyle='dashed',lw=1.5,label=r"$\mathcal{P}_{\Phi}$ class, z=100, direct")
# plt.loglog(class_all_z100[:,0],phi_class_poisson_z100[:],color="purple",linestyle='dashed',lw=1.5,label=r"$\mathcal{P}_{\Phi}$ class, z=100 Poisson")
# # plt.loglog(phi_gev_pow_z88[:,0],phi_gev_pow_z88[:,1],color="black",linestyle='dashed',lw=1.5,label=r"$\mathcal{P}_{\Phi}$ Gevolution, z=88, directly")
# # plt.loglog(deltam_gev_pow_z88[:,0],phi_poisson_z88[:],color="blue",linestyle='dashed',lw=1.5,label=r"$\mathcal{P}_{\Phi}$, Gevolution, z=88 , Poisson")

# plt.legend(bbox_to_anchor=(0.6, 0.90, 0.4, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)
# # plt.title('tiling factor=512, N_grid=2048, boxsize =1400.0, time step limit=0.04')
# plt.xlabel("k[1/Mpc]",fontsize=14)
# plt.ylabel(r"$ \mathcal{P}(\Phi)$",fontsize=23)
# plt.xlim(9.e-2,1.e0)
# plt.ylim(1.e-14,9.e-10)
# plt.grid(True)

# plt.subplot(322)
# plt.loglog(class_all_z0[:,0],power_class_z0_direct[:]*1.2 ,color="purple",linestyle='dashed',lw=1.5,label=r"$\mathcal{P}_{\Phi}$ class, z=0, direct")
# plt.loglog(class_all_z0[:,0],phi_class_poisson_z0[:],color="blue",linestyle='dashed',lw=1.5,label=r"$\mathcal{P}_{\Phi}$ class, z=0 Poisson")
# # plt.loglog(deltam_gev_pow_z0[:,0],phi_poisson_z0[:],color="red",linestyle='dashed',lw=1.5,label=r"$\mathcal{P}_{\Phi}$, z=0 Gevolution, Poisson")
# # plt.loglog(phi_gev_pow_z0[:,0],phi_gev_pow_z0[:,1],color="black",linestyle='dashed',lw=1.5,label=r"$\mathcal{P}_{\Phi}$ Gevolution, z=0, directly")
# plt.legend(bbox_to_anchor=(0.6, 0.90, 0.4, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)
# # plt.title('tiling factor=512, N_grid=2048, boxsize =1400.0, time step limit=0.04')
# plt.xlabel("k[1/Mpc]",fontsize=14)
# plt.ylabel(r"$ \mathcal{P}(\Phi)$",fontsize=23)
# plt.xlim(9.e-2,1.e0)
# plt.ylim(1.e-14,9.e-10)
# plt.grid(True)

#################################
#################################
#################################
# plt.subplot(312)
# plt.loglog(phi_gev_pow_z88[:,0],np.abs(phi_poisson_z88[:]-phi_gev_pow_z88[:,1])/(phi_gev_pow_z88[:,1]) ,color="red",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi (gev)$, z=88")
# # plt.loglog(phi_gev_pow_z50[:,0],np.abs(phi_poisson_z50[:]-phi_gev_pow_z50[:,1])/(phi_gev_pow_z50[:,1]) ,color="black",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi (gev)$, z=50 ")
# # plt.loglog(phi_gev_pow_z10[:,0],np.abs(phi_poisson_z10[:]-phi_gev_pow_z10[:,1])/(phi_gev_pow_z10[:,1]) ,color="blue",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi (gev)$, z=10 ")
# # plt.loglog(phi_gev_pow_z01[:,0],np.abs(phi_poisson_z01[:]-phi_gev_pow_z01[:,1])/(phi_gev_pow_z01[:,1]) ,color="magenta",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi (gev)$, z=1 ")
# # plt.loglog(phi_gev_pow_z0[:,0],np.abs(phi_poisson_z0[:] - phi_gev_pow_z0[:,1])/( phi_gev_pow_z0[:,1]) ,color="green",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi (gev)$, z=0 ")
# # #################################
# plt.legend(bbox_to_anchor=(0.0, 0.2, 0.3, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)
# # plt.title('tiling factor=512, N_grid=2048, boxsize =1400.0, time step limit=0.04')
# # plt.xlim(1.e-4,1.e1)
# # plt.ylim(1.e-3,2.e-1)
# plt.xlabel("k[1/Mpc]",fontsize=14)
# plt.ylabel(r"$|\Delta \Phi|/\Phi$(Gev)",fontsize=23)
# plt.grid(True)

#################################
#################################
#################################
# plt.subplot(313)

plt.loglog(class_all_z100[:,0],np.abs(phi_class_poisson_z100[:]-power_class_z100_direct[:])/(power_class_z100_direct[:]) ,color="red",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi$ class, z=100")
plt.loglog(class_all_z100[:,0],np.abs(phi_class_poisson_z10[:]-power_class_z10_direct[:])/(power_class_z10_direct[:]) ,color="blue",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi$ class, z=10")
plt.loglog(class_all_z100[:,0],np.abs(phi_class_poisson_z1[:]-power_class_z1_direct[:])/(power_class_z1_direct[:]) ,color="black",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi$ class, z=1")
plt.loglog(class_all_z100[:,0],np.abs(phi_class_poisson_z0[:]-power_class_z0_direct[:])/(power_class_z0_direct[:]) ,color="purple",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi$ class, z=0")
# #################################
# plt.legend(bbox_to_anchor=(0.7, 0.15, 0.3, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)
# # plt.title('tiling factor=512, N_grid=2048, boxsize =1400.0, time step limit=0.04')
plt.xlim(1.e-4,1.e1)
# plt.ylim(1.e-3,2.e-1)

plt.xlabel("k[1/Mpc]",fontsize=14)
plt.ylabel(r"$|\Delta \mathcal{P}(\Phi)|/\mathcal{P}(\Phi)$ (Class)",fontsize=23)
plt.grid(True)


# plt.savefig('Class_Gev_Poisson.jpg', format='jpg', dpi=500)
plt.show()

# %% [markdown]
# # Checking Poisson equation in Gevolution:

# %%
def Hubble_conf_Mpc(a):
    H0=0.00022593979933110373;w=-1;h=0.67556;
    Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
    Omega_m=Omega_b+Omega_cdm; Omega_Lambda=0.0;
    Omega_rad=9.16681e-05; Omega_kessence=1.-Omega_m-Omega_rad;
    return H0*np.sqrt(Omega_m*(a**-3)+Omega_rad*(a**-4)+Omega_Lambda+Omega_kessence*(a**(-3.*(1.+w))))*a
# Class power!
# Formula= P_phi= 9 H0^4 Omega_0^2 P_delta /4a^2 k^4
a88=1./(1.+88.);a50=1./(1.+50.);a48=1./(1.+48.);a10=1./(1.+10.);a1=1./(1.+1.);a0=1./(1.+0.)
#phi from Poisson equation: 
phi_poisson_z88= (9./4.) * (Omega_m*(a88**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)*deltam_gev_pow_z88[:,1]/((deltam_gev_pow_z88[:,0]*h)**4)
phi_poisson_z50= (9./4.) * (Omega_m*(a50**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)*deltam_gev_pow_z50[:,1]/((deltam_gev_pow_z50[:,0]*h)**4)
phi_poisson_z48= (9./4.) * (Omega_m*(a48**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)*deltam_gev_pow_z50[:,1]/((deltam_gev_pow_z50[:,0]*h)**4)
phi_poisson_z10= (9./4.) * (Omega_m*(a10**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)*deltam_gev_pow_z10[:,1]/((deltam_gev_pow_z10[:,0]*h)**4)
phi_poisson_z01= (9./4.) * (Omega_m*(a1**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)*deltam_gev_pow_z01[:,1]/((deltam_gev_pow_z01[:,0]*h)**4)
phi_poisson_z0= (9./4.) *  (Omega_m*(a0**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)*deltam_gev_pow_z0[:,1]/((deltam_gev_pow_z0[:,0]*h)**4)


#Plotting
plt.figure(figsize=(24,24))
plt.subplot(311)
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)

plt.loglog(deltam_gev_pow_z88[:,0],phi_poisson_z88[:] ,color="red",linestyle='dashed',lw=1.5,label=r"$\mathcal{P}_{\Phi}$ Gevolution, z=88, Poisson")
plt.loglog(phi_gev_pow_z88[:,0],phi_gev_pow_z88[:,1],color="blue",linestyle='dashed',lw=1.5,label=r"$\mathcal{P}_{\Phi}$ Gevolution, z=88 directly")

# plt.loglog(deltam_gev_pow_z10[:,0],phi_poisson_z10[:] ,color="green",linestyle='dashed',lw=1.5,label=r"$\mathcal{P}_{\Phi}$ Gevolution, z=10, Poisson")
# plt.loglog(phi_gev_pow_z10[:,0],phi_gev_pow_z10[:,1],color="black",linestyle='dashed',lw=1.5,label=r"$\mathcal{P}_{\Phi}$ Gevolution, z=10, directly")

# plt.loglog(deltam_gev_pow_z01[:,0],phi_poisson_z01[:] ,color="pink",linestyle='dashed',lw=1.5,label=r"$\mathcal{P}_{\Phi}$ Gevolution, z=1, Poisson")
# plt.loglog(phi_gev_pow_z01[:,0],phi_gev_pow_z01[:,1],color="cyan",linestyle='dashed',lw=1.5,label=r"$\mathcal{P}_{\Phi}$ Gevolution, z=1, directly")


# plt.loglog(deltam_gev_pow_z0[:,0],phi_poisson_z0[:] ,color="magenta",linestyle='dashed',lw=1.5,label=r"$\mathcal{P}_{\Phi}$ Gevolution, z=0, Poisson")
# plt.loglog(phi_gev_pow_z0[:,0],phi_gev_pow_z0[:,1],color="purple",linestyle='dashed',lw=1.5,label=r"$\mathcal{P}_{\Phi}$ Gevolution, z=0, directly")


plt.legend(bbox_to_anchor=(0.0, 0.40, 0.4, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)
# plt.title('tiling factor=512, N_grid=2048, boxsize =1400.0, time step limit=0.04')
plt.xlabel("k[1/Mpc]",fontsize=14)
plt.ylabel(r"$ |\mathcal{P}(\Phi)|$",fontsize=23)
plt.grid(True)

plt.subplot(312)

# plt.loglog(deltam_gev_pow_z88[:,0],deltam_gev_pow_z88[:,1] ,color="red",linestyle='dashed',lw=1.5,label=r"$\mathcal{P} (\delta_m) $ Gev, z=88")
# plt.loglog(deltam_gev_pow_z10[:,0],deltam_gev_pow_z10[:,1] ,color="black",linestyle='dashed',lw=1.5,label=r"$\mathcal{P} (\delta_m) $ Gev, z=10")
# plt.loglog(deltam_gev_pow_z01[:,0],deltam_gev_pow_z01[:,1] ,color="blue",linestyle='dashed',lw=1.5,label=r"$\mathcal{P} (\delta_m) $ Gev, z=1")
# plt.loglog(deltam_gev_pow_z0[:,0],deltam_gev_pow_z0[:,1] ,color="green",linestyle='dashed',lw=1.5,label=r"$\mathcal{P} (\delta_m) $ Gev, z=0")

#################################
plt.legend(bbox_to_anchor=(0.0, 0.15, 0.3, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)
# plt.title('tiling factor=512, N_grid=2048, boxsize =1400.0, time step limit=0.04')
plt.xlabel("k[1/Mpc]",fontsize=14)
plt.ylabel(r"$|\mathcal{P}|$",fontsize=23)
plt.grid(True)



plt.subplot(313)

# plt.loglog(phi_gev_pow_z88[:,0],np.abs(phi_poisson_z88[:]-phi_gev_pow_z88[:,1])/(phi_gev_pow_z88[:,1]) ,color="red",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi (gev)  $ Gev, z=88")
# plt.loglog(phi_gev_pow_z50[:,0],np.abs(phi_poisson_z50[:]-phi_gev_pow_z50[:,1])/(phi_gev_pow_z50[:,1]) ,color="black",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi (gev) $ Gev, z=50 ")
# plt.loglog(phi_gev_pow_z10[:,0],np.abs(phi_poisson_z10[:]-phi_gev_pow_z10[:,1])/(phi_gev_pow_z10[:,1]) ,color="blue",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi (gev)  $ Gev, z=10 ")
# plt.loglog(phi_gev_pow_z01[:,0],np.abs(phi_poisson_z01[:]-phi_gev_pow_z01[:,1])/(phi_gev_pow_z01[:,1]) ,color="magenta",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi (gev)  $ Gev, z=1 ")
# plt.loglog(phi_gev_pow_z0[:,0],np.abs(phi_poisson_z0[:] - phi_gev_pow_z0[:,1])/( phi_gev_pow_z0[:,1]) ,color="green",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi (gev)  $ Gev, z=0 ")

#################################
plt.legend(bbox_to_anchor=(0.0, 0.25, 0.3, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)
# plt.title('tiling factor=512, N_grid=2048, boxsize =1400.0, time step limit=0.04')
plt.xlabel("k[1/Mpc]",fontsize=14)
plt.ylabel(r"$|\Delta \Phi|/\Phi$",fontsize=23)
plt.grid(True)


# plt.savefig('Gev_Poisson.jpg', format='jpg', dpi=500)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-96c017a9506e> in <module>()
#       9 a88=1./(1.+88.);a50=1./(1.+50.);a48=1./(1.+48.);a10=1./(1.+10.);a1=1./(1.+1.);a0=1./(1.+0.)
#      10 #phi from Poisson equation:
# ---> 11 phi_poisson_z88= (9./4.) * (Omega_m*(a88**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)*deltam_gev_pow_z88[:,1]/((deltam_gev_pow_z88[:,0]*h)**4)
#      12 phi_poisson_z50= (9./4.) * (Omega_m*(a50**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)*deltam_gev_pow_z50[:,1]/((deltam_gev_pow_z50[:,0]*h)**4)
#      13 phi_poisson_z48= (9./4.) * (Omega_m*(a48**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)*deltam_gev_pow_z50[:,1]/((deltam_gev_pow_z50[:,0]*h)**4)
#
# NameError: name 'Omega_m' is not defined

# %% [markdown]
# # Convergence test for calculating \Phi' in the Gevolution

# %%
# First maiing the fields!
phi_z88_Gev=np.sqrt(phi_gev_pow_z88[:,1]);
phi_z54_Gev=np.sqrt(phi_gev_pow_z54[:,1]);
phi_z50_Gev=np.sqrt(phi_gev_pow_z50[:,1]);
phi_z48_Gev=np.sqrt(phi_gev_pow_z48[:,1]);


phi_prime_z88_Gev=np.sqrt(phi_prime_gev_pow_z88[:,1]);
phi_prime_z54_Gev=np.sqrt(phi_prime_gev_pow_z54[:,1]);
phi_prime_z50_Gev=np.sqrt(phi_prime_gev_pow_z50[:,1]);
phi_prime_z48_Gev=np.sqrt(phi_prime_gev_pow_z48[:,1]);


Delta_z88=88.-48.;
Delta_z54=54.-48.;
Delta_z50=50.-48.;

a88=1./(1.+88.);
a54=1./(1.+54.);
a50=1./(1.+50.);

phi_f_z48_made_z88=phi_z88_Gev- phi_prime_z88_Gev * a88 * Delta_z88;
phi_f_z48_made_z54=phi_z54_Gev- phi_prime_z54_Gev * a54 * Delta_z54;
phi_f_z48_made_z50=phi_z50_Gev- phi_prime_z50_Gev * a50 * Delta_z50;

plt.figure(figsize=(18,18))
plt.subplot(311)
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)
##############################
plt.loglog(phi_gev_pow_z48[:,0],phi_f_z48_made_z88[:] ,color="red",linestyle='dashed',lw=1.5,label=r"$\Phi_f= \Phi_i(z=88) + \Phi'(z=88) d \tau$ Gev, z=48 ")
plt.loglog(phi_gev_pow_z48[:,0],phi_f_z48_made_z54[:] ,color="black",linestyle='dashed',lw=1.5,label=r"$\Phi_f= \Phi_i(z=54) + \Phi'(z=54) d \tau$ Gev, z=48 ")
plt.loglog(phi_gev_pow_z48[:,0],phi_f_z48_made_z50[:] ,color="blue",linestyle='dashed',lw=1.5,label=r"$\Phi_f= \Phi_i(z=50) + \Phi'(z=50) d \tau$ Gev, z=48 ")

plt.loglog(phi_gev_pow_z48[:,0],phi_z48_Gev[:] ,color="green",linestyle='dashed',lw=1.5,label=r"$\Phi$ Gev-direct  z=48 ")
#################################
plt.legend(bbox_to_anchor=(0.1, 0.45, 0.4, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)
# plt.title('tiling factor=512, N_grid=2048, boxsize =1400.0, time step limit=0.04')
plt.xlabel("k[h/Mpc]",fontsize=14)
plt.ylabel(r"$ \Phi$",fontsize=23)
plt.grid(True)
plt.subplot(312)

plt.loglog(phi_gev_pow_z48[:,0],np.abs(phi_f_z48_made_z88[:]-phi_z48_Gev[:])/(phi_z48_Gev[:]) ,color="red",linestyle='dashed',lw=1.5,label=r"$\Phi_f/\Phi(gev) -1 $ Gev, z=48, z_ini=88 ")
plt.loglog(phi_gev_pow_z48[:,0],np.abs(phi_f_z48_made_z54[:]-phi_z48_Gev[:])/(phi_z48_Gev[:]) ,color="black",linestyle='dashed',lw=1.5,label=r"$\Phi_f/\Phi(gev) -1 $ Gev, z=48, z_ini=54 ")
plt.loglog(phi_gev_pow_z48[:,0],np.abs(phi_f_z48_made_z50[:]-phi_z48_Gev[:])/(phi_z48_Gev[:]) ,color="blue",linestyle='dashed',lw=1.5,label=r"$\Phi_f/\Phi(gev) -1 $ Gev, z=48, z_ini=50 ")
#################################
plt.legend(bbox_to_anchor=(0.0, 0.85, 0.3, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)
# plt.title('tiling factor=512, N_grid=2048, boxsize =1400.0, time step limit=0.04')
plt.xlabel("k[h/Mpc]",fontsize=14)
plt.ylabel(r"$|\Delta \Phi|/\Phi$",fontsize=23)
plt.grid(True)

##################################################################
##################################################################
plt.subplot(313)
plt.loglog(phi_prime_gev_pow_z88[:,0],phi_prime_z88_Gev[:] ,color="red",linestyle='dashed',lw=1.5,label=r"$\Phi'$ Gev, z=88 ")
plt.loglog(phi_prime_gev_pow_z54[:,0],phi_prime_z54_Gev[:] ,color="black",linestyle='dashed',lw=1.5,label=r"$\Phi' $ Gev, z_=54 ")
plt.loglog(phi_prime_gev_pow_z50[:,0],phi_prime_z50_Gev[:] ,color="orange",linestyle='dashed',lw=1.5,label=r"$\Phi'$ Gev, z=50 ")
plt.loglog(phi_prime_gev_pow_z48[:,0],phi_prime_z48_Gev[:],color="green",linestyle='dashed',lw=1.5,label=r"$\Phi' $ Gev, z=48 ")

#################################
plt.legend(bbox_to_anchor=(0.0, 0.25, 0.3, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)
# plt.title('tiling factor=512, N_grid=2048, boxsize =1400.0, time step limit=0.04')
plt.xlabel("k[h/Mpc]",fontsize=14)
plt.ylabel(r"$\Phi'$",fontsize=23)
plt.grid(True)

plt.savefig('compII.jpg', format='jpg', dpi=500)


plt.show()

# %% [markdown]
# # One-loop power spectrum!

# %%
((Hubble_conf_Mpc(1.)/P_22_power[:,0]*h)**4)[:40]
P_22_power[:20,2]
plt.loglog(P_22_power[:,0],P_22_power[:,2]+P_22_power[:,1],color="blue")
plt.loglog(P_22_power[:,0],P_22_power[:,1])
plt.loglog(class_matter_z50[:,0],class_matter_z50[:,1],color="red")

plt.show()

# %% [markdown]
# # Riess-Sciama effect claculation

# %%
# Parameters for converting to dimensionless power.
As=2.19*10**-9;
h=0.67556
kp=0.05/h; 
ns=0.96;
cs2=1.e-6;

def Hubble_conf_Mpc(a):
    H0=0.00022593979933110373;w=-1;h=0.67556;
    Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
    Omega_m=Omega_b+Omega_cdm; Omega_Lambda=0.0;
    Omega_rad=9.16681e-05; Omega_kessence=1.-Omega_m-Omega_rad;
    return H0*np.sqrt(Omega_m*(a**-3)+Omega_rad*(a**-4)+Omega_Lambda+Omega_kessence*(a**(-3*(1+w))))*a

a50=1./(1.+50.);
# pow_phi_prime_Riess_Sciama= ((P_22_power[:,0])**3/(2*np.pi**2)) * (a50)**2 * P_22_power[:,2]*(9./4.)*(Hubble_conf_Mpc(1.)/P_22_power[:,0]*h)**4
pow_phi_prime_Riess_Sciama= a50**2 * ((P_22_power[:,0]*h)**3/(2*np.pi**2))  * P_22_power[:,2]*(9./4.)*(Hubble_conf_Mpc(1.)/P_22_power[:,0]*h)**4

# Class power!
classpower_phi_prime_z50=As*((class_phi_z50[:,2])**2)*((class_phi_z50[:,0]/(kp*h))**(ns-1.));
# classpower_phi_prime_z30=As*((class_phi_z30[:,2])**2)*((class_phi_z30[:,0]/(kp*h))**(ns-1.));
# classpower_phi_prime_z10=As*((class_phi_z10[:,2])**2)*((class_phi_z10[:,0]/(kp*h))**(ns-1.));
######################
classpower_phi_z50=As*((class_phi_z50[:,3])**2)*((class_phi_z50[:,0]/(kp*h))**(ns-1.));
# classpower_phi_z30=As*((class_phi_z30[:,3])**2)*((class_phi_z30[:,0]/(kp*h))**(ns-1.));
# classpower_phi_z10=As*((class_phi_z10[:,3])**2)*((class_phi_z10[:,0]/(kp*h))**(ns-1.));
#######################
#Plot setting
plt.figure(figsize=(15,15))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)
# plt.subplot(211)
# plt.figure(1)
plt.plot(Gev_power_phi_prime[:,0]*h,Gev_power_phi_prime[:,1] ,color="blue",linestyle='dashed',lw=1.5,label=r"$\Phi'$/H  Gev z=50")
##############################
plt.plot(class_phi_z50[:,0],classpower_phi_prime_z50[:] ,color="red",linestyle='dashed',lw=1.5,label=r"$\Phi'$/H class, z=50 ")

plt.plot(P_22_power[:,0]*h,pow_phi_prime_Riess_Sciama[:] ,color="green",linestyle='dashed',lw=1.5,label=r"$\Phi'$/H class, Riess-Sciama z=50 ")

#################################

#################################
plt.legend(bbox_to_anchor=(0.1, 0.45, 0.3, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)
# plt.title('tiling factor=512, N_grid=2048, boxsize =1400.0, time step limit=0.04')
plt.xlabel("k[h/Mpc]",fontsize=14)
plt.ylabel(r"$\mathcal{P} (\Phi'/H))$",fontsize=23)
# plt.xlim(6.e-2,1.e0)
# plt.ylim(6.e-18,2.e-17)

plt.grid(True)

######################
# plt.subplot(212)
# # #z=50
# plt.loglog(Gev_power_phi[:,0]*h,Gev_power_phi[:,1] ,color="Purple",linestyle='dashed',lw=1.5,label=r"Phi_big run Gev z=50, ")
# plt.loglog(class_phi_z50[:,0],classpower_phi_z50[:] ,color="red",linestyle='dashed',lw=1.5,label=r"Phi class  z=50 ")
# plt.legend(bbox_to_anchor=(0.6, 0.9, 0.4, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)

# ##################################################################
# #################################
# #z=10
# # plt.loglog(phi_Gev_lcdm_z_10[:,0]*h,phi_Gev_lcdm_z_10[:,1] ,color="green",linestyle='dashed',lw=1.5,label=r"Phi Gev z=10 ")
# # plt.loglog(phi_Big_Gev_lcdm_z_10[:,0]*h,phi_Big_Gev_lcdm_z_10[:,1] ,color="green",linestyle='dashed',lw=1.5,label=r"Phi Gev z=50 ")
# # plt.loglog(class_phi_z10[:,0],classpower_phi_z10[:] ,color="black",linestyle='dashed',lw=1.5,label=r"Phi class  z=10 ")
# plt.legend(bbox_to_anchor=(0.0, 0.35, 0.6, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)
# ######################
# plt.xlabel("k[h/Mpc]",fontsize=14)
# plt.ylabel(r"$\mathcal{P} (\Phi)$",fontsize=23)
# plt.xlim(6.e-2,1.e0)

# plt.grid(True)
######################

# plt.ylim(1.e-3,1.e1)
plt.yscale('log')
plt.xscale('log')

# plt.savefig('compI.jpg', format='jpg', dpi=500)
plt.grid(True)
plt.show()

# %%
# Parameters for converting to dimensionless power.
As=2.19*10**-9;
h=0.67556
kp=0.05/h; 
ns=0.96;
cs2=1.e-6;

def Hubble_conf_Mpc(a):
    H0=0.00022593979933110373;w=-1;h=0.67556;
    Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
    Omega_m=Omega_b+Omega_cdm; Omega_Lambda=0.0;
    Omega_rad=9.16681e-05; Omega_kessence=1.-Omega_m-Omega_rad;
    return H0*np.sqrt(Omega_m*(a**-3)+Omega_rad*(a**-4)+Omega_Lambda+Omega_kessence*(a**(-3*(1+w))))*a

a50=1./(1.+50.);
# pow_phi_prime_Riess_Sciama= ((P_22_power[:,0])**3/(2*np.pi**2)) * (a50)**2 * P_22_power[:,2]*(9./4.)*(Hubble_conf_Mpc(1.)/P_22_power[:,0]*h)**4
pow_phi_prime_Riess_Sciama= a50**2 * ((P_22_power[:,0])**3/(2*np.pi**2))  * P_22_power[:,2]*(9./4.)*(Hubble_conf_Mpc(1.)/P_22_power[:,0]*h)**4

# Class power!
classpower_phi_prime_z50=As*((class_phi_z50[:,2])**2)*((class_phi_z50[:,0]/(kp*h))**(ns-1.));
# classpower_phi_prime_z30=As*((class_phi_z30[:,2])**2)*((class_phi_z30[:,0]/(kp*h))**(ns-1.));
# classpower_phi_prime_z10=As*((class_phi_z10[:,2])**2)*((class_phi_z10[:,0]/(kp*h))**(ns-1.));
######################
classpower_phi_z50=As*((class_phi_z50[:,3])**2)*((class_phi_z50[:,0]/(kp*h))**(ns-1.));
# classpower_phi_z30=As*((class_phi_z30[:,3])**2)*((class_phi_z30[:,0]/(kp*h))**(ns-1.));
# classpower_phi_z10=As*((class_phi_z10[:,3])**2)*((class_phi_z10[:,0]/(kp*h))**(ns-1.));
#######################
#Plot setting
plt.figure(figsize=(15,15))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)
# plt.subplot(211)
# plt.figure(1)
plt.loglog(Gev_power_phi_prime[:,0]*h,Gev_power_phi_prime[:,1] ,color="blue",linestyle='dashed',lw=1.5,label=r"$\Phi'$/H  Gev z=50")
##############################
plt.loglog(class_phi_z50[:,0],classpower_phi_prime_z50[:] ,color="red",linestyle='dashed',lw=1.5,label=r"$\Phi'$/H class, z=50 ")

plt.loglog(P_22_power[:,0]*h,pow_phi_prime_Riess_Sciama[:] ,color="green",linestyle='dashed',lw=1.5,label=r"$\Phi'$/H class, Riess-Sciama z=50 ")

#################################

#################################
plt.legend(bbox_to_anchor=(0.1, 0.45, 0.3, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)
# plt.title('tiling factor=512, N_grid=2048, boxsize =1400.0, time step limit=0.04')
plt.xlabel("k[h/Mpc]",fontsize=14)
plt.ylabel(r"$\mathcal{P} (\Phi'/H))$",fontsize=23)
# plt.xlim(6.e-2,1.e0)
# plt.ylim(6.e-18,2.e-17)

plt.grid(True)

######################
# plt.subplot(212)
# # #z=50
# plt.loglog(Gev_power_phi[:,0]*h,Gev_power_phi[:,1] ,color="Purple",linestyle='dashed',lw=1.5,label=r"Phi_big run Gev z=50, ")
# plt.loglog(class_phi_z50[:,0],classpower_phi_z50[:] ,color="red",linestyle='dashed',lw=1.5,label=r"Phi class  z=50 ")
# plt.legend(bbox_to_anchor=(0.6, 0.9, 0.4, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)

# ##################################################################
# #################################
# #z=10
# # plt.loglog(phi_Gev_lcdm_z_10[:,0]*h,phi_Gev_lcdm_z_10[:,1] ,color="green",linestyle='dashed',lw=1.5,label=r"Phi Gev z=10 ")
# # plt.loglog(phi_Big_Gev_lcdm_z_10[:,0]*h,phi_Big_Gev_lcdm_z_10[:,1] ,color="green",linestyle='dashed',lw=1.5,label=r"Phi Gev z=50 ")
# # plt.loglog(class_phi_z10[:,0],classpower_phi_z10[:] ,color="black",linestyle='dashed',lw=1.5,label=r"Phi class  z=10 ")
# plt.legend(bbox_to_anchor=(0.0, 0.35, 0.6, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)
# ######################
# plt.xlabel("k[h/Mpc]",fontsize=14)
# plt.ylabel(r"$\mathcal{P} (\Phi)$",fontsize=23)
# plt.xlim(6.e-2,1.e0)

# plt.grid(True)
######################

# plt.ylim(1.e-3,1.e1)
# plt.savefig('compI.jpg', format='jpg', dpi=500)
plt.grid(True)
plt.show()

# %% [markdown]
# # delta kess comparison

# %%
# params for makin power dimensionless
# H_0 in Gevilution unit.
h=0.67556
Boxsize=320.;
c=2997.; #[100km/s]
HGev=np.sqrt(Boxsize**2/c**2) #0.10677, H0 Gevolution in code's unit
def Hubble_conf_Mpc(a):
    H0=0.00022593979933110373;w=-0.9;h=0.67556;
    Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
    Omega_m=Omega_b+Omega_cdm; Omega_Lambda=0.0;
    Omega_rad=9.16681e-05; Omega_kessence=1.-Omega_m-Omega_rad;
    return H0*np.sqrt(Omega_m*(a**-3)+Omega_rad*(a**-4)+Omega_Lambda+Omega_kessence*(a**(-3*(1+w))))*a
#################################
#Class Hubble factor, H in unit 1/Mpc!
# It is phsyical hubble, to make it conformal need to multiply to a. Hconf = H_phys * a
H_conf_class_z100=Hubble_conf_Mpc(1./(1.+100.)); # Unit=1/Mpc Hconf=a*H
H_conf_class_z10=Hubble_conf_Mpc(1./(1.+10.)); # Unit=1/Mpc Hconf=a*H
H_conf_class_z1=Hubble_conf_Mpc(1./(1.+1.)); # Unit=1/Mpc Hconf=a*H
H_conf_class_z0=Hubble_conf_Mpc(1./(1.+0.)); # Unit=1/Mpc Hconf=a*H
#################################
# Parameters for converting to dimensionless power.
As=2.19*10**-9;
w=-0.9
h=0.67556
kp=0.05/h; 
ns=0.96;
cs2_e3=1.e-6;
#################################

#Making power of class field to compare with Gev
Class_power_z100=np.zeros((np.shape(delta_Gev_kess_z100)[0],8))
Class_power_z10=np.zeros((np.shape(delta_Gev_kess_z10)[0],8))
Class_power_z1=np.zeros((np.shape(delta_Gev_kess_z1)[0],8))
Class_power_z0=np.zeros((np.shape(delta_Gev_kess_z0)[0],8))
# Making interpolation, for delta_kess!
i=3;
interp_class_100 =interp1d(class_newt_z100[:,0],class_newt_z100[:,i])
interp_class_10 =interp1d(class_newt_z10[:,0],class_newt_z10[:,i])
interp_class_1 =interp1d(class_newt_z1[:,0],class_newt_z1[:,i])
interp_class_0 =interp1d(class_newt_z0[:,0],class_newt_z0[:,i])
Class_power_z100[:,i]=As*((interp_class_100(delta_Gev_kess_z100[:,0]))**2)*((delta_Gev_kess_z100[:,0]/kp)**(ns-1.));
Class_power_z10[:,i]=As*((interp_class_10(delta_Gev_kess_z10[:,0]))**2)*((delta_Gev_kess_z10[:,0]/kp)**(ns-1.));
Class_power_z1[:,i]=As*((interp_class_1(delta_Gev_kess_z1[:,0]))**2)*((delta_Gev_kess_z1[:,0]/kp)**(ns-1.));
Class_power_z0[:,i]=As*((interp_class_0(delta_Gev_kess_z0[:,0]))**2)*((delta_Gev_kess_z0[:,0]/kp)**(ns-1.));

#Class delta making
Class_delta_I=((1.+w)/cs2_e3)*((1.-3.*cs2_e3)*Hubble_conf_Mpc(1./(1.+100.))*class_newt_z100[:,1])
Class_delta_II=((1.+w)/cs2_e3)*(-class_newt_z100[:,5])
Class_delta_III=((1.+w)/cs2_e3)*(+class_newt_z100[:,2])
Class_deltakess_z100=Class_delta_I+Class_delta_II+Class_delta_III
Class_delta_pow=As*(Class_deltakess_z100[:]**2)*((class_newt_z100[:,0]/kp)**(ns-1.));


#Plot setting
plt.figure(figsize=(20,20))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)
#################################
plt.figure(1)
#################################
plt.subplot(211)
#################################
plt.loglog(delta_Gev_kess_z100[:,0],Class_power_z100[:,3] ,color="blue",linestyle='dashed',lw=1.5,label=r"class z=100 ")
plt.loglog(delta_Gev_kess_z10[:,0], Class_power_z10[:,3],color="red",linestyle='dashed',lw=1.5,label=r"class z=10 ")
plt.loglog(delta_Gev_kess_z1[:,0], Class_power_z1[:,3],color="black",linestyle='dashed',lw=1.5,label=r"class z=1 ")
plt.loglog(delta_Gev_kess_z0[:,0], Class_power_z0[:,3],color="green",linestyle='dashed',lw=1.5,label=r"class z=0 ")
#Class test:
# plt.loglog(class_newt_z0[:,0], Class_delta_pow,color="red",linestyle='dashed',lw=1.5,label=r"${\delta_{kess}}$ class_test z=100 ")
plt.loglog(delta_Gev_kess_z100[:,0],delta_Gev_kess_z100[:,1],color="blue",linestyle='solid',lw=1.5,label=r"Gev z=95 ")
plt.loglog(delta_Gev_kess_z10[:,0],delta_Gev_kess_z10[:,1],color="red",linestyle='solid',lw=1.5,label=r"Gev z=10 ")
plt.loglog(delta_Gev_kess_z1[:,0],delta_Gev_kess_z1[:,1],color="black",linestyle='solid',lw=1.5,label=r"Gev z=1 ")
plt.loglog(delta_Gev_kess_z0[:,0],delta_Gev_kess_z0[:,1],color="green",linestyle='solid',lw=1.5,label=r"Gev z=0 ")
plt.legend(bbox_to_anchor=(0.0, 0.25, 0.3, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=14)
plt.ylabel(r"$\mathcal{P} (\delta_{kess})$",fontsize=23)
plt.xlim(0.01,5.e-1)
plt.ylim(1.e-10,1.e0)
plt.grid(True)
# plt.savefig('comp_delta.jpg', format='jpg', dpi=500)
#################################
plt.subplot(212)
#################################
plt.loglog(delta_Gev_kess_z100[:,0], np.abs(Class_power_z100[:,i]-delta_Gev_kess_z100[:,1])/delta_Gev_kess_z100[:,1],color="blue",linestyle='dashed',lw=1.5,label=r"  z=100 ")
plt.loglog(delta_Gev_kess_z10[:,0], np.abs(Class_power_z10[:,i]-delta_Gev_kess_z10[:,1])/delta_Gev_kess_z10[:,1],color="red",linestyle='dashed',lw=1.5,label=r"  z=10 ")
plt.loglog(delta_Gev_kess_z1[:,0], np.abs(Class_power_z1[:,i]-delta_Gev_kess_z1[:,1])/delta_Gev_kess_z1[:,1],color="black",linestyle='dashed',lw=1.5,label=r" z=1 ")
plt.loglog(delta_Gev_kess_z0[:,0], np.abs(Class_power_z0[:,i]-delta_Gev_kess_z0[:,1])/delta_Gev_kess_z0[:,1],color="green",linestyle='dashed',lw=1.5,label=r" z=0 ")
####################33
plt.legend(bbox_to_anchor=(0.1, 0.90, 0.3, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=14)
plt.ylabel(r"$|\frac{\mathcal{P} \;(\delta_{class})-\mathcal{P} \;( \delta_{Gev}) }{\mathcal{P}\;( \delta_{Gev})}|$",fontsize=23)
plt.xlim(np.min(piGev_z_100[:,0]),np.max(piGev_z_100[:,0]-0.9))
plt.ylim(1.e-3,1.e3)
plt.grid(True)
plt.show()

# %% [markdown]
# # delta matter comparison

# %%
# params for makin power dimensionless
# H_0 in Gevilution unit.
h=0.67556
Boxsize=320.;
c=2997.; #[100km/s]
HGev=np.sqrt(Boxsize**2/c**2) #0.10677, H0 Gevolution in code's unit
def Hubble_conf_Mpc(a):
    H0=0.00022593979933110373;w=-0.9;h=0.67556;
    Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
    Omega_m=Omega_b+Omega_cdm; Omega_Lambda=0.0;
    Omega_rad=9.16681e-05; Omega_kessence=1.-Omega_m-Omega_rad;
    return H0*np.sqrt(Omega_m*(a**-3)+Omega_rad*(a**-4)+Omega_Lambda+Omega_kessence*(a**(-3*(1+w))))*a
#################################
#Class Hubble factor, H in unit 1/Mpc!
# It is phsyical hubble, to make it conformal need to multiply to a. Hconf = H_phys * a
H_conf_class_z100=Hubble_conf_Mpc(1./(1.+100.)); # Unit=1/Mpc Hconf=a*H
H_conf_class_z10=Hubble_conf_Mpc(1./(1.+10.)); # Unit=1/Mpc Hconf=a*H
H_conf_class_z1=Hubble_conf_Mpc(1./(1.+1.)); # Unit=1/Mpc Hconf=a*H
H_conf_class_z0=Hubble_conf_Mpc(1./(1.+0.)); # Unit=1/Mpc Hconf=a*H
#################################
# Parameters for converting to dimensionless power.
As=2.19*10**-9;
h=0.67556
kp=0.05/h; 
ns=0.96;
cs2=1.e-6;
#################################
#k list:
klist_100=delta_Gev_m_z100[:,0];
klist_10=delta_Gev_m_z10[:,0];
klist_1=delta_Gev_m_z1[:,0];
klist_0=delta_Gev_m_z0[:,0];
#Making power of class field to compare with Gev

Class_power_z100=np.zeros((np.shape(delta_Gev_m_z100)[0],8))
Class_power_z10=np.zeros((np.shape(delta_Gev_m_z10)[0],8))
Class_power_z1=np.zeros((np.shape(delta_Gev_m_z1)[0],8))
Class_power_z0=np.zeros((np.shape(delta_Gev_m_z0)[0],8))
# Making interpolation, for delta_m!
i=6;
interp_class_100 =interp1d(class_newt_z100[:,0],class_newt_z100[:,i])
interp_class_10 =interp1d(class_newt_z10[:,0],class_newt_z10[:,i])
interp_class_1 =interp1d(class_newt_z1[:,0],class_newt_z1[:,i])
interp_class_0 =interp1d(class_newt_z0[:,0],class_newt_z0[:,i])
Class_power_z100[:,i]=As*((interp_class_100(klist_100[:]))**2)*((klist_100/kp)**(ns-1.));
Class_power_z10[:,i]=As*((interp_class_10(klist_10[:]))**2)*((klist_10/kp)**(ns-1.));
Class_power_z1[:,i]=As*((interp_class_1(klist_1[:]))**2)*((klist_1/kp)**(ns-1.));
Class_power_z0[:,i]=As*((interp_class_0(klist_0[:]))**2)*((klist_0/kp)**(ns-1.));

#Plot setting
plt.figure(figsize=(20,20))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)
#################################
plt.figure(1)
#################################
plt.subplot(211)
#################################
#################################
plt.loglog(klist_100[:], Class_power_z100[:,6],color="blue",linestyle='dashed',lw=1.5,label=r"class z=100 ")
plt.loglog(klist_10[:], Class_power_z10[:,6],color="red",linestyle='dashed',lw=1.5,label=r"class z=10 ")
plt.loglog(klist_1[:], Class_power_z1[:,6],color="black",linestyle='dashed',lw=1.5,label=r"class z=1 ")
plt.loglog(klist_0[:], Class_power_z0[:,6],color="green",linestyle='dashed',lw=1.5,label=r"class z=0 ")
plt.loglog(klist_100[:],delta_Gev_m_z100[:,1],color="blue",linestyle='solid',lw=1.5,label=r"Gev z=95 ")
plt.loglog(klist_10[:],delta_Gev_m_z10[:,1],color="red",linestyle='solid',lw=1.5,label=r"Gev z=10 ")
plt.loglog(klist_1[:],delta_Gev_m_z1[:,1],color="black",linestyle='solid',lw=1.5,label=r"Gev z=1 ")
plt.loglog(klist_0[:],delta_Gev_m_z0[:,1],color="green",linestyle='solid',lw=1.5,label=r"Gev z=0 ")
plt.legend(bbox_to_anchor=(0.03, 0.90, 0.3, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=14)
plt.ylabel(r"$\mathcal{P}(\delta_{m}) $",fontsize=23)
plt.xlim(0.01,5.e-1)
# plt.ylim(1.e-15,1.e-7)
plt.grid(True)
#################################
plt.subplot(212)
#################################
plt.loglog(klist_100[:], np.abs(Class_power_z100[:,i]-delta_Gev_m_z100[:,1])/delta_Gev_m_z100[:,1],color="blue",linestyle='dashed',lw=1.5,label=r"  z=100 ")
plt.loglog(klist_10[:], np.abs(Class_power_z10[:,i]-delta_Gev_m_z10[:,1])/delta_Gev_m_z10[:,1],color="red",linestyle='dashed',lw=1.5,label=r"  z=10 ")
plt.loglog(klist_1[:], np.abs(Class_power_z1[:,i]-delta_Gev_m_z1[:,1])/delta_Gev_m_z1[:,1],color="black",linestyle='dashed',lw=1.5,label=r" z=1 ")
plt.loglog(klist_0[:], np.abs(Class_power_z0[:,i]-delta_Gev_m_z0[:,1])/delta_Gev_m_z0[:,1],color="green",linestyle='dashed',lw=1.5,label=r" z=0 ")
# ####################
plt.legend(bbox_to_anchor=(0.1, 0.90, 0.3, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=14)
plt.ylabel(r"$|\frac{\mathcal{P} \;(\delta m_{class})-\mathcal{P} \;( \delta m_{Gev}) }{\mathcal{P}\;( \delta m_{Gev})}|$",fontsize=23)
plt.xlim(np.min(piGev_z_100[:,0]),np.max(piGev_z_100[:,0]-0.9))
plt.ylim(1.e-5,1.e1)
plt.grid(True)
plt.show()

# %% [markdown]
# # Phi comparison

# %%
# params for makin power dimensionless
# H_0 in Gevilution unit.
h=0.67556
Boxsize=320.;
c=2997.; #[100km/s]
HGev=np.sqrt(Boxsize**2/c**2) #0.10677, H0 Gevolution in code's unit
def Hubble_conf_Mpc(a):
    H0=0.00022593979933110373;w=-0.9;h=0.67556;
    Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
    Omega_m=Omega_b+Omega_cdm; Omega_Lambda=0.0;
    Omega_rad=9.16681e-05; Omega_kessence=1.-Omega_m-Omega_rad;
    return H0*np.sqrt(Omega_m*(a**-3)+Omega_rad*(a**-4)+Omega_Lambda+Omega_kessence*(a**(-3*(1+w))))*a
#################################
#Class Hubble factor, H in unit 1/Mpc!
# It is phsyical hubble, to make it conformal need to multiply to a. Hconf = H_phys * a
H_conf_class_z100=Hubble_conf_Mpc(1./(1.+100.)); # Unit=1/Mpc Hconf=a*H
H_conf_class_z10=Hubble_conf_Mpc(1./(1.+10.)); # Unit=1/Mpc Hconf=a*H
H_conf_class_z1=Hubble_conf_Mpc(1./(1.+1.)); # Unit=1/Mpc Hconf=a*H
H_conf_class_z0=Hubble_conf_Mpc(1./(1.+0.)); # Unit=1/Mpc Hconf=a*H
#################################
# Parameters for converting to dimensionless power.
As=2.19*10**-9;
h=0.67556
kp=0.05/h; 
ns=0.96;
cs2=1.e-6;
#################################
#k list:
klist_100=delta_Gev_m_z100[:,0];
klist_10=delta_Gev_m_z10[:,0];
klist_1=delta_Gev_m_z1[:,0];
klist_0=delta_Gev_m_z0[:,0];
#Making power of class field to compare with Gev

Class_power_z100=np.zeros((np.shape(phi_gev_z100)[0],8))
Class_power_z10=np.zeros((np.shape(phi_gev_z100)[0],8))
Class_power_z1=np.zeros((np.shape(phi_gev_z100)[0],8))
Class_power_z0=np.zeros((np.shape(phi_gev_z100)[0],8))
# Making interpolation, for delta_m!
i=5;
interp_class_100 =interp1d(class_newt_z100[:,0],class_newt_z100[:,i])
interp_class_10 =interp1d(class_newt_z10[:,0],class_newt_z10[:,i])
interp_class_1 =interp1d(class_newt_z1[:,0],class_newt_z1[:,i])
interp_class_0 =interp1d(class_newt_z0[:,0],class_newt_z0[:,i])
Class_power_z100[:,i]=As*((interp_class_100(klist_100[:]))**2)*((klist_100/kp)**(ns-1.));
Class_power_z10[:,i]=As*((interp_class_10(klist_10[:]))**2)*((klist_10/kp)**(ns-1.));
Class_power_z1[:,i]=As*((interp_class_1(klist_1[:]))**2)*((klist_1/kp)**(ns-1.));
Class_power_z0[:,i]=As*((interp_class_0(klist_0[:]))**2)*((klist_0/kp)**(ns-1.));

#Plot setting
plt.figure(figsize=(20,20))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)
#################################
plt.figure(1)
#################################
plt.subplot(211)
#################################
#################################
#################################
plt.loglog(klist_100[:], Class_power_z100[:,5],color="blue",linestyle='dashed',lw=1.5,label=r"class z=100 ")
plt.loglog(klist_10[:], Class_power_z10[:,5],color="red",linestyle='dashed',lw=1.5,label=r"class z=10 ")
plt.loglog(klist_1[:], Class_power_z1[:,5],color="black",linestyle='dashed',lw=1.5,label=r"class z=1 ")
plt.loglog(klist_0[:], Class_power_z0[:,5],color="green",linestyle='dashed',lw=1.5,label=r"class z=0 ")

plt.loglog(klist_100[:],phi_gev_z100[:,1],color="blue",linestyle='solid',lw=1.5,label=r"Gev z=100 ")
plt.loglog(klist_100[:],phi_gev_z10[:,1],color="red",linestyle='solid',lw=1.5,label=r"Gev z=10 ")
plt.loglog(klist_100[:],phi_gev_z1[:,1],color="black",linestyle='solid',lw=1.5,label=r"Gev z=1 ")
plt.loglog(klist_100[:],phi_gev_z0[:,1],color="green",linestyle='solid',lw=1.5,label=r"Gev z=0 ")


plt.legend(bbox_to_anchor=(0.0, 0.25, 0.3, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=14)
plt.ylabel(r"$\mathcal{P}(\Phi)$",fontsize=23)
plt.xlim(0.01,5.e-1)
plt.ylim(1.e-13,5.e-10)
plt.grid(True)
#################################
plt.subplot(212)
#################################
plt.loglog(klist_100[:], np.abs(Class_power_z100[:,i]-phi_gev_z100[:,1])/phi_gev_z100[:,1],color="blue",linestyle='dashed',lw=1.5,label=r"  z=100 ")
plt.loglog(klist_10[:], np.abs(Class_power_z10[:,i]-phi_gev_z10[:,1])/phi_gev_z10[:,1],color="red",linestyle='dashed',lw=1.5,label=r"  z=10 ")
plt.loglog(klist_1[:], np.abs(Class_power_z1[:,i]-phi_gev_z1[:,1])/phi_gev_z1[:,1],color="black",linestyle='dashed',lw=1.5,label=r" z=1 ")
plt.loglog(klist_0[:], np.abs(Class_power_z0[:,i]-phi_gev_z0[:,1])/phi_gev_z0[:,1],color="green",linestyle='dashed',lw=1.5,label=r" z=0 ")
# ####################
plt.legend(bbox_to_anchor=(0.1, 0.90, 0.3, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=14)
plt.ylabel(r"$|\frac{\mathcal{P} \;(\Phi{class})-\mathcal{P} \;( \Phi{Gev}) }{\mathcal{P}\;( \Phi{Gev})}|$",fontsize=23)
plt.xlim(np.min(piGev_z_100[:,0]),np.max(piGev_z_100[:,0]-0.9))
plt.ylim(1.e-5,1.e1)
plt.grid(True)
plt.show()

# %% [markdown]
# # Background

# %%
# params for makin power dimensionless
# H_0 in Gevilution unit.
h=0.67556
Boxsize=320.;
c_gev=2997.; #[100km/s]
c=2.99*1.e5; #Km/s
H0_conf_Gev=np.sqrt(Boxsize**2/c**2); #0.10677 rho_crit in Gev=1
H0=100*h/c; #H0 in 1/Mpc unit. 0.00022593979933110373
print("H0[1/Mpc]=100h/c: ",H0);
#################################
#Class Hubble_conformal factor, H in unit 1/Mpc!
# H in unit Mpc!
def Hubble_conf_Mpc(a):
    H0=0.00022593979933110373;w=-0.9;h=0.67556;
    Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
    Omega_m=Omega_b+Omega_cdm; Omega_Lambda=0.0;
    Omega_rad=9.16681e-05; Omega_kessence=1.-Omega_m-Omega_rad;
    return H0*np.sqrt(Omega_m*(a**-3)+Omega_rad*(a**-4)+Omega_Lambda+Omega_kessence*(a**(-3*(1+w))))*a
a=bg_Gevolution[:,2];
# Gevolution background output : H_conf/H0
# Plot settings
#Plot setting
plt.figure(figsize=(20,20))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)

#*******************
#SubplotI
plt.figure(1)
plt.subplot(221)
plt.loglog(a,Hubble_conf_Mpc(a),color="red",label="formula")
plt.loglog(a,bg_Gevolution[:,3]*H0,color="blue",label="Gevolution")
plt.xlim(8e-3,1)
plt.ylim(1e-4,2e-2)
plt.xlabel("a",fontsize=20)
plt.ylabel(r"$\mathcal{H}(a)$",fontsize=20)
plt.legend()
plt.grid(True)

#*******************
#SubplotII
# plt.figure(1)
# Class background is H_phys [1/Mpc] 3d column.
# H_conf= H_phys * a
# 0th comun is redshift.
plt.subplot(222)
a_class=1./(1.+Class_Bg_newt_cs_e3[:,0]);
plt.loglog(a_class,Hubble_conf_Mpc(a_class),color="blue",label="Formula")
plt.loglog(a_class,Class_Bg_newt_cs_e3[:,3]*a_class,color="red",label="Class Bg")
plt.xlim(8e-3,1)
plt.ylim(1e-4,2e-2)
plt.xlabel("a",fontsize=20)
plt.ylabel(r"$\mathcal{H}(a)$",fontsize=20)
plt.legend()
plt.grid(True)

#*******************
#SubplotIII Difference plots
#Difference plot
plt.subplot(223)
a_class=1./(1.+Class_Bg_newt_cs_e3[:,0]);
plt.loglog(a,np.abs(bg_Gevolution[:,3]*H0-Hubble_conf_Mpc(a))/bg_Gevolution[:,3]*H0,color="red",label="Gev-Formula/Gev")
# plt.xlim(8e-3,1)
# plt.ylim(1e-4,2e-2)
plt.xlabel("a",fontsize=20)
plt.ylabel(r"$|\Delta \mathcal{H}/\mathcal{H}|$",fontsize=20)
plt.legend()
plt.grid(True)

#*******************
#SubplotIV 
plt.subplot(224)
a_class=1./(1.+Class_Bg_newt_cs_e3[:,0]);
plt.loglog(a_class,np.abs((Class_Bg_newt_cs_e3[:,3]*a_class-Hubble_conf_Mpc(a_class))/(Class_Bg_newt_cs_e3[:,3]*a_class)),color="red",label="(Class-formula)/class")
# plt.xlim(8e-3,1)
# plt.ylim(2e-3,3e-3)
plt.xlabel("a",fontsize=20)
plt.gca().set_ylim(2.e-3, 3.e-3)
plt.ylabel(r"$|\Delta \mathcal{H}/\mathcal{H}|$",fontsize=20)
plt.legend()
plt.grid(True)

# All subplots adjusting
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25,
                    wspace=0.25)
plt.show()
# Out:
# ('H0[1/Mpc]=100h/c: ', 0.00022593979933110373)

# %%
#Checking Class Poisson equation
def Hubble_conf_Mpc(a):
    H0=0.00022593979933110373;w=-1.;h=0.67556;
    Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
    Omega_m=Omega_b+Omega_cdm; Omega_Lambda=0.0;
    Omega_rad=9.16681e-05; Omega_kessence=1.-Omega_m-Omega_rad;
    return H0*np.sqrt(Omega_m*(a**-3)+Omega_rad*(a**-4)+Omega_Lambda+Omega_kessence*(a**(-3.*(1.+w))))*a
# Class power!
h=0.67556;
Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
Omega_m=Omega_b+Omega_cdm;
a100=1./(1.+100.)
a10=1./(1.+10.)
a1=1./(1.+1.)
a0=1./(1.+0.)
#phi from Poisson equation: 
As=2.19*10**-9;
w=-0.9
h=0.67556
kp=0.05/h; 
ns=0.96;
cs2_e3=1.e-6;
#################################

#Making power of class field to compare with Gev

phi_class_poisson_z100= (9./4.)* (Omega_m*(a100**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)*class_all_z100[:,5]**2/((class_all_z100[:,0]*h)**4)
phi_class_poisson_z10= (9./4.) * (Omega_m*(a10**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.))**4)*class_all_z10[:,5]**2/((class_all_z10[:,0]*h)**4)
phi_class_poisson_z1= (9./4.) * (Omega_m*(a1**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.))**4)*class_all_z1[:,5]**2/((class_all_z1[:,0]*h)**4)
phi_class_poisson_z0= (9./4.) * (Omega_m*(a0**-1))**2 * (Hubble_conf_Mpc(1./(1.+0.))**4)*class_all_z0[:,5]**2/((class_all_z0[:,0]*h)**4)

power_class_z100_direct= As*(class_all_z100[:,6])**2*((class_all_z100[:,0]/kp)**(ns-1.));
power_class_z0_direct= As*(class_all_z0[:,6])**2*((class_all_z0[:,0]/kp)**(ns-1.));

power_class_z0_poisson= As*phi_class_poisson_z100*((class_all_z0[:,0]/kp)**(ns-1.));
power_class_z0_poisson= As*phi_class_poisson_z0*((class_all_z0[:,0]/kp)**(ns-1.));



#Plotting
plt.figure(figsize=(24,24))
plt.subplot(311)
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)

plt.loglog(class_all_z100[:,0],phi_class_poisson_z100[:] ,color="red",linestyle='dashed',lw=1.5,label=r"$\Phi^2/\mathcal{R}^2$ class, z=100, Poisson")
plt.loglog(class_all_z100[:,0],class_all_z100[:,6]**2,color="blue",linestyle='dashed',lw=1.5,label=r"$\Phi^2/\mathcal{R}^2$ class, z=100 directly")

plt.loglog(class_all_z10[:,0],phi_class_poisson_z10[:] ,color="green",linestyle='dashed',lw=1.5,label=r"$\Phi^2/\mathcal{R}^2$ class, z=10, Poisson")
plt.loglog(class_all_z10[:,0],class_all_z10[:,6]**2,color="black",linestyle='dashed',lw=1.5,label=r"$\Phi^2/\mathcal{R}^2$ class, z=10, directly")

plt.loglog(class_all_z1[:,0],phi_class_poisson_z1[:] ,color="purple",linestyle='dashed',lw=1.5,label=r"$\Phi^2/\mathcal{R}^2$ class, z=1, Poisson")
plt.loglog(class_all_z1[:,0],class_all_z1[:,6]**2 ,color="cyan",linestyle='dashed',lw=1.5,label=r"$\Phi^2/\mathcal{R}^2$ class, z=1, directly")

plt.loglog(class_all_z0[:,0],phi_class_poisson_z0[:] ,color="magenta",linestyle='dashed',lw=1.5,label=r"$\Phi^2/\mathcal{R}^2$ class, z=0, Poisson")
plt.loglog(class_all_z0[:,0],class_all_z0[:,6]**2 ,color="pink",linestyle='dashed',lw=1.5,label=r"$\Phi^2/\mathcal{R}^2$ class, z=0, directly")


plt.legend(bbox_to_anchor=(0.0, 0.40, 0.4, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)
# plt.title('tiling factor=512, N_grid=2048, boxsize =1400.0, time step limit=0.04')
plt.xlabel("k[1/Mpc]",fontsize=14)
plt.ylabel(r"$ |\mathcal{P}(\Phi)|$",fontsize=23)
plt.grid(True)

plt.subplot(312)

plt.loglog(class_all_z100[:,0],class_all_z100[:,6]**2 ,color="red",linestyle='dashed',lw=1.5,label=r"$ \delta_m^2 $ class, z=100")
plt.loglog(class_all_z10[:,0],class_all_z10[:,6]**2 ,color="blue",linestyle='dashed',lw=1.5,label=r"$\delta_m^2 $ class, z=10")
plt.loglog(class_all_z1[:,0],class_all_z1[:,6]**2 ,color="black",linestyle='dashed',lw=1.5,label=r"$\delta_m^2 $ class, z=1")
plt.loglog(class_all_z0[:,0],class_all_z0[:,6]**2 ,color="green",linestyle='dashed',lw=1.5,label=r"$\delta_m^2 $ class, z=0")

#################################
plt.legend(bbox_to_anchor=(0.0, 0.75, 0.3, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)
# plt.title('tiling factor=512, N_grid=2048, boxsize =1400.0, time step limit=0.04')
plt.xlabel("k[1/Mpc]",fontsize=14)
plt.ylabel(r"$|\mathcal{P}|$",fontsize=23)
plt.grid(True)



plt.subplot(313)

plt.loglog(class_all_z100[:,0],np.abs(phi_class_poisson_z100[:]-class_all_z100[:,6]**2)/(class_all_z100[:,6]**2) ,color="red",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi$ class, z=100")
plt.loglog(class_all_z10[:,0],np.abs(phi_class_poisson_z10[:]-class_all_z10[:,6]**2)/(class_all_z10[:,6]**2) ,color="black",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi$ class, z=10 ")
plt.loglog(class_all_z1[:,0],np.abs(phi_class_poisson_z1[:]-class_all_z1[:,6]**2)/(class_all_z1[:,6]**2) ,color="blue",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi$ class, z=1 ")
plt.loglog(class_all_z0[:,0],np.abs(phi_class_poisson_z0[:] - class_all_z0[:,6]**2)/( class_all_z0[:,6]**2) ,color="green",linestyle='dashed',lw=1.5,label=r"$\Delta \mathcal{P}_\Phi/\mathcal{P}_\Phi$ class, z=0 ")

#################################
plt.legend(bbox_to_anchor=(0.7, 0.15, 0.3, .102), loc=1,ncol=1,fontsize=13, mode="expand", borderaxespad=0.)
# plt.title('tiling factor=512, N_grid=2048, boxsize =1400.0, time step limit=0.04')
plt.xlim(1.e-4,1.e1)
plt.ylim(1.e-3,2.e-1)

plt.xlabel("k[1/Mpc]",fontsize=14)
plt.ylabel(r"$|\Delta \Phi|/\Phi$",fontsize=23)
plt.grid(True)


plt.savefig('Class_Poisson.jpg', format='jpg', dpi=500)
plt.show()

# %% [markdown]
# # Class Consistency checks!

# %%
cs2_e3=1.e-6;
cs2_e1=1.e-2;
cs2_e0=1.e0;
w=-0.9;
h=0.67;
As=2.215*10.e-9;
ns=0.96;
kp=0.05/h;
H_confz_list=[Hubble_conf_Mpc(1./(1.+100.)),Hubble_conf_Mpc(1./(1.+10.)),Hubble_conf_Mpc(1./(1.+1.)),Hubble_conf_Mpc(1./(1.+0.))]; # Unit=1/Mpc Hconf=a*H
a_list=[1./(1.+100.),1./(1.+10.),1./(1.+1.),1./(1.+0.)];
z_list=[100,10,1,0]
# According to the formula it is different, maybe because different comsological parameters!
# pi' definition is so sensitive to the exact amount of Hconf_zini!!!
# \pi_conf in Newtonian in class : -(-\theta/k^2) pi here is conformal pi! and there is "-" from the definition of \theta!
#K=1/Mpc and theta itself is in Mpc-1 so pi is in Mpc unit! and the conversion.
i=0;
pi_class_cs_e3_newt=(class_z_all[i][:,4]/((class_z_all[i][:,0]*h)**2) );
#     pi_class_cs_e1_newt_zlist.append(class_cs_e1_newt[i][:,4]/((class_cs_e1_newt[i][:,0]*h)**2));
#     pi_class_cs_e0_newt_zlist.append(class_cs_e0_newt[i][:,4]/((class_cs_e0_newt[i][:,0]*h)**2));
#*********************************
#\pi_v in class
# Psi is Class_newt_z100[:,7] and delta=Class_newt_z100[:,4]
#pi'_conf in class according to the formula: delta_kess= (1+w/cs2)[-Psi + pi' + Hconf * pi (-3cs2 +1)]
pi_prime_class_cs_e3_newt_zlist=(cs2_e3*class_z_all[i][:,3]/(1.+w) + H_confz_list[i]*pi_class_cs_e3_newt*(3.*cs2_e3-1.) + class_z_all[i][:,5]) ;
#     pi_prime_class_cs_e1_newt_zlist.append(cs2_e1*class_cs_e1_newt[i][:,3]/(1.+w) + H_confz_list[i]*pi_class_cs_e1_newt_zlist[i]*(3.*cs2_e1-1.) + class_cs_e1_newt[i][:,5]) ;
#     pi_prime_class_cs_e0_newt_zlist.append(cs2_e0*class_cs_e0_newt[i][:,3]/(1.+w) + H_confz_list[i]*pi_class_cs_e0_newt_zlist[i]*(3.*cs2_e0-1.) + class_cs_e0_newt[i][:,5]) ;

#*********************************

# Some checks!
# We expect that \dot{\pi} + \Psi vanish! which we get \pi'+ H \pi -\Psi, cs=1.e-3;
pidot_zlist=(pi_prime_class_cs_e3_newt_zlist + H_confz_list[i] * pi_class_cs_e3_newt)
Psi_zlist=(class_z_all[i][:,5])
#*********************************

#Plot setting
plt.figure(figsize=(20,20))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)

#*******************
#SubplotI Check that the pi and are made correctly with correct H-conf
#     plt.figure(1)
plt.subplot(321)
plt.loglog(class_z_all[i][:,0],class_z_all[i][:,1],color="red",label=r"$\pi$ in the file, $c_s=10^{-3}$, z="+str(z_list[i]))
plt.loglog(class_z_all[i][:,0],pi_class_cs_e3_newt[:],color="blue",label=r"$\pi$, made here by $\theta/k^2$")
plt.loglog(class_z_all[i][:,0],(pi_class_cs_e3_newt[:]-class_z_all[i][:,1]),color="green",label=r"$\pi$ difference")
plt.legend(bbox_to_anchor=(0.05, 0.20, 0.46, .102), loc=1,ncol=1,fontsize=12, mode="expand", borderaxespad=0.)
# plt.yscale('log')
plt.xlabel("k[h/Mpc]",fontsize=11)
plt.ylabel(r"$\pi/\mathcal{R}$",fontsize=11)
# plt.xlim(0.0001,5)
plt.grid(True)

# #     #*******************
# #     #SubplotII Check that the pi' are made correctly with correct H-conf
plt.subplot(322)
plt.semilogx(class_z_all[i][:,0],class_z_all[i][:,2],color="red",label=r"$\pi'$ in the file, $c_s=10^{-3}$, z="+str(z_list[i]))
plt.semilogx(class_z_all[i][:,0],pi_prime_class_cs_e3_newt_zlist[:],color="blue",label=r"$\pi'$ made here by $\pi'_{conf}=\frac{c_s^2}{1+w}\delta + \Psi +\mathcal{H}\pi (3c_s^2-1)$")
plt.semilogx(class_z_all[i][:,0],(pi_prime_class_cs_e3_newt_zlist[:]-class_z_all[i][:,2]),color="green",label=r"$\pi'$ difference")
plt.legend(bbox_to_anchor=(0.05, 0.18, 0.66, .102), loc=1,ncol=1,fontsize=12, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=11)
plt.ylabel(r"$\pi'$",fontsize=11)
plt.grid(True)

# #     #*******************
# #     #SubplotIII Check that the \dot{pi} and \Psi comparison
plt.subplot(323)
plt.loglog(class_z_all[i][:,0],pidot_zlist[:],color="red",label=r"$\pi'+ \mathcal{H} \pi =\dot{\pi}$ in the file")
plt.loglog(class_z_all[i][:,0],Psi_zlist[:],color="blue",label=r"$\Psi$")
plt.loglog(class_z_all[i][:,0],np.abs(pidot_zlist[:]-Psi_zlist[:]),color="green",label=r"$ |\Psi-\dot{\pi}|$")

plt.legend(bbox_to_anchor=(0.00, 0.50, 0.26, .102), loc=1,ncol=1,fontsize=12, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=11)
plt.ylabel(r"$T/{\mathcal{R}}$",fontsize=11)
plt.grid(True)

# #     #*******************
# #     #SubplotIV Check that the pi' + Hconf \pi -psi = pi_dot  -Psi , is  comparable with cs2 k^2/H^2 \Psi!
# #     # For cs->0 these plots should be the same! (pi_dot  -Psi) -> cs2 k^2/H^2 \Psi
plt.subplot(324)
plt.loglog(class_z_all[i][:,0],np.abs(pidot_zlist[:]-Psi_zlist[:]),color="red",label=r"$\pi'+ \mathcal{H} \pi -\Psi$ in the file")
plt.loglog(class_z_all[i][:,0],cs2_e3*(class_z_all[i][:,0]*h/(H_confz_list[i]))**2 * Psi_zlist[:],color="blue",label=r"$ c_s^2 k^2/\mathcal{H}^2 \Psi$")
plt.legend(bbox_to_anchor=(0.25, 0.90, 0.29, .102), loc=1,ncol=1,fontsize=12, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=11)
plt.ylabel(r"$|T/{\mathcal{R}}|$",fontsize=11)
plt.grid(True)


# plt.savefig('Class_1.jpg', format='jpg', dpi=500)
# All subplots adjusting
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25,
                        wspace=0.25)
plt.show()
