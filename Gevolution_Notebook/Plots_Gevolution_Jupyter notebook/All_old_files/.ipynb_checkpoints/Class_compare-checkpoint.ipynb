# %%
import numpy as np
import matplotlib.pylab as plt
from scipy.interpolate import interp1d

# %% [markdown]
# # Comparison between field transfer in hi-class and EFTcamb

# %%
synch=np.loadtxt("./output/psi_Synch_class.dat")
newt=np.loadtxt("./output/psi_Newt_class.dat")
synch_hiclass=np.loadtxt("./../hi_class/JupyterNotebook/Kessence_field_direct_cs0.dat")

# %%
data = synch_hiclass
astar=1./(1.) # z=0, desired redshift
ainterval=0.01
mask = np.logical_and(data[:,1]>astar-ainterval, data[:,1]<astar+ainterval)
dataprime = data[mask]
condition=np.zeros(np.shape(dataprime)[0])
for i in range(0,np.shape(dataprime)[0]-1):
#     consition[ii] =np.array_equal(dataprime[i,0],dataprime[i+1,0])
    condition[i]=int(np.array_equal(dataprime[i,0],dataprime[i+1,0]))
klistinitial=np.zeros(np.shape(dataprime)[0]);
j=0;
for i in range (0,np.shape(dataprime)[0]-1):
    if (condition[i]==0):
        klistinitial[j]=dataprime[i-1,0]
        j+=1;

klist = klistinitial[klistinitial!=0]
dataprime_separated = np.zeros((np.shape(klist)[0],np.shape(dataprime)[0],9))

for l,p in enumerate(klist):
    w = np.shape(dataprime[dataprime[:,0]==p])[0]
    dataprime_separated[l,:w,:] = dataprime[dataprime[:,0]==p]
# np.shape(dataprime_separated)
hiclass_cs0=np.zeros((np.shape(klist)[0],7)); # the final file for the fiels are initialized, klist is the list ok k without repitition
# Transfer_kess=np.zeros((np.shape(klist)[0],2)); # the final file for the fiels are initialized, klist is the list ok k without repitition

for i in range(np.shape(klist)[0]):
    Vec_x = dataprime_separated[i,dataprime_separated[i,:,0]!=0,:]
#     interp_pi=interp1d(Vec_x[:,1],Vec_x[:,2], kind='cubic')
#     interp_pi_prime=interp1d(Vec_x[:,1], Vec_x[:,3], kind='cubic')
#     interp_pi_prime_prime=interp1d(Vec_x[:,1], Vec_x[:,4], kind='cubic')
    interp_deltarho=interp1d(Vec_x[:,1],Vec_x[:,2])
    interp_pi=interp1d(Vec_x[:,1], Vec_x[:,3])
    interp_pi_synch=interp1d(Vec_x[:,1], Vec_x[:,4])
    interp_pi_prime=interp1d(Vec_x[:,1], Vec_x[:,5])
    interp_psi_synch=interp1d(Vec_x[:,1], Vec_x[:,6])
#     interp_pi_prime=interp1d(Vec_x[:,1], Vec_x[:,4])
#     psi_sync=interp1d(Vec_x[:,1], Vec_x[:,5])
    alpha=interp1d(Vec_x[:,1], Vec_x[:,6])
    alpha_prime=interp1d(Vec_x[:,1], Vec_x[:,7])

#     interp_pi_prime_prime=interp1d(Vec_x[:,1], Vec_x[:,4])
    hiclass_cs0[i,0]=klist[i]
#     Final_file[i,1]=astar
    hiclass_cs0[i,1]=interp_pi(astar)
    hiclass_cs0[i,2]=interp_deltarho(astar)
    hiclass_cs0[i,3]=interp_pi_synch(astar)
    hiclass_cs0[i,4]=interp_pi_prime(astar)
    hiclass_cs0[i,5]=interp_psi_synch(astar)
    hiclass_cs0[i,6]=alpha(astar)
    hiclass_cs0[i,3]=alpha_prime(astar)

#     Final_file[i,4]=interp_pi_prime(astar)
#     Final_file[i,5]=psi_sync(astar)
#     Final_file[i,6]=alpha(astar)
#     Final_file[i,7]=alpha_prime(astar)

#     Final_file[i,4]=interp_pi_prime_prime(astar)
# Final_file = Final_file[Final_file[:,0].argsort()]
# Transfer_kess[:,0]=Final_file[:,0]; # wavenumber
# Transfer_kess[:,1]=Final_file[:,1]; # redshift
# Transfer_kess[:,2]=Final_file[:,2] # T= \pi
# Transfer_kess[:,3]=Final_file[:,3]; # T_pi_dot= \pi_v
# Transfer_kess[:,4]=Final_file[:,4]*Final_file[:,4]; # T_pi_dot_dot= \pi_v^2
hiclass_cs0[:10,:3]
# np.savetxt("Test_ceck.txt",hiclass_cs0)
# Out:
# array([[  0.7241469,  10.69908  , -21.84431  ],
#        [  0.6192239,  13.56422  , -28.39103  ],
#        [  0.5528646,  16.12431  , -34.23289  ],
#        [  0.5066885,  18.42328  , -39.47271  ],
#        [  0.4716919,  20.55281  , -44.32171  ],
#        [  0.4434967,  22.58371  , -48.94222  ],
#        [  0.4197903,  24.55664  , -53.42814  ],
#        [  0.3992433,  26.51161  , -57.87011  ],
#        [  0.3810343,  28.45577  , -62.28612  ],
#        [  0.3646255,  30.43107  , -66.76954  ]])

# %%
data = synch
astar=1./(1.) # z=0, desired redshift
ainterval=0.01
mask = np.logical_and(data[:,1]>astar-ainterval, data[:,1]<astar+ainterval)
dataprime = data[mask]
condition=np.zeros(np.shape(dataprime)[0])
for i in range(0,np.shape(dataprime)[0]-1):
#     consition[ii] =np.array_equal(dataprime[i,0],dataprime[i+1,0])
    condition[i]=int(np.array_equal(dataprime[i,0],dataprime[i+1,0]))
klistinitial=np.zeros(np.shape(dataprime)[0]);
j=0;
for i in range (0,np.shape(dataprime)[0]-1):
    if (condition[i]==0):
        klistinitial[j]=dataprime[i-1,0]
        j+=1;

klist = klistinitial[klistinitial!=0]
dataprime_separated = np.zeros((np.shape(klist)[0],np.shape(dataprime)[0],3))

for l,p in enumerate(klist):
    w = np.shape(dataprime[dataprime[:,0]==p])[0]
    dataprime_separated[l,:w,:] = dataprime[dataprime[:,0]==p]
# np.shape(dataprime_separated)
Final_synch=np.zeros((np.shape(klist)[0],2)); # the final file for the fiels are initialized, klist is the list ok k without repitition
# Transfer_kess=np.zeros((np.shape(klist)[0],2)); # the final file for the fiels are initialized, klist is the list ok k without repitition

for i in range(np.shape(klist)[0]):
    Vec_x = dataprime_separated[i,dataprime_separated[i,:,0]!=0,:]
    interp_pi=interp1d(Vec_x[:,1],Vec_x[:,2])
    Final_synch[i,0]=klist[i]
#     Final_file[i,1]=astar
    Final_synch[i,1]=interp_pi(astar)
Final_synch[:10,:3]
# Out:
# array([[ 0.7241469 ,  0.00200448],
#        [ 0.6192239 ,  0.00258749],
#        [ 0.5528646 ,  0.0031076 ],
#        [ 0.5066885 ,  0.00357416],
#        [ 0.4716919 ,  0.00400596],
#        [ 0.4434967 ,  0.00441743],
#        [ 0.4197903 ,  0.00481706],
#        [ 0.3992433 ,  0.00521276],
#        [ 0.3810343 ,  0.00560615],
#        [ 0.3646255 ,  0.00600569]])

# %%
data = newt
astar=1./(1.) # z=0, desired redshift
ainterval=0.01
mask = np.logical_and(data[:,1]>astar-ainterval, data[:,1]<astar+ainterval)
dataprime = data[mask]
condition=np.zeros(np.shape(dataprime)[0])
for i in range(0,np.shape(dataprime)[0]-1):
#     consition[ii] =np.array_equal(dataprime[i,0],dataprime[i+1,0])
    condition[i]=int(np.array_equal(dataprime[i,0],dataprime[i+1,0]))
klistinitial=np.zeros(np.shape(dataprime)[0]);
j=0;
for i in range (0,np.shape(dataprime)[0]-1):
    if (condition[i]==0):
        klistinitial[j]=dataprime[i-1,0]
        j+=1;

klist = klistinitial[klistinitial!=0]
dataprime_separated = np.zeros((np.shape(klist)[0],np.shape(dataprime)[0],3))

for l,p in enumerate(klist):
    w = np.shape(dataprime[dataprime[:,0]==p])[0]
    dataprime_separated[l,:w,:] = dataprime[dataprime[:,0]==p]
# np.shape(dataprime_separated)
Final_New=np.zeros((np.shape(klist)[0],2)); # the final file for the fiels are initialized, klist is the list ok k without repitition
# Transfer_kess=np.zeros((np.shape(klist)[0],2)); # the final file for the fiels are initialized, klist is the list ok k without repitition

for i in range(np.shape(klist)[0]):
    Vec_x = dataprime_separated[i,dataprime_separated[i,:,0]!=0,:]
    interp_pi=interp1d(Vec_x[:,1],Vec_x[:,2])
    Final_New[i,0]=klist[i]
#     Final_file[i,1]=astar
    Final_New[i,1]=interp_pi(astar)
Final_New[:10,:3]
# Out:
# array([[ 0.7241469 ,  0.0020047 ],
#        [ 0.6192239 ,  0.00258765],
#        [ 0.5528646 ,  0.00310772],
#        [ 0.5066885 ,  0.00357445],
#        [ 0.4716919 ,  0.00400632],
#        [ 0.4434967 ,  0.00441766],
#        [ 0.4197903 ,  0.00481728],
#        [ 0.3992433 ,  0.00521312],
#        [ 0.3810343 ,  0.00560651],
#        [ 0.3646255 ,  0.006006  ]])

# %% [markdown]
# # Class fluid trasnfer function in the cs=1e-4 and w=-0.9999, to check the behaviour is like DM transfer function

# %%
h=0.67
plt.plot(Final_New[:,0]/h,Final_New[:,1],color="red",label=r"class, Newt")
# plt.plot(newt[:,0],newt[:,2],color="red",label=r"Class, synch DM ")
# plt.plot(synch[:,0],synch[:,2],color="red",label=r"Class, synch DM ")
plt.plot(Final_synch[:,0]/h,Final_synch[:,1],color="blue",label=r"class, synch")
plt.plot(hiclass_cs0[:,0]/h,hiclass_cs0[:,5],color="black",label=r"hi-class, synch")


# plt.plot(class_test_newt[:,0],-class_test_newt[:,4],color="Blue",label=r"Class, Newt  field")
# plt.plot(class_test_newt[:,0],-class_test_newt[:,3],color="Green",label=r"Class, Newt DM")

# plt.plot(cdm_hiclass[:,0],-cdm_hiclass[:,3],color="Magenta",label=r"hi-class, lcdm, Synch, $z=0$")
# plt.plot(hiclass_lcdm[:,0],-hiclass_lcdm[:,3],color="Blue",label="hi-class cs=1,w_0=-0.9, z=0")
# plt.plot(class_lcdm[:,0],-class_lcdm[:,3],color="Blue",label="hi-class cs=1,w_0=-0.9, z=0")

# plt.plot(class_Newt[:,0]/h,class_Newt[:,3],color="green",label="hi-class cs=1,w_0=-0.9, z=0")

# plt.plot(Final_file_camb_cs0[:,0],-Final_file_camb_cs0[:,1],color="blue",label="camb, w_0=-0.9999, cs=0, z=0")
# plt.plot(cdm_hiclass[:,0],-cdm_hiclass[:,3],color="blue",label="camb, w_0=-0.9999, cs=0, z=0")
# plt.plot(Final_file_camb_cs1[:,0],-Final_file_camb_cs1[:,1]/Final_file_camb_cs1[:,0],color="Magenta",label="camb, w_0=-0.9999, cs=0, z=0")
# plt.plot(class_synch[:,0],class_synch[:,3],color="Green",label="Class, ,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classSynz100[:,0],file_classSynz100[:,4],color="Blue",label="Class_Sync_z=100, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(Myfield[:,0],Myfield[:,3]/(3.1415*(Myfield[:,0]/(0.05))**(0.96-1)),color="Green",label="MyResult_z100, T_fld,w_0=-0.9,cs=1, z=0")

# Myfield[:111,0]**3
# plt.plot(Transfer_kess[:,0],Transfer_kess[:,2],color="Blue",label="hi-class, direct smg, z=0")
plt.legend(bbox_to_anchor=(0.10, 0.5, 0.35, .102), loc=1,ncol=1, fontsize=8 mode="expand", borderaxespad=0.)
plt.title( r"$z=0$")

plt.xscale('log')
plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel(r"$\Psi$")
# plt.ylim(-1.,0.22)
plt.savefig('psi_comp.jpg',bbox_inches='tight')
plt.show()

# %%
data_hi = synch
# print(np.shape(data_hi))
# print(data_hi[:,1].max(),data_hi[:,1].min())

astar_hi=1. # z=0, desired redshift
ainterval_hi=0.01
mask_hi = np.logical_and(data_hi[:,1]>astar_hi-ainterval_hi, data_hi[:,1]<astar_hi+ainterval_hi)
# print (mask)
dataprime_hi = data_hi[mask_hi]
# print(dataprime)
# print(np.shape(dataprime))

condition_hi=np.zeros(np.shape(dataprime_hi)[0])
for i in range(0,np.shape(dataprime_hi)[0]-1):
#     consition[ii] =np.array_equal(dataprime[i,0],dataprime[i+1,0])
    condition_hi[i]=int(np.array_equal(dataprime_hi[i,1],dataprime_hi[i+1,1]))
# print(condition[:200])

klistinitial_hi=np.zeros(np.shape(dataprime_hi)[0]);
j=0;
for i in range (0,np.shape(dataprime_hi)[0]-1):
    if (condition_hi[i]==0):
        klistinitial_hi[j]=dataprime_hi[i-1,0]
        j+=1;

klist_hi = klistinitial_hi[klistinitial_hi!=0]
# klist_hi

dataprime_separated_hi = np.zeros((np.shape(klist_hi)[0],np.shape(dataprime_hi)[0],3))
for l,p in enumerate(klist_hi):
    w = np.shape(dataprime_hi[dataprime_hi[:,1]==p])[0]
    dataprime_separated_hi[l,:w,:] = dataprime_hi[dataprime_hi[:,1]==p]
#     print("separated",dataprime_separated)
np.shape(dataprime_separated_hi)
Final_synch=np.zeros((np.shape(klist_hi)[0],2)); # the final file for the fiels are initialized, klist is the list ok k without repitition
# Transfer_kess=np.zeros((np.shape(klist)[0],8)); # the final file for the fiels are initialized, klist is the list ok k without repitition

for i in range(np.shape(klist_hi)[0]):
#     print(i)
    Vec_x_hi = dataprime_separated_hi[i,dataprime_separated_hi[i,:,1]!=0,:]
#     pi_camb=interp1d(Vec_x_hi[:,1], Vec_x_hi[:,2])
    
#     print(i,(Vec_x_hi[:4,0:3]))
    interp_pi=interp1d(Vec_x_hi[:,0],Vec_x_hi[:,2])
#     interp_pi_prime=interp1d(Vec_x_hi[:,0],Vec_x_hi[:,4])

#     interp_pi_prime=interp1d(Vec_x[:,1], Vec_x[:,3], kind='cubic')
#     interp_pi_prime_prime=interp1d(Vec_x[:,1], Vec_x[:,4], kind='cubic')
    Final_synch[i,0]=klist_hi[i]
#     Final_file_camb_cs0[i,1]=astar_camb
    Final_synch[i,1]=interp_pi(astar_hi)
#     Final_file_camb_cs0[i,2]=interp_pi_prime(astar_hi)

    #     interp_pi_prime_prime=interp1d(Vec_x[:,1], Vec_x[:,4])
Final_synch[:10,:]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-a9813ec41119> in <module>()
#      42
#      43 #     print(i,(Vec_x_hi[:4,0:3]))
# ---> 44     interp_pi=interp1d(Vec_x_hi[:,0],Vec_x_hi[:,2])
#      45 #     interp_pi_prime=interp1d(Vec_x_hi[:,0],Vec_x_hi[:,4])
#      46
#
# /Users/farbod/anaconda2/lib/python2.7/site-packages/scipy/interpolate/interpolate.pyc in __init__(self, x, y, kind, axis, copy, bounds_error, fill_value, assume_sorted)
#     444         # Interpolation goes internally along the first axis
#     445         self.y = y
# --> 446         self._y = self._reshape_yi(self.y)
#     447         self.x = x
#     448         del y, x  # clean up namespace to prevent misuse; use attributes
#
# /Users/farbod/anaconda2/lib/python2.7/site-packages/scipy/interpolate/polyint.pyc in _reshape_yi(self, yi, check)
# ...

# %% [markdown]
# # DM transfer function behaviour in Class and hi-class

# %%
plt.plot(class_synch[:,0],-class_synch[:,3],color="black",label=r"class, Synch gauge $c_s^2=0,w_0=-0.9999, z=0$")
plt.plot(class_Newt[:,0],-class_Newt[:,3],color="red",label=r"Class, Newt $c_s^2=1,cs=0,w_0=-0.9999, z=0$")
# plt.plot(cdm_hiclass[:,0],-cdm_hiclass[:,3],color="Magenta",label=r"hi-class, lcdm, Synch, $z=0$")
plt.plot(hiclass_lcdm[:,0],-hiclass_lcdm[:,3],color="Magenta",label="hi-class Synch gauge $c_s^2=0,w_0=-0.9999, z=0$")
# plt.plot(hiclass_lcdm[:,0],-hiclass_lcdm[:,3],color="Blue",label="hi-class cs=1,w_0=-0.9, z=0")
# plt.plot(class_lcdm[:,0],-class_lcdm[:,3],color="Blue",label="hi-class cs=1,w_0=-0.9, z=0")

# plt.plot(class_Newt[:,0]/h,class_Newt[:,3],color="green",label="hi-class cs=1,w_0=-0.9, z=0")

# plt.plot(Final_file_camb_cs0[:,0],-Final_file_camb_cs0[:,1],color="blue",label="camb, w_0=-0.9999, cs=0, z=0")
# plt.plot(cdm_hiclass[:,0],-cdm_hiclass[:,3],color="blue",label="camb, w_0=-0.9999, cs=0, z=0")
# plt.plot(Final_file_camb_cs1[:,0],-Final_file_camb_cs1[:,1]/Final_file_camb_cs1[:,0],color="Magenta",label="camb, w_0=-0.9999, cs=0, z=0")
# plt.plot(class_synch[:,0],class_synch[:,3],color="Green",label="Class, ,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classSynz100[:,0],file_classSynz100[:,4],color="Blue",label="Class_Sync_z=100, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(Myfield[:,0],Myfield[:,3]/(3.1415*(Myfield[:,0]/(0.05))**(0.96-1)),color="Green",label="MyResult_z100, T_fld,w_0=-0.9,cs=1, z=0")

# Myfield[:111,0]**3
# plt.plot(Transfer_kess[:,0],Transfer_kess[:,2],color="Blue",label="hi-class, direct smg, z=0")
plt.legend(bbox_to_anchor=(0., 1.24, 1., .102), loc=1,ncol=1, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel(r"$T_{cdm}$")
# plt.ylim(-1.,0.22)
# plt.savefig('Kessence-smgfld_comp.jpg',bbox_inches='tight')
plt.show()

# %%
data = field_hiclass_cs0
astar=1./(1.) # z=0, desired redshift
ainterval=0.01
mask = np.logical_and(data[:,1]>astar-ainterval, data[:,1]<astar+ainterval)
dataprime = data[mask]
condition=np.zeros(np.shape(dataprime)[0])
for i in range(0,np.shape(dataprime)[0]-1):
#     consition[ii] =np.array_equal(dataprime[i,0],dataprime[i+1,0])
    condition[i]=int(np.array_equal(dataprime[i,0],dataprime[i+1,0]))
klistinitial=np.zeros(np.shape(dataprime)[0]);
j=0;
for i in range (0,np.shape(dataprime)[0]-1):
    if (condition[i]==0):
        klistinitial[j]=dataprime[i-1,0]
        j+=1;

klist = klistinitial[klistinitial!=0]
dataprime_separated = np.zeros((np.shape(klist)[0],np.shape(dataprime)[0],9))

for l,p in enumerate(klist):
    w = np.shape(dataprime[dataprime[:,0]==p])[0]
    dataprime_separated[l,:w,:] = dataprime[dataprime[:,0]==p]
# np.shape(dataprime_separated)
hiclass_cs0=np.zeros((np.shape(klist)[0],7)); # the final file for the fiels are initialized, klist is the list ok k without repitition
# Transfer_kess=np.zeros((np.shape(klist)[0],2)); # the final file for the fiels are initialized, klist is the list ok k without repitition

for i in range(np.shape(klist)[0]):
    Vec_x = dataprime_separated[i,dataprime_separated[i,:,0]!=0,:]
#     interp_pi=interp1d(Vec_x[:,1],Vec_x[:,2], kind='cubic')
#     interp_pi_prime=interp1d(Vec_x[:,1], Vec_x[:,3], kind='cubic')
#     interp_pi_prime_prime=interp1d(Vec_x[:,1], Vec_x[:,4], kind='cubic')
    interp_deltarho=interp1d(Vec_x[:,1],Vec_x[:,2])
    interp_pi=interp1d(Vec_x[:,1], Vec_x[:,3])
    interp_pi_synch=interp1d(Vec_x[:,1], Vec_x[:,4])
    interp_pi_prime=interp1d(Vec_x[:,1], Vec_x[:,5])
    interp_psi_synch=interp1d(Vec_x[:,1], Vec_x[:,6])
#     interp_pi_prime=interp1d(Vec_x[:,1], Vec_x[:,4])
#     psi_sync=interp1d(Vec_x[:,1], Vec_x[:,5])
    alpha=interp1d(Vec_x[:,1], Vec_x[:,6])
    alpha_prime=interp1d(Vec_x[:,1], Vec_x[:,7])

#     interp_pi_prime_prime=interp1d(Vec_x[:,1], Vec_x[:,4])
    hiclass_cs0[i,0]=klist[i]
#     Final_file[i,1]=astar
    hiclass_cs0[i,1]=interp_pi(astar)
    hiclass_cs0[i,2]=interp_deltarho(astar)
    hiclass_cs0[i,3]=interp_pi_synch(astar)
    hiclass_cs0[i,4]=interp_pi_prime(astar)
    hiclass_cs0[i,5]=interp_psi_synch(astar)
    hiclass_cs0[i,6]=alpha(astar)
    hiclass_cs0[i,3]=alpha_prime(astar)

#     Final_file[i,4]=interp_pi_prime(astar)
#     Final_file[i,5]=psi_sync(astar)
#     Final_file[i,6]=alpha(astar)
#     Final_file[i,7]=alpha_prime(astar)

#     Final_file[i,4]=interp_pi_prime_prime(astar)
# Final_file = Final_file[Final_file[:,0].argsort()]
# Transfer_kess[:,0]=Final_file[:,0]; # wavenumber
# Transfer_kess[:,1]=Final_file[:,1]; # redshift
# Transfer_kess[:,2]=Final_file[:,2] # T= \pi
# Transfer_kess[:,3]=Final_file[:,3]; # T_pi_dot= \pi_v
# Transfer_kess[:,4]=Final_file[:,4]*Final_file[:,4]; # T_pi_dot_dot= \pi_v^2
hiclass_cs0[:10,:3]
# np.savetxt("Test_ceck.txt",hiclass_cs0)
# Out:
# array([[  0.7241469,  10.69908  , -21.84431  ],
#        [  0.6192239,  13.56422  , -28.39103  ],
#        [  0.5528646,  16.12431  , -34.23289  ],
#        [  0.5066885,  18.42328  , -39.47271  ],
#        [  0.4716919,  20.55281  , -44.32171  ],
#        [  0.4434967,  22.58371  , -48.94222  ],
#        [  0.4197903,  24.55664  , -53.42814  ],
#        [  0.3992433,  26.51161  , -57.87011  ],
#        [  0.3810343,  28.45577  , -62.28612  ],
#        [  0.3646255,  30.43107  , -66.76954  ]])

# %%
h=0.67
# deltarho_newtc1=hiclass_cs1[:,2]
# deltarho_Synchc1=deltarho_newtc1-0.3*Hubb*hiclass_cs1[:,3]

# plt.plot(class_synch[:,0], -class_synch[:,3],color="red",label=r"class,Synch, $\delta_{cdm}$ , z=0")
# plt.plot(class_Newt[:,0],-class_Newt[:,3],color="Yellow",label=r"Class, Newt $c_s^2=1,cs=0,w_0=-0.9999, z=0$")
# plt.plot(class_test_newt[:,0],-class_test_newt[:,4],color="Blue",label=r"Class, Newt  field")
# plt.plot(hiclass_cs0[:,0]/h,-deltarho_Synch[:],color="Blue",label="hi-class cs=0,w_0=-0.9999, z=0")
# plt.plot(hiclass_cs1[:,0]/h,-deltarho_Synchc1[:],color="Magenta",label="hi-class cs=0,w_0=-0.9999, z=0")
plt.plot(hiclass_cs0[:,0]/h,-1.e4*(-hiclass_cs0[:,5]+hiclass_cs0[:,4]),color="Blue",label=r"hi-class,Newt, $\delta_{\pi}, cs=10^{-4},w_0=-0.9999, z=0$")
plt.plot(hiclass_cs0[:,0]/h,-hiclass_cs0[:,2],color="red",label=r"hi-class,Newt, $\delta_{\pi}, cs=10^{-4},w_0=-0.9999, z=0$")

# plt.plot(hiclass_cs1[:,0]/h,-hiclass_cs1[:,2],color="black",label=r"hi-class,Newt, $\delta_{\pi}, cs=1,w_0=-0.9, z=0$")
# plt.plot(hiclass_cs0[:,0]/h,-hiclass_cs0[:,2]+3.e-4*Hubb*hiclass_cs0[:,3],color="green",label=r"hi-class, Synch, $\delta_{\pi}, cs=10^{-4},w_0=-0.9999, z=0$")
# plt.plot(hiclass_cs1[:,0]/h,-hiclass_cs1[:,2]+0.3*Hubb*hiclass_cs1[:,3],color="magenta",label=r"hi-class, Synch, $\delta_{\pi}, cs=1,w_0=-0.9, z=0$")

# plt.plot(class_Newt[:,0]/h,class_Newt[:,3],color="green",label="hi-class cs=1,w_0=-0.9, z=0")

# plt.plot(Final_file_camb_cs0[:,0],-Final_file_camb_cs0[:,1],color="blue",label="camb, w_0=-0.9999, cs=0, z=0")
# plt.plot(cdm_hiclass[:,0],-cdm_hiclass[:,3],color="blue",label="camb, w_0=-0.9999, cs=0, z=0")
# plt.plot(Final_file_camb_cs1[:,0],-Final_file_camb_cs1[:,1]/Final_file_camb_cs1[:,0],color="Magenta",label="camb, w_0=-0.9999, cs=0, z=0")
# plt.plot(class_synch[:,0],class_synch[:,3],color="Green",label="Class, ,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classSynz100[:,0],file_classSynz100[:,4],color="Blue",label="Class_Sync_z=100, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(Myfield[:,0],Myfield[:,3]/(3.1415*(Myfield[:,0]/(0.05))**(0.96-1)),color="Green",label="MyResult_z100, T_fld,w_0=-0.9,cs=1, z=0")

# Myfield[:111,0]**3
# plt.plot(Transfer_kess[:,0],Transfer_kess[:,2],color="Blue",label="hi-class, direct smg, z=0")
plt.legend(bbox_to_anchor=(0., 1.21, 1., .102), loc=1,ncol=1, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel("$T$")
# plt.ylim(-1.,0.22)
# plt.savefig('Kessence-smgfld_comp.jpg',bbox_inches='tight')
plt.show()

# %% [markdown]
#   # Plots: Density transfer function in the limits c_s=e-4 , w0=-0.9999

# %%
h=0.67
deltarho_newtc1=hiclass_cs1[:,2]
deltarho_Synchc1=deltarho_newtc1-0.3*Hubb*hiclass_cs1[:,3]

plt.plot(class_test_synch[:,0],-class_test_synch[:,4],color="black",label=r"class,$c_s^2=10^{-8}, w_0=-0.9999$ Synch field, z=0")
plt.plot(class_test_synch[:,0],-class_test_synch[:,3],color="red",label=r"Class,$c_s^2=10^{-8}, w_0=-0.9999$ synch DM ")
plt.plot(class_test_newt[:,0],-class_test_newt[:,4],color="Blue",label=r"Class, Newt,$c_s^2=10^{-8}, w_0=-0.9999$  field")
plt.plot(class_test_newt[:,0],-class_test_newt[:,3],color="Green",label=r"Class, Newt,$c_s^2=10^{-8}, w_0=-0.9999$ DM")
# plt.plot(class_Newt[:,0],-class_Newt[:,3],color="Blue",label=r"Class, Newt $c_s^2=1,cs=0,w_0=-0.9999, z=0$")
# plt.plot(hiclass_cs0[:,0]/h,-deltarho_newt[:],color="black",label="hi-class cs=0,w_0=-0.9999, z=0")
# plt.plot(hiclass_cs0[:,0]/h,-deltarho_Synch[:],color="Blue",label="hi-class cs=0,w_0=-0.9999, z=0")
# plt.plot(hiclass_cs1[:,0]/h,-deltarho_Synchc1[:],color="Magenta",label="hi-class cs=0,w_0=-0.9999, z=0")

# plt.plot(hiclass_cs0[:,0]/h,-hiclass_cs0[:,2],color="blue",label=r"hi-class,Newt, $\delta_{\pi}, cs=10^{-4},w_0=-0.9999, z=0$")
# plt.plot(hiclass_cs1[:,0]/h,-hiclass_cs1[:,2],color="black",label=r"hi-class,Newt, $\delta_{\pi}, cs=1,w_0=-0.9, z=0$")
# plt.plot(hiclass_cs0[:,0]/h,-hiclass_cs0[:,2]+3.e-4*Hubb*hiclass_cs0[:,3],color="green",label=r"hi-class, Synch, $\delta_{\pi}, cs=10^{-4},w_0=-0.9999, z=0$")
# plt.plot(hiclass_cs1[:,0]/h,-hiclass_cs1[:,2]+0.3*Hubb*hiclass_cs1[:,3],color="magenta",label=r"hi-class, Synch, $\delta_{\pi}, cs=1,w_0=-0.9, z=0$")

plt.plot(Final_file_camb_cs0[:,0]/h,-Final_file_camb_cs0[:,1],color="magenta",label="EFTcamb,$c_s^2=10^{-8}, w_0=-0.9999$, z=0")

# plt.plot(Final_file_camb_cs0[:,0],-Final_file_camb_cs0[:,1],color="blue",label="camb, w_0=-0.9999, cs=0, z=0")
# plt.plot(cdm_hiclass[:,0],-cdm_hiclass[:,3],color="blue",label="camb, w_0=-0.9999, cs=0, z=0")
# plt.plot(Final_file_camb_cs1[:,0],-Final_file_camb_cs1[:,1]/Final_file_camb_cs1[:,0],color="Magenta",label="camb, w_0=-0.9999, cs=0, z=0")
# plt.plot(class_synch[:,0],class_synch[:,3],color="Green",label="Class, ,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classSynz100[:,0],file_classSynz100[:,4],color="Blue",label="Class_Sync_z=100, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(Myfield[:,0],Myfield[:,3]/(3.1415*(Myfield[:,0]/(0.05))**(0.96-1)),color="Green",label="MyResult_z100, T_fld,w_0=-0.9,cs=1, z=0")

# Myfield[:111,0]**3
# plt.plot(Transfer_kess[:,0],Transfer_kess[:,2],color="Blue",label="hi-class, direct smg, z=0")
plt.legend(bbox_to_anchor=(0., 1.51, 1., .102), loc=1,ncol=1, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel("$T$")
# plt.ylim(-1.,0.22)
# plt.savefig('Kessence-smgfld_comp.jpg',bbox_inches='tight')
plt.show()

# %% [markdown]
# # alpha comparison

# %%
plt.plot(class_synch[:,0],-(-class_synch[:,4]+class_Newt[:,4])/(0.3*Hubb),color="red",label=r"class, alpha from T_newt-T_synch/coeff , z=0")
# plt.plot(class_Newt[:,0],-class_Newt[:,3],color="green",label=r"Class, Newt $c_s^2=1,cs=0,w_0=-0.9999, z=0$")
# plt.plot(hiclass_cs0[:,0]/h,-deltarho_newt[:],color="black",label="hi-class cs=0,w_0=-0.9999, z=0")
# plt.plot(hiclass_cs0[:,0]/h,-deltarho_Synch[:],color="Blue",label="hi-class cs=0,w_0=-0.9999, z=0")
# plt.plot(hiclass_cs1[:,0]/h,-deltarho_Synchc1[:],color="Magenta",label="hi-class cs=0,w_0=-0.9999, z=0")

plt.plot(hiclass_cs1[:,0]/h,hiclass_cs1[:,3],color="blue",label="hi-class,alpha cs=1,w_0=-0.9, z=0")
# plt.plot(class_Newt[:,0]/h,class_Newt[:,3],color="green",label="hi-class cs=1,w_0=-0.9, z=0")

# plt.plot(Final_file_camb_cs0[:,0],-Final_file_camb_cs0[:,1],color="blue",label="camb, w_0=-0.9999, cs=0, z=0")
# plt.plot(cdm_hiclass[:,0],-cdm_hiclass[:,3],color="blue",label="camb, w_0=-0.9999, cs=0, z=0")
# plt.plot(Final_file_camb_cs1[:,0],-Final_file_camb_cs1[:,1]/Final_file_camb_cs1[:,0],color="Magenta",label="camb, w_0=-0.9999, cs=0, z=0")
# plt.plot(class_synch[:,0],class_synch[:,3],color="Green",label="Class, ,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classSynz100[:,0],file_classSynz100[:,4],color="Blue",label="Class_Sync_z=100, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(Myfield[:,0],Myfield[:,3]/(3.1415*(Myfield[:,0]/(0.05))**(0.96-1)),color="Green",label="MyResult_z100, T_fld,w_0=-0.9,cs=1, z=0")

# Myfield[:111,0]**3
# plt.plot(Transfer_kess[:,0],Transfer_kess[:,2],color="Blue",label="hi-class, direct smg, z=0")
plt.legend(bbox_to_anchor=(0., 1.11, 1., .102), loc=1,ncol=1, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel("$T$")
# plt.ylim(-1.,0.22)
# plt.savefig('Kessence-smgfld_comp.jpg',bbox_inches='tight')
plt.show()

# %%
# plt.plot(class_synch[:,0],class_synch[:,4],color="red",label=r"class, alpha from T_newt-T_synch/coeff , z=0")
plt.plot(class_Newt[:,0],-class_Newt[:,4],color="green",label=r"Class, Newt $c_s^2=1,cs=0,w_0=-0.9999, z=0$")
# plt.plot(hiclass_cs0[:,0]/h,-deltarho_newt[:],color="black",label="hi-class cs=0,w_0=-0.9999, z=0")
# plt.plot(hiclass_cs0[:,0]/h,-deltarho_Synch[:],color="Blue",label="hi-class cs=0,w_0=-0.9999, z=0")
# plt.plot(hiclass_cs1[:,0]/h,-deltarho_Synchc1[:],color="Magenta",label="hi-class cs=0,w_0=-0.9999, z=0")
# plt.plot(hiclass_cs1[:,0]/h,-hiclass_cs1[:,2],color="blue",label="hi-class,alpha cs=1,w_0=-0.9, z=0")
# plt.plot(hiclass_cs1[:,0]/h,hiclass_cs1[:,3],color="magenta",label="hi-class,alpha cs=1,w_0=-0.9, z=0")
# plt.plot(hiclass_cs1[:,0]/h,hiclass_cs1[:,1],color="black",label="hi-class,alpha cs=1,w_0=-0.9, z=0")
# plt.plot(Final_file_camb_cs0[:,0],-Final_file_camb_cs0[:,1],color="red",label="EFTcamb,$c_s^2=10^{-8}, w_0=-0.9999$, z=0")

# plt.plot(class_Newt[:,0]/h,class_Newt[:,3],color="green",label="hi-class cs=1,w_0=-0.9, z=0")

# plt.plot(Final_file_camb_cs0[:,0],-Final_file_camb_cs0[:,1],color="blue",label="camb, w_0=-0.9999, cs=0, z=0")
# plt.plot(cdm_hiclass[:,0],-cdm_hiclass[:,3],color="blue",label="camb, w_0=-0.9999, cs=0, z=0")
# plt.plot(Final_file_camb_cs1[:,0],-Final_file_camb_cs1[:,1]/Final_file_camb_cs1[:,0],color="Magenta",label="camb, w_0=-0.9999, cs=0, z=0")
# plt.plot(class_synch[:,0],class_synch[:,3],color="Green",label="Class, ,w_0=-0.9,cs=1, z=0")
# plt.plot(file_classSynz100[:,0],file_classSynz100[:,4],color="Blue",label="Class_Sync_z=100, T_fld,w_0=-0.9,cs=1, z=0")
# plt.plot(Myfield[:,0],Myfield[:,3]/(3.1415*(Myfield[:,0]/(0.05))**(0.96-1)),color="Green",label="MyResult_z100, T_fld,w_0=-0.9,cs=1, z=0")

# Myfield[:111,0]**3
# plt.plot(Transfer_kess[:,0],Transfer_kess[:,2],color="Blue",label="hi-class, direct smg, z=0")
plt.legend(bbox_to_anchor=(0., 1.41, 1., .102), loc=1,ncol=1, mode="expand", borderaxespad=0.)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("k[h/Mpc]")
plt.ylabel("$T$")
# plt.ylim(-1.,0.22)
# plt.savefig('Kessence-smgfld_comp.jpg',bbox_inches='tight')
plt.show()
