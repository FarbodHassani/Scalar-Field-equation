# %% [markdown]
# # Notebook for comparison beween  Gevolution and class and agreement between class and hi-class

# %%
import numpy as np
import matplotlib.pylab as plt
from scipy.interpolate import interp1d
from pylab import rcParams
import scipy.integrate as integrate
tableau12 = [(0, 0, 0), (50, 0, 0), (0, 50, 0), (0, 0, 50),    
             (0, 50, 50), (50, 50, 0), (50, 0, 50), (50, 50, 50),    
             (100, 50, 50), (50, 100, 50), (50, 50, 100), (100, 100, 100)]    
  
# Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.    
for i in range(len(tableau12)):    
    r, g, b = tableau12[i]    
    tableau12[i] = (r / 255., g / 255., b / 255.) 
    
tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),    
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),    
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),    
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),    
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]    
  
# Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.    
for i in range(len(tableau20)):    
    r, g, b = tableau20[i]    
    tableau20[i] = (r / 255., g / 255., b / 255.)
# plt.style.available
plt.rcParams.update(plt.rcParamsDefault)

# plt.style.use('seaborn-paper')
plt.rcParams['font.serif'] = 'Ubuntu'

# %% [markdown]
# # Gevolution linear and class reading

# %%
# Gevolution Linear
# addressGev="Daint_Runs/Kessence_Linear_Ngrid_1920_DT_0.04/output";
addressGev="fld_linear_kessence";

# addressGev="Gevolution_outputs/2018.06.22.00.29.47";
########
# z=100
########
Gev_lin_deltakess_z100=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_000_delta_kess.dat")
Gev_lin_zeta_z100=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_000_zeta.dat")
Gev_lin_Hpi_z100=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_000_pi_k.dat")
Gev_lin_delta_m_z100=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_000_delta.dat")
Gev_lin_phi_z100=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_000_phi.dat")
Gev_lin_phi_prime_z100=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_000_phi_prime.dat")

########
# z=50
########
Gev_lin_deltakess_z50=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_001_delta_kess.dat")
Gev_lin_zeta_z50=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_001_zeta.dat")
Gev_lin_Hpi_z50=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_001_pi_k.dat")
Gev_lin_delta_m_z50=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_001_delta.dat")
Gev_lin_phi_z50=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_001_phi.dat")
Gev_lin_phi_prime_z50=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_001_phi_prime.dat")
########
# z=10
########
Gev_lin_deltakess_z10=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_002_delta_kess.dat")
Gev_lin_zeta_z10=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_002_zeta.dat")
Gev_lin_Hpi_z10=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_002_pi_k.dat")
Gev_lin_delta_m_z10=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_002_delta.dat")
Gev_lin_phi_z10=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_002_phi.dat")
Gev_lin_phi_prime_z10=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_002_phi_prime.dat")
########
# z=6
########
Gev_lin_deltakess_z6=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_003_delta_kess.dat")
Gev_lin_zeta_z6=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_003_zeta.dat")
Gev_lin_Hpi_z6=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_003_pi_k.dat")
Gev_lin_delta_m_z6=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_003_delta.dat")
Gev_lin_phi_z6=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_003_phi.dat")
Gev_lin_phi_prime_z6=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_003_phi_prime.dat")
########
# z=1
########
Gev_lin_deltakess_z1=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_004_delta_kess.dat")
Gev_lin_zeta_z1=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_004_zeta.dat")
Gev_lin_Hpi_z1=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_004_pi_k.dat")
Gev_lin_delta_m_z1=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_004_delta.dat")
Gev_lin_phi_z1=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_004_phi.dat")
Gev_lin_phi_prime_z1=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_004_phi_prime.dat")
########
# z=0
########
Gev_lin_deltakess_z0=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_005_delta_kess.dat")
Gev_lin_zeta_z0=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_005_zeta.dat")
Gev_lin_Hpi_z0=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_005_pi_k.dat")
Gev_lin_delta_m_z0=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_005_delta.dat")
Gev_lin_phi_z0=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_005_phi.dat")
Gev_lin_phi_prime_z0=np.loadtxt("./"+addressGev+"/kess_pk_cs_e3_005_phi_prime.dat")

Gev_lin_deltakess_z_all=[Gev_lin_deltakess_z100, Gev_lin_deltakess_z50, Gev_lin_deltakess_z10,
                         Gev_lin_deltakess_z6, Gev_lin_deltakess_z1, Gev_lin_deltakess_z0];
Gev_lin_zeta_z_all=[Gev_lin_zeta_z100, Gev_lin_zeta_z50, Gev_lin_zeta_z10,
                         Gev_lin_zeta_z6, Gev_lin_zeta_z1, Gev_lin_zeta_z0];
Gev_lin_Hpi_z_all=[Gev_lin_Hpi_z100, Gev_lin_Hpi_z50, Gev_lin_Hpi_z10,
                         Gev_lin_Hpi_z6, Gev_lin_Hpi_z1, Gev_lin_Hpi_z0];
Gev_lin_delta_m_z_all=[Gev_lin_delta_m_z100, Gev_lin_delta_m_z50, Gev_lin_delta_m_z10,
                         Gev_lin_delta_m_z6, Gev_lin_delta_m_z1, Gev_lin_delta_m_z0];
Gev_lin_phi_prime_z_all=[Gev_lin_phi_prime_z100, Gev_lin_phi_prime_z50, Gev_lin_phi_prime_z10,
                         Gev_lin_phi_prime_z6, Gev_lin_phi_prime_z1, Gev_lin_phi_prime_z0];
Gev_lin_phi_z_all=[Gev_lin_phi_z100, Gev_lin_phi_z50, Gev_lin_phi_z10,
                         Gev_lin_phi_z6, Gev_lin_phi_z1, Gev_lin_phi_z0];
#Backgrounds:
bg_Gevolution_lin=np.loadtxt("./"+addressGev+"/kess_cs_e3_background.dat")


#Gev_fluid:
#class powerspectra
address_fld="Fluid_Gevolution/kess/";
# address_fld="Gevolution_outputs/gev_normal";



########
# z=100
########
Gev_fld_delta_z100=np.loadtxt("./"+address_fld+"/kess_pk_cs_e3_000_delta.dat")
Gev_fld_phi_z100=np.loadtxt("./"+address_fld+"/kess_pk_cs_e3_000_phi.dat")

########
# z=50
########
Gev_fld_delta_z50=np.loadtxt("./"+address_fld+"/kess_pk_cs_e3_001_delta.dat")
Gev_fld_phi_z50=np.loadtxt("./"+address_fld+"/kess_pk_cs_e3_001_phi.dat")
########
# z=10
########
Gev_fld_delta_z10=np.loadtxt("./"+address_fld+"/kess_pk_cs_e3_002_delta.dat")
Gev_fld_phi_z10=np.loadtxt("./"+address_fld+"/kess_pk_cs_e3_002_phi.dat")
########
# z=6
########
Gev_fld_delta_z6=np.loadtxt("./"+address_fld+"/kess_pk_cs_e3_003_delta.dat")
Gev_fld_phi_z6=np.loadtxt("./"+address_fld+"/kess_pk_cs_e3_003_phi.dat")
########
# z=1
########
Gev_fld_delta_z1=np.loadtxt("./"+address_fld+"/kess_pk_cs_e3_004_delta.dat")
Gev_fld_phi_z1=np.loadtxt("./"+address_fld+"/kess_pk_cs_e3_004_phi.dat")
########
# z=0
########
Gev_fld_delta_z0=np.loadtxt("./"+address_fld+"/kess_pk_cs_e3_005_delta.dat")
Gev_fld_phi_z0=np.loadtxt("./"+address_fld+"/kess_pk_cs_e3_005_phi.dat")

bg_Gevolution_fld=np.loadtxt("./"+address_fld+"/kess_cs_e3_background.dat")

Gev_fld_deltakess_z_all=[Gev_fld_delta_z100, Gev_fld_delta_z50, Gev_fld_delta_z10,
                         Gev_fld_delta_z6, Gev_fld_delta_z1, Gev_fld_delta_z0];
Gev_fld_phi_z_all=[Gev_fld_phi_z100, Gev_fld_phi_z50, Gev_fld_phi_z10,
                         Gev_fld_phi_z6, Gev_fld_phi_z1, Gev_fld_phi_z0];

#class:
#class powerspectra
addressClass="./Making_IC_Class"
class_newt_z100=np.loadtxt(addressClass+"/Class_kess_cs_e3_z99_newt_Gev.dat")
class_newt_z50=np.loadtxt(addressClass+"/Class_kess_cs_e3_z50_newt_Gev.dat")
class_newt_z10=np.loadtxt(addressClass+"/Class_kess_cs_e3_z10_newt_Gev.dat")
class_newt_z6=np.loadtxt(addressClass+"/Class_kess_cs_e3_z6_newt_Gev.dat")
class_newt_z1=np.loadtxt(addressClass+"/Class_kess_cs_e3_z1_newt_Gev.dat")
class_newt_z0=np.loadtxt(addressClass+"/Class_kess_cs_e3_z0_newt_Gev.dat")
class_z_all=[class_newt_z100, class_newt_z50, class_newt_z10, class_newt_z6, class_newt_z1, class_newt_z0];
#Phi_prime
class_phi_prime_z100=np.loadtxt(addressClass+"/Kessence_field_class_phi_prime_z99.dat")
class_phi_prime_z50=np.loadtxt(addressClass+"/Kessence_field_class_phi_prime_z50.dat")
class_phi_prime_z10=np.loadtxt(addressClass+"/Kessence_field_class_phi_prime_z10.dat")
class_phi_prime_z6=np.loadtxt(addressClass+"/Kessence_field_class_phi_prime_z6.dat")
class_phi_prime_z1=np.loadtxt(addressClass+"/Kessence_field_class_phi_prime_z1.dat")
class_phi_prime_z0=np.loadtxt(addressClass+"/Kessence_field_class_phi_prime_z0.dat")
class_phi_prime_z_all=[class_phi_prime_z100,class_phi_prime_z50,class_phi_prime_z10,
                       class_phi_prime_z6,class_phi_prime_z1,class_phi_prime_z0]
#Class matter powerspectrum for some checks
class_matter_pow_z100=np.loadtxt(addressClass+"/class_cs_e3_newt/class_kess_cs_e3_newt_z2_pk.dat")
class_matter_pow_z50=np.loadtxt(addressClass+"/class_cs_e3_newt/class_kess_cs_e3_newt_z3_pk.dat")
class_matter_pow_z10=np.loadtxt(addressClass+"/class_cs_e3_newt/class_kess_cs_e3_newt_z4_pk.dat")
class_matter_pow_z6=np.loadtxt(addressClass+"/class_cs_e3_newt/class_kess_cs_e3_newt_z5_pk.dat")
class_matter_pow_z1=np.loadtxt(addressClass+"/class_cs_e3_newt/class_kess_cs_e3_newt_z6_pk.dat")
class_matter_pow_z0=np.loadtxt(addressClass+"/class_cs_e3_newt/class_kess_cs_e3_newt_z7_pk.dat")
class_matter_pow_zall=[class_matter_pow_z100, class_matter_pow_z50, class_matter_pow_z10, class_matter_pow_z6,
                      class_matter_pow_z1, class_matter_pow_z0]
Gev_normal_pm=np.loadtxt("./lcdm_pk000_delta.dat")

# %% [markdown]
# # Background and cosmological parameters

# %%
#################################
#################################
# Cosmological parameters.
As=2.215*1.e-9;
h=0.67556;
kp=0.05/h; 
ns=0.9619;
cs2_e3=1.e-6;
c=2.99792458*1.e5; #Km/s
# Boxsize=320.;
# c_gev=2997.92458; #[100km/s]
# H0_conf_Gev=np.sqrt(Boxsize**2/c**2); #0.10677 rho_crit in Gev=1
H0=100*h/c; #H0 in 1/Mpc unit. 0.00022593979933110373
# print("H0[1/Mpc]=100h/c: ",H0);
w=-0.9;
print("H0[1/Mpc]=100h/c: ",H0);
def Hubble_conf_Mpc(a):
    c=2.99792458*1.e5;h=0.67556;H0=100*h/c;w=-0.9;
    Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
    Omega_m=Omega_b+Omega_cdm; Omega_Lambda=0;
    Omega_rad=9.1671353942930788e-05; Omega_kessence=1.-Omega_m-Omega_rad;
    return H0*np.sqrt(Omega_m*(a**-3)+Omega_rad*(a**-4)+Omega_kessence*(a**(-3*(1+w))))*a
Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
Omega_m=Omega_b + Omega_cdm;
z_all=[99.597220, 48.322258, 9.951253, 5.808126, 0.988975, 0.]
z_list=[100, 50, 10, 6, 1, 0]
# List of scale factor
a100=(1./(1.+z_all[0])); a50=(1./(1.+z_all[1])); a10=(1./(1.+z_all[2])); a6=(1./(1.+z_all[3]));
a1=(1./(1.+z_all[4])); a0=(1./(1.+z_all[5]));
a_all=[a100,a50,a10,a6,a1,a0]
H_conf_z100=Hubble_conf_Mpc(1./(1.+z_all[0])); # Unit=1/Mpc Hconf=a*H
H_conf_z50=Hubble_conf_Mpc(1./(1.+z_all[1])); # Unit=1/Mpc Hconf=a*H
H_conf_z10=Hubble_conf_Mpc(1./(1.+z_all[2])); # Unit=1/Mpc Hconf=a*H
H_conf_z6=Hubble_conf_Mpc(1./(1.+z_all[3])); # Unit=1/Mpc Hconf=a*H
H_conf_z1=Hubble_conf_Mpc(1./(1.+z_all[4])); # Unit=1/Mpc Hconf=a*H
H_conf_z0=Hubble_conf_Mpc(1./(1.+z_all[5])); # Unit=1/Mpc Hconf=a*H
H_conf_zall_list=[H_conf_z100, H_conf_z50, H_conf_z10,
                  H_conf_z6, H_conf_z1, H_conf_z0];
# Out:
# ('H0[1/Mpc]=100h/c: ', 0.00022534256015206366)

# %% [markdown]
# # Class extrapolation

# %%
#################################
#Making power of phi_prime field to compare with Gev
interp_class_phiprime_z100 =interp1d(class_phi_prime_z100[:,0],class_phi_prime_z100[:,2])
interp_class_phiprime_z50 =interp1d(class_phi_prime_z50[:,0],class_phi_prime_z50[:,2])
interp_class_phiprime_z10 =interp1d(class_phi_prime_z10[:,0],class_phi_prime_z10[:,2])
interp_class_phiprime_z6 =interp1d(class_phi_prime_z6[:,0],class_phi_prime_z6[:,2])
interp_class_phiprime_z1 =interp1d(class_phi_prime_z1[:,0],class_phi_prime_z1[:,2])
interp_class_phiprime_z0 =interp1d(class_phi_prime_z0[:,0],class_phi_prime_z0[:,2])

Class_power_phiprime_z100=As*((interp_class_phiprime_z100(Gev_lin_phi_prime_z100[:,0]))**2)*((Gev_lin_phi_prime_z100[:,0]/kp)**(ns-1.));
Class_power_phiprime_z50=As*((interp_class_phiprime_z50(Gev_lin_phi_prime_z50[:,0]))**2)*((Gev_lin_phi_prime_z50[:,0]/kp)**(ns-1.));
Class_power_phiprime_z10=As*((interp_class_phiprime_z10(Gev_lin_phi_prime_z10[:,0]))**2)*((Gev_lin_phi_prime_z10[:,0]/kp)**(ns-1.));
Class_power_phiprime_z6=As*((interp_class_phiprime_z6(Gev_lin_phi_prime_z6[:,0]))**2)*((Gev_lin_phi_prime_z6[:,0]/kp)**(ns-1.));
Class_power_phiprime_z1=As*((interp_class_phiprime_z1(Gev_lin_phi_prime_z1[:,0]))**2)*((Gev_lin_phi_prime_z1[:,0]/kp)**(ns-1.));
Class_power_phiprime_z0=As*((interp_class_phiprime_z0(Gev_lin_phi_prime_z0[:,0]))**2)*((Gev_lin_phi_prime_z0[:,0]/kp)**(ns-1.));
Class_power_phiprime_z_all=[Class_power_phiprime_z100,Class_power_phiprime_z50,
                            Class_power_phiprime_z10,Class_power_phiprime_z6,Class_power_phiprime_z1,Class_power_phiprime_z0]

#Making power of class field to compare with Gev
Class_power_z100=np.zeros((np.shape(Gev_lin_deltakess_z100)[0],8))
Class_power_z50=np.zeros((np.shape(Gev_lin_deltakess_z50)[0],8))
Class_power_z10=np.zeros((np.shape(Gev_lin_deltakess_z10)[0],8))
Class_power_z6=np.zeros((np.shape(Gev_lin_deltakess_z6)[0],8))
Class_power_z1=np.zeros((np.shape(Gev_lin_deltakess_z1)[0],8))
Class_power_z0=np.zeros((np.shape(Gev_lin_deltakess_z0)[0],8))
Class_Matter_power_z_all=np.zeros((np.shape(Gev_lin_delta_m_z100)[0],6))


# Making interpolation, for delta!
for i in range (1,7):
    interp_class_100 =interp1d(class_newt_z100[:,0],class_newt_z100[:,i])
    interp_class_50 =interp1d(class_newt_z50[:,0],class_newt_z50[:,i])
    interp_class_10 =interp1d(class_newt_z10[:,0],class_newt_z10[:,i])
    interp_class_6 =interp1d(class_newt_z6[:,0],class_newt_z6[:,i])
    interp_class_1 =interp1d(class_newt_z1[:,0],class_newt_z1[:,i])
    interp_class_0 =interp1d(class_newt_z0[:,0],class_newt_z0[:,i])
    
    Class_power_z100[:,i]=As*((interp_class_100(Gev_lin_deltakess_z100[:,0]))**2)*((Gev_lin_deltakess_z100[:,0]/kp)**(ns-1.));
    Class_power_z50[:,i]=As*((interp_class_50(Gev_lin_deltakess_z50[:,0]))**2)*((Gev_lin_deltakess_z50[:,0]/kp)**(ns-1.));
    Class_power_z10[:,i]=As*((interp_class_10(Gev_lin_deltakess_z10[:,0]))**2)*((Gev_lin_deltakess_z10[:,0]/kp)**(ns-1.));
    Class_power_z6[:,i]=As*((interp_class_6(Gev_lin_deltakess_z6[:,0]))**2)*((Gev_lin_deltakess_z6[:,0]/kp)**(ns-1.));
    Class_power_z1[:,i]=As*((interp_class_1(Gev_lin_deltakess_z1[:,0]))**2)*((Gev_lin_deltakess_z1[:,0]/kp)**(ns-1.));
    Class_power_z0[:,i]=As*((interp_class_0(Gev_lin_deltakess_z0[:,0]))**2)*((Gev_lin_deltakess_z0[:,0]/kp)**(ns-1.));

Class_power_z_all=[Class_power_z100,Class_power_z50,Class_power_z10,Class_power_z6,Class_power_z1,Class_power_z0]
#np.shape(Class_power_z_all)

##############################
###POISSON EQUATION Gevolution
##############################
#Making power of class field to compare with Gev. dimensionless power of phi from matter power!
phi_Gev_poisson_zall=np.zeros((np.shape(Gev_lin_deltakess_z100)[0],6))
for i in range (0,6):
    C_poiss=(9./4.)* (Omega_m)**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4);
    phi_Gev_poisson_zall[:,i]=C_poiss* (a_all[i]**-1)**2 * Gev_lin_delta_m_z_all[i][:,1]/((Gev_lin_delta_m_z_all[i][:,0]*h)**4);
# phi_class_poisson_z100= phi_class_poisson_zall[:,0]
# phi_class_poisson_z10= phi_class_poisson_zall[:,2]
# plt.loglog(Gev_lin_deltakess_z100[:,0],phi_class_poisson_zall[:,3] )
# plt.loglog(Gev_lin_deltakess_z100[:,0],Class_power_z6[:,5] )
# plt.show()


###########################
###POISSON EQUATION CLASS #
###########################
#Making power of class field to compare with Gev. dimensionless power of phi from matter power!
#k^3/2 pi^2 to make Class power dimensionless
phi_class_poisson_zall=np.zeros((np.shape(Gev_lin_deltakess_z100)[0],6))
for i in range (0,6):
    interp_class_matter_power=interp1d(class_matter_pow_zall[i][:,0],class_matter_pow_zall[i][:,1])
    interp_class_phi_poisson =interp1d(class_matter_pow_zall[i][:,0],class_matter_pow_zall[i][:,1])
    C_poiss=(9./4.)* (Omega_m)**2 * (Hubble_conf_Mpc(1./(1.+0.0))**4)/(2.*np.pi**2);
    
    #dimensionless class matter power, Class_Matter_power_z_all[:,0] ->z=100
    Class_Matter_power_z_all[:,i] = (Gev_lin_delta_m_z_all[i][:,0])**3* interp_class_matter_power(Gev_lin_deltakess_z_all[i][:,0])/(2.*np.pi**2)
    phi_class_poisson_zall[:,i]=C_poiss* (a_all[i]**-1)**2 * (Gev_lin_deltakess_z_all[i][:,0])**3* interp_class_phi_poisson(Gev_lin_deltakess_z_all[i][:,0])/((Gev_lin_deltakess_z_all[i][:,0]*h)**4);
# phi_class_poisson_z100= phi_class_poisson_zall[:,0]
# phi_class_poisson_z10= phi_class_poisson_zall[:,2]
#Class TEST
# plt.loglog(Gev_lin_deltakess_z100[:,0],phi_class_poisson_zall[:,3] )
# plt.loglog(Gev_lin_deltakess_z100[:,0],Class_power_z6[:,5] )

#Gev Poisson TEST
# i=0
# plt.loglog(Gev_lin_phi_z_all[i][:,0],phi_Gev_poisson_zall[:,0] )
# plt.loglog(Gev_lin_phi_z_all[i][:,0],Gev_lin_phi_z_all[i][:,1] )

#Matter power TEST
# plt.loglog(Gev_lin_phi_z_all[i][:,0],Gev_lin_delta_m_z_all[0][:,1] )
# plt.loglog(Gev_lin_phi_z_all[i][:,0],Class_Matter_power_z_all[:,0] )

# plt.show()

# %% [markdown]
# # Background tests

# %%
#################################
#Class Hubble_conformal factor, H in unit 1/Mpc!
# H in unit Mpc!
def Hubble_conf_Mpc(a):
    w=-0.9;h=0.67556;c=2.99792458*1.e5;H0=100.*h/c;
    Omega_b=0.022032/h/h; Omega_cdm=0.12038/h/h;
    Omega_m=Omega_b+Omega_cdm; Omega_Lambda=0.0;
    Omega_rad=9.1671353942930788e-05; Omega_kessence=1.-Omega_m-Omega_rad;
    return H0*np.sqrt(Omega_m*(a**-3)+Omega_rad*(a**-4)+Omega_Lambda+Omega_kessence*(a**(-3*(1+w))))*a
a=bg_Gevolution_lin[:,2];
# Gevolution background output : H_conf/H0
#####Interpolation###
#interp_field_bg_lin=interp1d(np.log(bg_Gevolution_fld[:,2]),np.log(bg_Gevolution_fld[:,3]))
interp_field_bg_lin=interp1d((bg_Gevolution_fld[:,2]),(bg_Gevolution_fld[:,3]))

#Plot setting
plt.figure(figsize=(14,10))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 12)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 13)
#*******************
#Subplot I
#Difference plot
plt.figure(1)
# plt.subplot(211)
# plt.loglog(bg_Gevolution_fld[:,2],np.exp(interp_field_bg_lin(np.log(bg_Gevolution_fld[:,2]))),color="green",label="JulInt-Gev")
# plt.loglog(bg_Gevolution_fld[:,2],bg_Gevolution_fld[:,3],color="blue",label="Julian-Gev")
# plt.loglog(bg_Gevolution_lin[:,2],bg_Gevolution_lin[:,3],color="red",label="Mine-Gev")
#plt.loglog(bg_Gevolution_lin[:,2],2.*np.abs(np.exp(interp_field_bg_lin(np.log(bg_Gevolution_lin[:,2])))-bg_Gevolution_lin[:,3])/(bg_Gevolution_lin[:,3]+np.exp(interp_field_bg_lin(np.log(bg_Gevolution_lin[:,2])))),".",color="olive",
#           label=r"2|$\frac{\mathcal{H}(fluid)-\mathcal{H}(field)}{\mathcal{H}(fluid)+\mathcal{H}(field)}|$")
plt.plot(bg_Gevolution_lin[:,2],np.abs((interp_field_bg_lin((bg_Gevolution_lin[:,2])))-bg_Gevolution_lin[:,3])/(bg_Gevolution_lin[:,3]+(interp_field_bg_lin((bg_Gevolution_lin[:,2])))),".",color="olive",
           label=r"2|$\frac{\mathcal{H}(fluid)-\mathcal{H}(field)}{\mathcal{H}(fluid)+\mathcal{H}(field)}|$")

# plt.xlim(8e-3,1)
# plt.ylim(1e-4,2e-2)
plt.xlabel("a",fontsize=12)
plt.ylabel(r"$\mathcal{H}(a)$",fontsize=12)
# plt.ylabel('log')
# plt.xlabel('log')

plt.legend()
plt.grid(True)

# # #SubplotI
# plt.subplot(212)
# # plt.loglog(a,Hubble_conf_Mpc(a)/Hubble_conf_Mpc(1.),color="red",label="formula")
# plt.loglog(bg_Gevolution_fld[:,2],np.abs(bg_Gevolution_fld[:,3]- Hubble_conf_Mpc(bg_Gevolution_fld[:,2])/Hubble_conf_Mpc(1.))/bg_Gevolution_fld[:,3],color="purple",
#            label=r"|$\frac{\mathcal{H}(field)-\mathcal{H}(formula)}{\mathcal{H}(field)}|$")

# plt.loglog(bg_Gevolution_fld[:,2],np.abs(interp_class_bg_lin(bg_Gevolution_fld[:,2])- Hubble_conf_Mpc(bg_Gevolution_fld[:,2])/Hubble_conf_Mpc(1.))/interp_class_bg_lin(bg_Gevolution_fld[:,2]),color="olive",
#            label=r"|$\frac{\mathcal{H}(fluid)-\mathcal{H}(formula)}{\mathcal{H}(fluid)}|$")
# # label=r"($\mathcal{H}$(Gev-fld)-$\mathcal{H}$(formula))/$\mathcal{H}$(Gev-fld)")
# # plt.xlim(8e-3,1)
# # plt.ylim(1e-4,2e-2)
# plt.xlabel("a",fontsize=20)
# plt.ylabel(r"$\mathcal{H}(a)$",fontsize=20)
# plt.legend()
# plt.grid(True)

# # #*******************
# # #SubplotIII
# # # Class background is H_phys [1/Mpc] 3d column.
# # # H_conf= H_phys * a
# # # 0th comun is redshift.
# plt.subplot(323)
# a_class=1./(1.+Class_Bg_newt_cs_e3[:,0]);
# plt.loglog(a_class,Hubble_conf_Mpc(a_class),color="red",label="formula")
# plt.loglog(a_class,Class_Bg_newt_cs_e3[:,3]*a_class,color="blue",label="Class ")
# plt.loglog(a_class,np.abs((Class_Bg_newt_cs_e3[:,3]*a_class-Hubble_conf_Mpc(a_class))/(Class_Bg_newt_cs_e3[:,3]*a_class)),color="olive",
#            label=r"($\mathcal{H}$(Class)-$\mathcal{H}$(formula))/$\mathcal{H}$(class)")

# # plt.xlim(8e-7,1)
# # plt.ylim(1e-4,2e-0)
# plt.xlabel("a",fontsize=20)
# plt.ylabel(r"$\mathcal{H}(a)$",fontsize=20)
# plt.legend()
# plt.grid(True)


# plt.savefig('./Gev-Class_Images/field-fluid.jpg', format='jpg', dpi=100)

# # All subplots adjusting
# plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25,
#                     wspace=0.25)
plt.show()

# %% [markdown]
# # Linear Class vs Linear Gevolution kessence_source_gravity= 1

# %%
# plt.figure(figsize=(30,30))
# ax = plt.gca()
# ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
# ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)

#Class Hubble factor, H in unit 1/Mpc!
# Theta Calculation Theta = pi * k^2
Gev_lin_theta_z_all=np.zeros((np.shape(Gev_lin_Hpi_z100)[0],6))
# Making interpolation, for delta!
for i in range (0,5):
    Gev_lin_theta_z_all[:,i] =Gev_lin_Hpi_z_all[i][:,1] * (Gev_lin_Hpi_z_all[i][:,0]*h)**4/(H_conf_zall_list[i]**2)


string=r"$N_{grid} =1920, boxsize= 1600.0 \,, \, nKe\_numsteps=10 \, , \, time step limit = 0.04$";
# plt.loglog(Gev_lin_phi_z_all[i][:,0],Gev_lin_delta_m_z_all[4][:,1] )
# plt.loglog(Gev_lin_phi_z_all[i][:,0],Class_Matter_power_z_all[:,4] )
plt.figure(figsize=(13,9))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 10)
plt.figure(1)
#####################
#####################
#####################

#     #Julian
#     plt.loglog(Gev_fld_deltakess_z_all[i][:,0], Gev_fld_deltakess_z_all[i][:,1],color="blue",linestyle='dashed',lw=1.5,  label=r"$\delta_{m}$, Gevolution-fluid, z="+str(z_list[i]))
# #     plt.loglog(Gev_lin_deltakess_z10[:,0], Class_Matter_power_z_all[:,i],color="purple",linestyle='solid',lw=1.5,label=r"$\delta_{m}$ class, z="+str(z_list[i]))
#     plt.loglog(Gev_lin_delta_m_z0[:,0], Gev_lin_delta_m_z_all[i][:,1],color="red",linestyle='dashed',lw=1.5,  label=r"$\delta_{m}$, Gevolution-linear, z="+str(z_list[i]))
plt.semilogx(Gev_lin_phi_z100[:,0], (Gev_lin_phi_z100[:,1]-Gev_fld_phi_z100[:,1])/Gev_fld_phi_z100[:,1],color="darkblue",linestyle='dashed',lw=1.5, label=r"$\frac{\Phi(field)-\Phi(fluid)}{\Phi(fluid)}$,  z=100 ")
plt.semilogx(Gev_lin_phi_z10[:,0], (Gev_lin_phi_z10[:,1]-Gev_fld_phi_z10[:,1])/Gev_fld_phi_z10[:,1],color="red",linestyle='dashed',lw=1.5, label=r"$\frac{\Phi(field)-\Phi(fluid)}{\Phi(fluid)}$, z=10 ")
plt.semilogx(Gev_lin_phi_z6[:,0], (Gev_lin_phi_z6[:,1]-Gev_fld_phi_z6[:,1])/Gev_fld_phi_z6[:,1],color="magenta",linestyle='dashed',lw=1.5, label=r"$\frac{\Phi(field)-\Phi(fluid)}{\Phi(fluid)}$,  z=6 ")
plt.semilogx(Gev_lin_phi_z1[:,0], (Gev_lin_phi_z1[:,1]-Gev_fld_phi_z1[:,1])/Gev_fld_phi_z1[:,1],color="cyan",linestyle='dashed',lw=1.5, label=r"$\frac{\Phi(field)-\Phi(fluid)}{\Phi(fluid)}$, z=1 ")
plt.semilogx(Gev_lin_phi_z0[:,0], (Gev_lin_phi_z0[:,1]-Gev_fld_phi_z0[:,1])/Gev_fld_phi_z0[:,1],color="purple",linestyle='dashed',lw=1.5, label=r"$\frac{\Phi(field)-\Phi(fluid)}{\Phi(fluid)}$, z=0 ")

ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 16)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)
#     plt.axvline(x=Hubble_conf_Mpc(a_all[i])/h, color='brown', linestyle='-',label=r"Hubble-horizon(z="+str(z_list[i])+")")
#     plt.axvline(x=Hubble_conf_Mpc(a_all[i])/np.sqrt(cs2_e3)/h, color='tomato', linestyle='-',label=r"Sound-horizon(z="+str(z_list[i])+")")
    
plt.legend(bbox_to_anchor=(0.5, 0.35, 0.4, .102), loc=1,ncol=1,fontsize=16, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=16)
plt.ylabel(r"$\mathcal{P} $",fontsize=16)
#     plt.xlim(0.01,5.e-1)
#     plt.ylim(1-4.e-3,1+0.007)
plt.grid(True)
plt.title(string,fontsize=16)
# ax.loglog()

#     plt.yticks([])
#     ax.axis([3.e-2, 7, 1-1.e-2, 1+1.e-3])
plt.savefig("./phi_comp.jpg", format='jpg', dpi=100)

plt.show()

# %%
# plt.figure(figsize=(30,30))
# ax = plt.gca()
# ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
# ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)

#Class Hubble factor, H in unit 1/Mpc!
# Theta Calculation Theta = pi * k^2
Gev_lin_theta_z_all=np.zeros((np.shape(Gev_lin_Hpi_z100)[0],6))
# Making interpolation, for delta!
for i in range (0,5):
    Gev_lin_theta_z_all[:,i] =Gev_lin_Hpi_z_all[i][:,1] * (Gev_lin_Hpi_z_all[i][:,0]*h)**4/(H_conf_zall_list[i]**2)


string=r"$N_{grid} =1920, boxsize= 1600.0 \,, \, nKe\_numsteps=10 \, , \, time step limit = 0.04$";
# plt.loglog(Gev_lin_phi_z_all[i][:,0],Gev_lin_delta_m_z_all[4][:,1] )
# plt.loglog(Gev_lin_phi_z_all[i][:,0],Class_Matter_power_z_all[:,4] )
plt.figure(figsize=(13,9))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 10)
plt.figure(1)
#####################
#####################
#####################

#     #Julian
#     plt.loglog(Gev_fld_deltakess_z_all[i][:,0], Gev_fld_deltakess_z_all[i][:,1],color="blue",linestyle='dashed',lw=1.5,  label=r"$\delta_{m}$, Gevolution-fluid, z="+str(z_list[i]))
# #     plt.loglog(Gev_lin_deltakess_z10[:,0], Class_Matter_power_z_all[:,i],color="purple",linestyle='solid',lw=1.5,label=r"$\delta_{m}$ class, z="+str(z_list[i]))
#     plt.loglog(Gev_lin_delta_m_z0[:,0], Gev_lin_delta_m_z_all[i][:,1],color="red",linestyle='dashed',lw=1.5,  label=r"$\delta_{m}$, Gevolution-linear, z="+str(z_list[i]))
plt.semilogx(Gev_lin_deltakess_z100[:,0], (Gev_lin_delta_m_z100[:,1]-Gev_fld_delta_z100[:,1])/Gev_fld_delta_z100[:,1],color="darkblue",linestyle='dashed',lw=1.5, label=r"$\frac{\delta_{m}(field)-\delta_{m}(fluid)}{\delta_{m}(fluid)}$,  z=100 ")
plt.semilogx(Gev_lin_deltakess_z10[:,0], (Gev_lin_delta_m_z10[:,1]-Gev_fld_delta_z10[:,1])/Gev_fld_delta_z10[:,1],color="red",linestyle='dashed',lw=1.5, label=r"$\frac{\delta_{m}(field)-\delta_{m}(fluid)}{\delta_{m}(fluid)}$, z=10 ")
plt.semilogx(Gev_lin_deltakess_z6[:,0], (Gev_lin_delta_m_z6[:,1]-Gev_fld_delta_z6[:,1])/Gev_fld_delta_z6[:,1],color="magenta",linestyle='dashed',lw=1.5, label=r"$\frac{\delta_{m}(field)-\delta_{m}(fluid)}{\delta_{m}(fluid)}$,  z=6 ")
plt.semilogx(Gev_lin_deltakess_z1[:,0], (Gev_lin_delta_m_z1[:,1]-Gev_fld_delta_z1[:,1])/Gev_fld_delta_z1[:,1],color="cyan",linestyle='dashed',lw=1.5, label=r"$\frac{\delta_{m}(field)-\delta_{m}(fluid)}{\delta_{m}(fluid)}$, z=1 ")
plt.semilogx(Gev_lin_deltakess_z0[:,0], (Gev_lin_delta_m_z0[:,1]-Gev_fld_delta_z0[:,1])/Gev_fld_delta_z0[:,1],color="purple",linestyle='dashed',lw=1.5, label=r"$\frac{\delta_{m}(field)-\delta_{m}(fluid)}{\delta_{m}(fluid)}$, z=0 ")

ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 16)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 12)
#     plt.axvline(x=Hubble_conf_Mpc(a_all[i])/h, color='brown', linestyle='-',label=r"Hubble-horizon(z="+str(z_list[i])+")")
#     plt.axvline(x=Hubble_conf_Mpc(a_all[i])/np.sqrt(cs2_e3)/h, color='tomato', linestyle='-',label=r"Sound-horizon(z="+str(z_list[i])+")")
    
plt.legend(bbox_to_anchor=(0.0, 0.88, 0.4, .102), loc=1,ncol=1,fontsize=16, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=16)
plt.ylabel(r"$\mathcal{P} $",fontsize=16)
#     plt.xlim(0.01,5.e-1)
#     plt.ylim(1-4.e-3,1+0.007)
plt.grid(True)
plt.title(string,fontsize=16)
# ax.loglog()

#     plt.yticks([])
#     ax.axis([3.e-2, 7, 1-1.e-2, 1+1.e-3])
plt.savefig("./deltam_comp.jpg", format='jpg', dpi=100)

plt.show()

# %%
##### plt.figure(figsize=(30,30))
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 24)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 16)


# Theta Calculation Theta = pi * k^2
Gev_lin_theta_z100= Gev_lin_Hpi_z100[:,1] * (Gev_lin_Hpi_z100[:,0]*h)**4/(H_conf_z100**2)
Gev_lin_theta_z50= Gev_lin_Hpi_z50[:,1] * (Gev_lin_Hpi_z50[:,0]*h)**4/(H_conf_z50**2)
Gev_lin_theta_z10= Gev_lin_Hpi_z10[:,1] * (Gev_lin_Hpi_z10[:,0]*h)**4/(H_conf_z10**2)
Gev_lin_theta_z6= Gev_lin_Hpi_z6[:,1] * (Gev_lin_Hpi_z6[:,0]*h)**4/(H_conf_z6**2)
Gev_lin_theta_z1= Gev_lin_Hpi_z1[:,1] * (Gev_lin_Hpi_z1[:,0]*h)**4/(H_conf_z1**2)
Gev_lin_theta_z0= Gev_lin_Hpi_z0[:,1] * (Gev_lin_Hpi_z0[:,0]*h)**4/(H_conf_z0**2)

string=r"$N_{grid} =1920, boxsize= 1600.0 \,, \, nKe_numsteps=10 \, , \, time step limit = 0.04$";

plt.figure(1)
#####################
#####################
#####################
#Blue,red,purple,olivedrab,darkblue,salmon,blueviolet,yellowgreen

#SubplotI Check the pi in class and Gevolution
# Hconf*pi comparison
plt.subplot(321)
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 12)
ax.tick_params(axis = 'both', which = 'minor', labelsize = 12)
plt.loglog(Gev_lin_deltakess_z10[:,0], Gev_lin_deltakess_z10[:,1],color="darkblue",linestyle='dashed',lw=1.5, label=r"$\delta_{kess}$, Gevolution-linear,  z=10 ")
plt.loglog(Gev_lin_delta_m_z10[:,0], Gev_lin_delta_m_z10[:,1],color="red",linestyle='dashed',lw=1.5,  label=r"$\delta_{m}$, Gevolution-linear,  z=10 ")
plt.loglog(Gev_lin_deltakess_z0[:,0], Gev_lin_deltakess_z0[:,1],color="purple",linestyle='dashed',lw=1.5, label=r"$\delta_{kess}$, Gevolution-linear,  z=0 ")
plt.loglog(Gev_lin_delta_m_z0[:,0], Gev_lin_delta_m_z0[:,1],color="olivedrab",linestyle='dashed',lw=1.5,  label=r"$\delta_{m}$, Gevolution-linear,  z=0 ")
#Class
plt.loglog(Gev_lin_deltakess_z10[:,0], Class_power_z10[:,3],color="blue",linestyle='solid',lw=1.5,label=r"$\delta_{kess}$ class z=10 ")
plt.loglog(Gev_lin_deltakess_z10[:,0], Class_Matter_power_z_all[:,2],color="salmon",linestyle='solid',lw=1.5,label=r"$\delta_{m}$ class z=10 ")
plt.loglog(Gev_lin_deltakess_z10[:,0], Class_power_z0[:,3],color="blueviolet",linestyle='solid',lw=1.5,label=r"$\delta_{kess}$ class z=0 ")
plt.loglog(Gev_lin_deltakess_z10[:,0], Class_Matter_power_z_all[:,5],color="yellowgreen",linestyle='solid',lw=1.5,label=r"$\delta_{m}$ class z=0 ")
# plt.axvline(x=Hubble_conf_Mpc(a_all[i])/h, color='brown', linestyle='-',label=r"Hubble-horizon")
# plt.axvline(x=Hubble_conf_Mpc(a_all[i])/np.sqrt(cs2_e3)/h, color='tomato', linestyle='-',label=r"Sound-horizon")
# plt.axvline(x=Hubble_conf_Mpc(a_all[0])/np.sqrt(cs2_e3)/h, color='firebrick', linestyle='-',label=r"sound-horizon (z="+str(z_list[0])+")")#a_all[2] z=10
plt.axvline(x=Hubble_conf_Mpc(a_all[2])/np.sqrt(cs2_e3)/h, color='brown', linestyle='-',label=r"sound-horizon (z="+str(z_list[2])+")")#a_all[2] z=10
plt.axvline(x=Hubble_conf_Mpc(a_all[5])/np.sqrt(cs2_e3)/h, color='tomato', linestyle='-',label=r"sound-horizon(z="+str(z_list[5])+")")    

plt.legend(bbox_to_anchor=(0.1, 0.30, 0.3, .102), loc=1,ncol=1,fontsize=10, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=14)
plt.ylabel(r"$\mathcal{P} $",fontsize=14)
# plt.xlim(0.01,5.e-1)
# plt.ylim(1.e-15,1.e-9)
plt.grid(True)
plt.title(string)
#####################
#####################
#####################
plt.subplot(322)
plt.loglog(Gev_lin_deltakess_z100[:,0], Gev_lin_theta_z100[:],color="darkblue",linestyle='dashed',lw=1.5, label=r"$\theta$, Gevolution-linear,  z=100 ")
plt.loglog(Gev_lin_deltakess_z10[:,0], Gev_lin_theta_z10[:],color="red",linestyle='dashed',lw=1.5, label=r"$\theta$, Gevolution-linear,  z=10 ")
plt.loglog(Gev_lin_deltakess_z0[:,0], Gev_lin_theta_z0[:],color="purple",linestyle='dashed',lw=1.5, label=r"$\theta$, Gevolution-linear,  z=0 ")
# Class 
plt.loglog(Gev_lin_deltakess_z100[:,0], Class_power_z100[:,4],color="blue",linestyle='dashed',lw=1.5,label=r"$\theta$ class z=100 ")
plt.loglog(Gev_lin_deltakess_z10[:,0], Class_power_z10[:,4],color="salmon",linestyle='dashed',lw=1.5,label=r"$\theta$ class z=10 ")
plt.loglog(Gev_lin_deltakess_z0[:,0], Class_power_z0[:,4],color="blueviolet",linestyle='dashed',lw=1.5,label=r"$\theta$ class z=0 ")
# plt.axvline(x=Hubble_conf_Mpc(a_all[i])/h, color='brown', linestyle='-',label=r"Hubble-horizon")
# plt.axvline(x=Hubble_conf_Mpc(a_all[i])/np.sqrt(cs2_e3)/h, color='tomato', linestyle='-',label=r"Sound-horizon")
plt.axvline(x=Hubble_conf_Mpc(a_all[0])/np.sqrt(cs2_e3)/h, color='firebrick', linestyle='-',label=r"sound-horizon (z="+str(z_list[0])+")")#a_all[2] z=10
plt.axvline(x=Hubble_conf_Mpc(a_all[2])/np.sqrt(cs2_e3)/h, color='brown', linestyle='-',label=r"sound-horizon (z="+str(z_list[2])+")")#a_all[2] z=10
plt.axvline(x=Hubble_conf_Mpc(a_all[5])/np.sqrt(cs2_e3)/h, color='tomato', linestyle='-',label=r"sound-horizon(z="+str(z_list[5])+")")    

plt.title(string)
plt.legend(bbox_to_anchor=(0.1, 0.20, 0.3, .102), loc=1,ncol=1,fontsize=10, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=14)
plt.ylabel(r"$\mathcal{P} $",fontsize=14)
# plt.xlim(0.01,5.e-1)
plt.ylim(2.e-14,1.e-7)
plt.grid(True)
#####################
#####################
#####################
plt.subplot(323)
plt.loglog(Gev_lin_deltakess_z100[:,0], Gev_lin_deltakess_z100[:,1]/Gev_lin_delta_m_z100[:,1],color="darkblue",linestyle='dashed',lw=1.5, label=r"$\delta_{kess}/\delta_{m}$, Gevolution-linear,  z=100 ")
plt.loglog(Gev_lin_deltakess_z10[:,0], Gev_lin_deltakess_z10[:,1]/Gev_lin_delta_m_z10[:,1],color="red",linestyle='dashed',lw=1.5, label=r"$\delta_{kess}/\delta_{m}$, Gevolution-linear,  z=10 ")
plt.loglog(Gev_lin_deltakess_z0[:,0], Gev_lin_deltakess_z0[:,1]/Gev_lin_delta_m_z0[:,1],color="purple",linestyle='dashed',lw=1.5, label=r"$\delta_{kess}/\delta_{m}$, Gevolution-linear,  z=0 ")
# Class 
plt.loglog(Gev_lin_deltakess_z100[:,0], Class_power_z100[:,3]/Class_Matter_power_z_all[:,0],color="blue",linestyle='dashed',lw=1.5,label=r"$\delta_{kess}/\delta_{m}$ class z=100 ")
plt.loglog(Gev_lin_deltakess_z10[:,0], Class_power_z10[:,3]/Class_Matter_power_z_all[:,2],color="salmon",linestyle='dashed',lw=1.5,label=r"$\delta_{kess}/\delta_{m}$ class z=10 ")
plt.loglog(Gev_lin_deltakess_z0[:,0], Class_power_z0[:,3]/Class_Matter_power_z_all[:,5],color="blueviolet",linestyle='dashed',lw=1.5,label=r"$\delta_{kess}/\delta_{m}$ class z=0 ")
# plt.title(r"$N_{grid} =64, boxsize= 1600.0 \,, \, nKe_numsteps=1 \, , \, time step limit = 0.04$")
plt.axvline(x=Hubble_conf_Mpc(a_all[0])/np.sqrt(cs2_e3)/h, color='firebrick', linestyle='-',label=r"sound-horizon (z="+str(z_list[0])+")")#a_all[2] z=10
plt.axvline(x=Hubble_conf_Mpc(a_all[2])/np.sqrt(cs2_e3)/h, color='brown', linestyle='-',label=r"sound-horizon (z="+str(z_list[2])+")")#a_all[2] z=10
plt.axvline(x=Hubble_conf_Mpc(a_all[5])/np.sqrt(cs2_e3)/h, color='tomato', linestyle='-',label=r"sound-horizon(z="+str(z_list[5])+")")    

plt.legend(bbox_to_anchor=(0.1, 0.20, 0.3, .102), loc=1,ncol=1,fontsize=10, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=14)
plt.ylabel(r"$\mathcal{P} $",fontsize=14)
# plt.xlim(0.01,5.e-1)
plt.ylim(8.e-8,5.e-3)
plt.grid(True)
#####################
#####################
#####################
plt.subplot(324)
plt.loglog(Gev_lin_Hpi_z10[:,0], Gev_lin_Hpi_z10[:,1],color="darkblue",linestyle='dashed',lw=1.5,  label=r"$\pi \mathcal{H}$, Gevolution-Lin,  z=10 ")
plt.loglog(Gev_lin_zeta_z10[:,0], Gev_lin_zeta_z10[:,1],color="red",linestyle='dashed',lw=1.5, label=r"$\zeta$, Gevolution-Lin,  z=10 ")
plt.loglog(Gev_lin_Hpi_z0[:,0], Gev_lin_Hpi_z0[:,1],color="purple",linestyle='dashed',lw=1.5,  label=r"$\pi \mathcal{H}$, Gevolution-Lin,  z=0 ")
plt.loglog(Gev_lin_zeta_z0[:,0], Gev_lin_zeta_z0[:,1],color="olivedrab",linestyle='dashed',lw=1.5, label=r"$\zeta$, Gevolution-Lin,  z=0 ")
# Class z=10
plt.loglog(Gev_lin_Hpi_z10[:,0], Class_power_z10[:,1]*H_conf_z10**2,color="blue",linestyle='solid',lw=1.5,label=r"$\pi \mathcal{H}$ class z=10 ")
plt.loglog(Gev_lin_zeta_z10[:,0], Class_power_z10[:,2],color="salmon",linestyle='solid',lw=1.5,label=r"$\zeta$ class z=10 ")
plt.loglog(Gev_lin_Hpi_z0[:,0], Class_power_z0[:,1]*H_conf_z0**2,color="blueviolet",linestyle='solid',lw=1.5,label=r"$\pi \mathcal{H}$ class z=0 ")
plt.loglog(Gev_lin_zeta_z0[:,0], Class_power_z0[:,2],color="yellowgreen",linestyle='solid',lw=1.5,label=r"$\zeta$ class z=0 ")
# plt.axvline(x=Hubble_conf_Mpc(a_all[0])/np.sqrt(cs2_e3)/h, color='firebrick', linestyle='-',label=r"sound-horizon (z="+str(z_list[0])+")")#a_all[2] z=10
plt.axvline(x=Hubble_conf_Mpc(a_all[2])/np.sqrt(cs2_e3)/h, color='brown', linestyle='-',label=r"sound-horizon (z="+str(z_list[2])+")")#a_all[2] z=10
plt.axvline(x=Hubble_conf_Mpc(a_all[5])/np.sqrt(cs2_e3)/h, color='tomato', linestyle='-',label=r"sound-horizon(z="+str(z_list[5])+")")    
    
# plt.title(r"$N_{grid} =64, boxsize= 500.0 \,, \, nKe_numsteps=1 \, , \, time step limit = 0.04$")
plt.legend(bbox_to_anchor=(0.1, 0.30, 0.3, .102), loc=1,ncol=1,fontsize=10, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=14)
plt.ylabel(r"$\mathcal{P} $",fontsize=14)
# plt.xlim(0.01,5.e-1)
# plt.ylim(1.e-15,1.e-9)
plt.grid(True)
#####################
#####################
#####################
plt.subplot(325)

plt.loglog(Gev_lin_delta_m_z100[:,0], 2.*np.abs(Gev_lin_delta_m_z100[:,1] -Class_Matter_power_z_all[:,0])
           /(Gev_lin_delta_m_z100[:,1] + Class_Matter_power_z_all[:,0]) ,color="darkblue",linestyle='dashed',
           lw=1.5,  label=r"$2 \frac{\delta_m(gev) - \delta_m(class)} {\delta_m(gev) + \delta_m(class)}$, Gevolution-Lin,  z=100 ")

plt.loglog(Gev_lin_delta_m_z10[:,0], 2.*np.abs(Gev_lin_delta_m_z10[:,1] -Class_Matter_power_z_all[:,2])
           /(Gev_lin_delta_m_z10[:,1] + Class_Matter_power_z_all[:,2]) ,color="red",linestyle='dashed',
           lw=1.5,  label=r"$2 \frac{\delta_m(gev) - \delta_m(class)} {\delta_m(gev) + \delta_m(class)}$, Gevolution-Lin,  z=10 ")
plt.loglog(Gev_lin_delta_m_z0[:,0], 2.*np.abs(Gev_lin_delta_m_z0[:,1] -Class_Matter_power_z_all[:,5])
           /(Gev_lin_delta_m_z0[:,1] + Class_Matter_power_z_all[:,5]) ,color="purple",linestyle='dashed',
           lw=1.5,  label=r"$2 \frac{\delta_m(gev) - \delta_m(class)} {\delta_m(gev) + \delta_m(class)}$, Gevolution-Lin,  z=0 ")
plt.axvline(x=Hubble_conf_Mpc(a_all[0])/np.sqrt(cs2_e3)/h, color='firebrick', linestyle='-',label=r"sound-horizon (z="+str(z_list[0])+")")#a_all[2] z=10
plt.axvline(x=Hubble_conf_Mpc(a_all[2])/np.sqrt(cs2_e3)/h, color='brown', linestyle='-',label=r"sound-horizon (z="+str(z_list[2])+")")#a_all[2] z=10
plt.axvline(x=Hubble_conf_Mpc(a_all[5])/np.sqrt(cs2_e3)/h, color='tomato', linestyle='-',label=r"sound-horizon(z="+str(z_list[5])+")")    

plt.legend(bbox_to_anchor=(0.0, 0.20, 0.3, .102), loc=1,ncol=1,fontsize=10, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=14)
plt.ylabel(r"$\mathcal{P} $",fontsize=14)
# plt.xlim(0.01,5.e-1)
# plt.ylim(1.e-15,1.e-9)
plt.grid(True)
#####################
#####################
#####################
plt.subplot(326)
plt.loglog(Gev_lin_Hpi_z10[:,0], 2.*np.abs(Gev_lin_Hpi_z10[:,1] -Class_power_z10[:,1]*H_conf_z10**2)
           /(Gev_lin_Hpi_z10[:,1]+Class_power_z10[:,1]*H_conf_z10**2) ,color="darkblue",linestyle='solid',
           lw=1.5,  label=r"$2 \frac{ \pi \mathcal{H}(gev) - \pi \mathcal{H}(class)} {\pi \mathcal{H}(gev) + \pi \mathcal{H}(class)}$, Gevolution-Lin,  z=10 ")
plt.loglog(Gev_lin_zeta_z10[:,0], 2.* np.abs(Gev_lin_zeta_z10[:,1]-Class_power_z10[:,2])/(Gev_lin_zeta_z10[:,1]+Class_power_z10[:,2])
           ,color="red",linestyle='solid',lw=1.5, label=r"$2 \frac{ \zeta (gev) - \zeta(class)} {\zeta (gev) + \zeta(class)}$, Gevolution-Lin,  z=10 ")
#####################
plt.loglog(Gev_lin_Hpi_z0[:,0], 2.*np.abs(Gev_lin_Hpi_z0[:,1] -Class_power_z0[:,1]*H_conf_z0**2)
           /(Gev_lin_Hpi_z0[:,1]+Class_power_z0[:,1]*H_conf_z0**2) ,color="purple",linestyle='solid',
           lw=1.5,  label=r"$2 \frac{ \pi \mathcal{H}(gev) - \pi \mathcal{H}(class)} {\pi \mathcal{H}(gev) + \pi \mathcal{H}(class)}$, Gevolution-Lin,  z=0 ")
plt.loglog(Gev_lin_zeta_z0[:,0], 2.* np.abs(Gev_lin_zeta_z0[:,1]-Class_power_z0[:,2])/(Gev_lin_zeta_z0[:,1]+Class_power_z0[:,2])
           ,color="olivedrab",linestyle='solid',lw=1.5, label=r"$2 \frac{ \zeta (gev) - \zeta(class)} {\zeta (gev) + \zeta(class)}$, Gevolution-Lin,  z=0 ")
# plt.axvline(x=Hubble_conf_Mpc(a_all[0])/np.sqrt(cs2_e3)/h, color='firebrick', linestyle='-',label=r"sound-horizon (z="+str(z_list[0])+")")#a_all[2] z=10
plt.axvline(x=Hubble_conf_Mpc(a_all[2])/np.sqrt(cs2_e3)/h, color='brown', linestyle='-',label=r"sound-horizon (z="+str(z_list[2])+")")#a_all[2] z=10
plt.axvline(x=Hubble_conf_Mpc(a_all[5])/np.sqrt(cs2_e3)/h, color='tomato', linestyle='-',label=r"sound-horizon(z="+str(z_list[5])+")")    
    
plt.legend(bbox_to_anchor=(0.0, 0.20, 0.3, .102), loc=1,ncol=1,fontsize=10, mode="expand", borderaxespad=0.)
plt.xlabel("k[h/Mpc]",fontsize=14)
plt.ylabel(r"$\mathcal{P} $",fontsize=14)
# plt.xlim(0.01,5.e-1)li
# plt.ylim(1.e-15,1.e-9)
plt.grid(True)

# plt.savefig('./Gev-Class_Images/Kessence_evolution_Ngrid_1912.jpg', format='jpg', dpi=100)
plt.show()
